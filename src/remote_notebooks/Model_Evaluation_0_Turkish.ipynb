# %%
from google.colab import drive

import json
import random
import time
from typing import Optional

import torch
import numpy as np

drive.mount('/content/drive', force_remount=True)
root_filepath = '/content/drive/MyDrive/CS685-NLP-GroupProject/Code/singleNotebookFromPythonFilesStructure/'
is_remote_execution = True
torch.set_printoptions(threshold=100000, edgeitems=10000, linewidth=100000)
torch.device("cuda")


# 16M Turkish
SETimesByT5Vaswani2017Kocmi2018_0 = {
    'runner_hyperparameters_name': 'SETimesByT5Vaswani2017Kocmi2018_0',
    'model_parameter_filepath': root_filepath + "resources/saved_parameters/SETimesByT5Vaswani2017Kocmi2018_0-1715937924-model.params",
    'datasets_filepath': root_filepath + "resources/parsed_datasets/setimes/setimes_parsed-1715586293",
    'output_filepath': root_filepath + "resources/model_translations/SETimesByT5Vaswani2017Kocmi2018_0.json",
    'model_hyperparameters': {
        'src_vocab_size': 91,
        'tgt_vocab_size': 81,
        'max_src_seq_len': 266,
        'max_tgt_seq_len': 256,
        'd_model': 256,
        'nhead': 8,
        # number of encoders is 3 times that of decoders, following Xue 2021 - ByT5 - Sec 3.1
        'num_encoder_layers': 9,
        'num_decoder_layers': 3,
        'dim_feedforward': 2048,
        'dropout': 0.1,
        'activation': torch.nn.functional.relu,
        'custom_encoder': None,
        'custom_decoder': None,
        'layer_norm_eps': 1e-5,
        'batch_first': True,
        'norm_first': False,
        'bias': True,
        'device': None,
        'dtype': None
    }
}

# 15M Turkish
SETimesByT5Vaswani2017Kocmi2018_1 = {
    'runner_hyperparameters_name': 'SETimesByT5Vaswani2017Kocmi2018_1',
    'model_parameter_filepath': root_filepath + "resources/saved_parameters/SETimesByT5Vaswani2017Kocmi2018_1-1715937961-model.params",
    'datasets_filepath': root_filepath + "resources/parsed_datasets/setimes/setimes_parsed-1715586974",
    'output_filepath': root_filepath + "resources/model_translations/SETimesByT5Vaswani2017Kocmi2018_1.json",
    'model_hyperparameters': {
        'src_vocab_size': 91,
        'tgt_vocab_size': 81,
        'max_src_seq_len': 266,
        'max_tgt_seq_len': 256,
        'd_model': 256,
        'nhead': 8,
        # number of encoders is 3 times that of decoders, following Xue 2021 - ByT5 - Sec 3.1
        'num_encoder_layers': 9,
        'num_decoder_layers': 3,
        'dim_feedforward': 1796,
        'dropout': 0.1,
        'activation': torch.nn.functional.relu,
        'custom_encoder': None,
        'custom_decoder': None,
        'layer_norm_eps': 1e-5,
        'batch_first': True,
        'norm_first': False,
        'bias': True,
        'device': None,
        'dtype': None
    }
}

# 4M Turkish
SETimesByT5Vaswani2017Kocmi2018_2 = {
    'runner_hyperparameters_name': 'SETimesByT5Vaswani2017Kocmi2018_2',
    'model_parameter_filepath': root_filepath + "resources/saved_parameters/SETimesByT5Vaswani2017Kocmi2018_2-1715936459-model.params",
    'datasets_filepath': root_filepath + "resources/parsed_datasets/setimes/setimes_parsed-1715586361",
    'output_filepath': root_filepath + "resources/model_translations/SETimesByT5Vaswani2017Kocmi2018_2.json",
    'model_hyperparameters': {
        'src_vocab_size': 91,
        'tgt_vocab_size': 81,
        'max_src_seq_len': 266,
        'max_tgt_seq_len': 256,
        'd_model': 128,
        'nhead': 8,
        # number of encoders is 3 times that of decoders, following Xue 2021 - ByT5 - Sec 3.1
        'num_encoder_layers': 9,
        'num_decoder_layers': 3,
        'dim_feedforward': 1024,
        'dropout': 0.1,
        'activation': torch.nn.functional.relu,
        'custom_encoder': None,
        'custom_decoder': None,
        'layer_norm_eps': 1e-5,
        'batch_first': True,
        'norm_first': False,
        'bias': True,
        'device': None,
        'dtype': None
    }
}

# 16M Kazakh
NewsCommentaryByT5Vaswani2017Kocmi2018_0 = {
    'runner_hyperparameters_name': 'NewsCommentaryByT5Vaswani2017Kocmi2018_0',
    'model_parameter_filepath': root_filepath + "resources/saved_parameters/NewsCommentaryByT5Vaswani2017Kocmi2018_0-1715965639-model.params",
    'datasets_filepath': root_filepath + "resources/parsed_datasets/SMTNewsCommentary/SMTNewsCommentary_parsed-1715949808",
    'output_filepath': root_filepath + "resources/model_translations/NewsCommentaryByT5Vaswani2017Kocmi2018_0.json",
    'model_hyperparameters': {
        'src_vocab_size': 150,
        'tgt_vocab_size': 81,
        'max_src_seq_len': 266,
        'max_tgt_seq_len': 256,
        'd_model': 256,
        'nhead': 8,
        # number of encoders is 3 times that of decoders, following Xue 2021 - ByT5 - Sec 3.1
        'num_encoder_layers': 9,
        'num_decoder_layers': 3,
        'dim_feedforward': 2048,
        'dropout': 0.1,
        'activation': torch.nn.functional.relu,
        'custom_encoder': None,
        'custom_decoder': None,
        'layer_norm_eps': 1e-5,
        'batch_first': True,
        'norm_first': False,
        'bias': True,
        'device': None,
        'dtype': None
    }
}

# 15M Kazakh
NewsCommentaryByT5Vaswani2017Kocmi2018_1 = {
    'runner_hyperparameters_name': 'NewsCommentaryByT5Vaswani2017Kocmi2018_1',
    'model_parameter_filepath': root_filepath + "resources/saved_parameters/NewsCommentaryByT5Vaswani2017Kocmi2018_1-1715966141-model.params",
    'datasets_filepath': root_filepath + "resources/parsed_datasets/SMTNewsCommentary/SMTNewsCommentary_parsed-1715949808",
    'output_filepath': root_filepath + "resources/model_translations/NewsCommentaryByT5Vaswani2017Kocmi2018_1.json",
    'model_hyperparameters': {
        'src_vocab_size': 150,
        'tgt_vocab_size': 81,
        'max_src_seq_len': 266,
        'max_tgt_seq_len': 256,
        'd_model': 256,
        'nhead': 8,
        # number of encoders is 3 times that of decoders, following Xue 2021 - ByT5 - Sec 3.1
        'num_encoder_layers': 9,
        'num_decoder_layers': 3,
        'dim_feedforward': 1796,
        'dropout': 0.1,
        'activation': torch.nn.functional.relu,
        'custom_encoder': None,
        'custom_decoder': None,
        'layer_norm_eps': 1e-5,
        'batch_first': True,
        'norm_first': False,
        'bias': True,
        'device': None,
        'dtype': None
    }
}

# 4M Kazakh
NewsCommentaryByT5Vaswani2017Kocmi2018_2 = {
    'runner_hyperparameters_name': 'NewsCommentaryByT5Vaswani2017Kocmi2018_2',
    'model_parameter_filepath': root_filepath + "resources/saved_parameters/NewsCommentaryByT5Vaswani2017Kocmi2018_2-1715965581-model.params",
    'datasets_filepath': root_filepath + "resources/parsed_datasets/SMTNewsCommentary/SMTNewsCommentary_parsed-1715949808",
    'output_filepath': root_filepath + "resources/model_translations/NewsCommentaryByT5Vaswani2017Kocmi2018_2.json",
    'model_hyperparameters': {
        'src_vocab_size': 150,
        'tgt_vocab_size': 81,
        'max_src_seq_len': 266,
        'max_tgt_seq_len': 256,
        'd_model': 128,
        'nhead': 8,
        # number of encoders is 3 times that of decoders, following Xue 2021 - ByT5 - Sec 3.1
        'num_encoder_layers': 9,
        'num_decoder_layers': 3,
        'dim_feedforward': 1024,
        'dropout': 0.1,
        'activation': torch.nn.functional.relu,
        'custom_encoder': None,
        'custom_decoder': None,
        'layer_norm_eps': 1e-5,
        'batch_first': True,
        'norm_first': False,
        'bias': True,
        'device': None,
        'dtype': None
    }
}


class DatasetHolder:

    def __init__(self):
        self.unknown_vocabulary_type = None
        self.padding_vocabulary_type = None
        self.end_of_sequence_type = None
        self.target_vocab = None
        self.target_vocab_array = None
        self.target_vocab_counts = None
        self.source_vocab = None
        self.source_vocab_array = None
        self.source_vocab_counts = None
        self.target_encodings = None
        self.target_encodings_train = None
        self.target_encodings_test = None
        self.source_encodings = None
        self.source_encodings_train = None
        self.source_encodings_test = None
        self.max_src_seq_obs = 0
        self.max_tgt_seq_obs = 0

    def get_unknown_vocabulary_type(self):
        return self.unknown_vocabulary_type

    def set_unknown_vocabulary_type(self, unknown_vocabulary_type):
        self.unknown_vocabulary_type = unknown_vocabulary_type

    def get_padding_vocabulary_type(self):
        return self.padding_vocabulary_type

    def set_padding_vocabulary_type(self, padding_vocabulary_type):
        self.padding_vocabulary_type = padding_vocabulary_type

    def get_end_of_sequence_vocabulary_type(self):
        return self.end_of_sequence_type

    def set_end_of_sequence_vocabulary_type(self, end_of_sequence_type):
        self.end_of_sequence_type = end_of_sequence_type

    def get_target_vocab(self):
        return self.target_vocab

    def set_target_vocab(self, target_vocab):
        self.target_vocab = target_vocab

    def get_target_vocab_numpy(self):
        if self.target_vocab_array is None:
            self.target_vocab_array = np.array(self.target_vocab)
        return self.target_vocab_array

    def get_target_vocab_counts(self):
        return self.target_vocab_counts

    def set_target_vocab_counts(self, target_vocab_counts):
        self.target_vocab_counts = target_vocab_counts

    def get_source_vocab(self):
        return self.source_vocab

    def set_source_vocab(self, source_vocab):
        self.source_vocab = source_vocab

    def get_source_vocab_numpy(self):
        if self.source_vocab_array is None:
            self.source_vocab_array = np.array(self.source_vocab)
        return self.source_vocab_array

    def get_source_vocab_counts(self):
        return self.source_vocab_counts

    def set_source_vocab_counts(self, source_vocab_counts):
        self.source_vocab_counts = source_vocab_counts

    def get_target_encodings(self):
        return self.target_encodings

    def set_target_encodings(self, target_encodings):
        del self.target_encodings
        self.target_encodings = target_encodings
        if is_remote_execution:
            torch.cuda.empty_cache()

    def get_source_encodings(self):
        return self.source_encodings

    def set_source_encodings(self, source_encodings):
        del self.source_encodings
        self.source_encodings = source_encodings
        if is_remote_execution:
            torch.cuda.empty_cache()

    def get_target_encodings_train(self):
        return self.target_encodings_train

    def set_target_encodings_train(self, target_encodings_train):
        del self.target_encodings_train
        self.target_encodings_train = target_encodings_train
        if is_remote_execution:
            torch.cuda.empty_cache()

    def get_source_encodings_train(self):
        return self.source_encodings_train

    def set_source_encodings_train(self, source_encodings_train):
        del self.source_encodings_train
        self.source_encodings_train = source_encodings_train
        if is_remote_execution:
            torch.cuda.empty_cache()

    def get_target_encodings_test(self):
        return self.target_encodings_test

    def set_target_encodings_test(self, target_encodings_test):
        del self.target_encodings_test
        self.target_encodings_test = target_encodings_test
        if is_remote_execution:
            torch.cuda.empty_cache()

    def get_source_encodings_test(self):
        return self.source_encodings_test

    def set_source_encodings_test(self, source_encodings_test):
        del self.source_encodings_test
        self.source_encodings_test = source_encodings_test
        if is_remote_execution:
            torch.cuda.empty_cache()

    def get_max_src_seq_obs(self):
        return self.max_src_seq_obs

    def set_max_src_seq_obs(self, max_src_seq_obs):
        self.max_src_seq_obs = max_src_seq_obs

    def get_max_tgt_seq_obs(self):
        return self.max_tgt_seq_obs

    def set_max_tgt_seq_obs(self, max_tgt_seq_obs):
        self.max_tgt_seq_obs = max_tgt_seq_obs

# class name matches file name
class transformer_vaswani2017(torch.nn.Transformer):

    def __init__(self,
                 model_hyperparameters):
        super().__init__(
            d_model=model_hyperparameters['d_model'],
            nhead=model_hyperparameters['nhead'],
            num_encoder_layers=model_hyperparameters['num_encoder_layers'],
            num_decoder_layers=model_hyperparameters['num_decoder_layers'],
            dim_feedforward=model_hyperparameters['dim_feedforward'],
            dropout=model_hyperparameters['dropout'],
            activation=model_hyperparameters['activation'],
            custom_encoder=model_hyperparameters['custom_encoder'],
            custom_decoder=model_hyperparameters['custom_decoder'],
            layer_norm_eps=model_hyperparameters['layer_norm_eps'],
            batch_first=model_hyperparameters['batch_first'],
            norm_first=model_hyperparameters['norm_first'],
            bias=model_hyperparameters['bias'],
            device=model_hyperparameters['device'],
            dtype=model_hyperparameters['dtype']
        )
        self.model_hyperparameters = model_hyperparameters
        # add one for the end of sequence token
        self.max_src_seq_len = model_hyperparameters['max_src_seq_len'] + 1
        self.max_tgt_seq_len = model_hyperparameters['max_tgt_seq_len'] + 1
        self.src_embeddings = torch.nn.Embedding(
            model_hyperparameters['src_vocab_size'],
            model_hyperparameters['d_model']
        )
        self.tgt_embeddings = torch.nn.Embedding(
            model_hyperparameters['tgt_vocab_size'],
            model_hyperparameters['d_model']
        )
        self.src_pos_enc = torch.nn.Embedding(
            self.max_src_seq_len,
            model_hyperparameters['d_model']
        ).requires_grad_(False)
        self.tgt_pos_enc = torch.nn.Embedding(
            self.max_tgt_seq_len,
            model_hyperparameters['d_model']
        ).requires_grad_(False)
        self.linear_output_projection_1 = torch.nn.Linear(
            self.max_tgt_seq_len,
            1,
            bias=False
        )
        self.linear_output_projection_2 = torch.nn.Linear(
            model_hyperparameters['d_model'],
            model_hyperparameters['tgt_vocab_size'],
            bias=False
        )
        self.logsoftmax_output = torch.nn.LogSoftmax(dim=1)
        self.model_hyperparameters = model_hyperparameters
        self.tgt_mask_cache = {}
        for i in range(0, self.max_tgt_seq_len + 1):
            tgt_mask = self.generate_square_subsequent_mask(i)
            if is_remote_execution:
                self.tgt_mask_cache[i] = tgt_mask.to(device="cuda")
            self.tgt_mask_cache[i] = tgt_mask
        self.indices_cache = {}
        for i in range(0, max([self.max_src_seq_len, self.max_tgt_seq_len]) + 1):
            indices = torch.tensor(np.arange(0, i), dtype=torch.long)
            if is_remote_execution:
                indices = indices.to(device="cuda")
            self.indices_cache[i] = indices

    def forward(self,
                src: torch.Tensor,
                tgt: torch.Tensor,
                src_mask: Optional[torch.Tensor] = None,
                tgt_mask: Optional[torch.Tensor] = None,
                memory_mask: Optional[torch.Tensor] = None,
                src_key_padding_mask: Optional[torch.Tensor] = None,
                tgt_key_padding_mask: Optional[torch.Tensor] = None,
                memory_key_padding_mask: Optional[torch.Tensor] = None,
                src_is_causal: Optional[bool] = None,
                tgt_is_causal: Optional[bool] = True,
                memory_is_causal: bool = False) -> torch.Tensor:
        if len(src.shape) == 1:
            src = src.unsqueeze(dim=0)
        if len(tgt.shape) == 1:
            tgt = tgt.unsqueeze(dim=0)
        src_embedding_pos_enc = self.src_embeddings(src) + self.src_pos_enc(self.indices_cache[src.shape[1]])
        tgt_embedding_pos_enc = self.tgt_embeddings(tgt) + self.tgt_pos_enc(self.indices_cache[tgt.shape[1]])
        tgt_mask = self.tgt_mask_cache[tgt.shape[1]]
        transformer_output = super().forward(src_embedding_pos_enc, tgt_embedding_pos_enc, src_mask,
                                             tgt_mask, memory_mask, src_key_padding_mask,
                                             tgt_key_padding_mask, memory_key_padding_mask,
                                             src_is_causal, tgt_is_causal, memory_is_causal)
        transformer_output = torch.swapaxes(transformer_output, -1, -2)
        transformer_output = torch.nn.functional.pad(
            transformer_output,
            (0, self.max_tgt_seq_len - transformer_output.shape[2]),
            value=0
        )
        output = self.logsoftmax_output(
            self.linear_output_projection_2(
                torch.squeeze(
                    self.linear_output_projection_1(
                        transformer_output
                    ),
                    dim=2
                )
            )
        )
        del src_embedding_pos_enc
        del tgt_embedding_pos_enc
        del transformer_output
        return output

    def freeze_target_embeddings(self):
        del self.tgt_embeddings
        self.tgt_embeddings = torch.nn.Embedding(
            self.model_hyperparameters['tgt_vocab_size'],
            self.model_hyperparameters['d_model']
        ).requires_grad_(False)
        del self.linear_output_projection_1
        self.linear_output_projection_1 = torch.nn.Linear(
            self.max_tgt_seq_len,
            1,
            bias=False
        ).requires_grad_(False)
        del self.linear_output_projection_2
        self.linear_output_projection_2 = torch.nn.Linear(
            self.model_hyperparameters['d_model'],
            self.model_hyperparameters['tgt_vocab_size'],
            bias=False
        ).requires_grad_(False)

    def set_source_embeddings_for_transfer_learning(self, source_embeddings_dim):
        del self.src_embeddings
        self.src_embeddings = torch.nn.Embedding(
            source_embeddings_dim,
            self.model_hyperparameters['d_model']
        )


class Runner:

    def __init__(self):
        self.runner_hyperparameters = SETimesByT5Vaswani2017Kocmi2018_0
        self.model_hyperparameters = self.runner_hyperparameters['model_hyperparameters']
        self.runner_hyperparameters_name = self.runner_hyperparameters['runner_hyperparameters_name']
        self.model_parameter_filepath = self.runner_hyperparameters['model_parameter_filepath']
        self.datasets_filepath = self.runner_hyperparameters['datasets_filepath']
        self.output_filepath = self.runner_hyperparameters['output_filepath']
        self.max_target_sequence_length = self.runner_hyperparameters['model_hyperparameters']['max_tgt_seq_len']
        self.dataset_holder: DatasetHolder = None
        self.model = None
        print(f"Initialized runner {self.runner_hyperparameters_name} with parameters {self.runner_hyperparameters}")

    def load_dataset(self):
        self.dataset_holder = torch.load(self.datasets_filepath)

    def load_model(self):
        self.model = transformer_vaswani2017(model_hyperparameters=self.model_hyperparameters)
        self.model.freeze_target_embeddings()
        if is_remote_execution:
            model_parameters = torch.load(self.model_parameter_filepath, map_location=torch.device('cuda'))
        else:
            model_parameters = torch.load(self.model_parameter_filepath, map_location=torch.device('cpu'))
        self.model.load_state_dict(model_parameters)
        if is_remote_execution:
            self.model.cuda()
        self.model.eval()

    def evaluate_model(self):
        outputs = list()
        source_vocab_numpy = self.dataset_holder.get_source_vocab_numpy()
        target_vocab_numpy = self.dataset_holder.get_target_vocab_numpy()
        assert len(self.dataset_holder.get_source_encodings_test()) == len(self.dataset_holder.get_target_encodings_test())
        for i in range(0, len(self.dataset_holder.get_source_encodings_test())):
            if is_remote_execution:
                source_encoding = self.dataset_holder.get_source_encodings_test()[i].to(device="cuda")
                target_encoding = self.dataset_holder.get_target_encodings_test()[i].to(device="cuda")
            else:
                source_encoding = self.dataset_holder.get_source_encodings_test()[i].to(device="cpu")
                target_encoding = self.dataset_holder.get_target_encodings_test()[i].to(device="cpu")
            j = 0
            end_of_sequence = False
            while j < self.model_hyperparameters['max_tgt_seq_len'] and end_of_sequence == False:
                target_encoding_slice = torch.tensor_split(target_encoding, [j], dim=0)
                output_logits = self.model.forward(
                    source_encoding,
                    target_encoding_slice[0]
                ).detach().to(device="cpu").flatten().numpy()
                output_logits_sort_pairs = list()
                for k in range(0, len(output_logits)):
                    output_logits_sort_pairs.append([output_logits[k], k])
                output_logits_sorted = sorted(output_logits_sort_pairs, key=lambda logit_pair: logit_pair[0], reverse=True)
                output_sort_index = 0
                # don't pick mark up characters or whitespace if first term
                if j == 0:
                    while output_logits_sorted[output_sort_index][1] in (0, 1, 2, 7):
                        output_sort_index = output_sort_index + 1
                else:
                    # don't repeat unknown, padding, or spaces
                    if (prediction_encoding[j-1] == 0
                            or prediction_encoding[j-1] == 1
                            or prediction_encoding[j-1] == 7):
                        while (output_logits_sorted[output_sort_index][1] == 0
                               or output_logits_sorted[output_sort_index][1] == 1
                               or output_logits_sorted[output_sort_index][1] == 7):
                            output_sort_index = output_sort_index + 1
                output_vocab_index = output_logits_sorted[output_sort_index][1]
                # index = output_vocab_index # always outputs "Krrrr...<eos>"
                index = min(random.randint(output_vocab_index, output_vocab_index + 3), len(output_logits_sorted))
                if j == 0:
                    prediction_encoding = torch.tensor([output_logits_sorted[index][1]], dtype=torch.float)
                else:
                    prediction_encoding = torch.cat([prediction_encoding, torch.tensor([output_logits_sorted[index][1]], dtype=torch.float)])
                if prediction_encoding[j] == self.dataset_holder.get_target_vocab().index(
                        self.dataset_holder.get_end_of_sequence_vocabulary_type()):
                    end_of_sequence = True
                j = j + 1
            decoded_source = np.take(source_vocab_numpy, source_encoding.detach().to(device="cpu").flatten().numpy())
            decoded_target = np.take(target_vocab_numpy, target_encoding.detach().to(device="cpu").flatten().numpy())
            decoded_translation = np.take(target_vocab_numpy, prediction_encoding.detach().to(device="cpu", dtype=torch.int32).numpy())
            outputs.append({
                "source": "".join(decoded_source.tolist()),
                "target": "".join(decoded_target.tolist()),
                "translation": "".join(decoded_translation.tolist())
            })
            del source_encoding
            del target_encoding
            del prediction_encoding
            del target_encoding_slice
            del decoded_source
            del decoded_target
            del decoded_translation
            print(f"Completed translation {i} of {len(self.dataset_holder.get_source_encodings_test())} at {time.time()}")
            if is_remote_execution:
                torch.cuda.empty_cache()
                if i % 100 == 0:
                    print(f"Memory usage summary:")
                    print(f"{torch.cuda.memory_summary()}")
                    torch.cuda.reset_max_memory_allocated()
                    torch.cuda.reset_max_memory_cached()
                    torch.cuda.reset_peak_memory_stats()
            if i % 100 == 0 or i == len(self.dataset_holder.get_source_encodings_test()) - 1:
                print(f"Translation{i}: {outputs[i]}")
                output_file = open(self.output_filepath, "w")
                output_file.write(json.dumps(outputs, ensure_ascii=False, indent=1))
                output_file.close()


runner = Runner()
runner.load_dataset()
runner.load_model()
runner.evaluate_model()
# Out:
# Mounted at /content/drive
# Initialized runner SETimesByT5Vaswani2017Kocmi2018_0 with parameters {'runner_hyperparameters_name': 'SETimesByT5Vaswani2017Kocmi2018_0', 'model_parameter_filepath': '/content/drive/MyDrive/CS685-NLP-GroupProject/Code/singleNotebookFromPythonFilesStructure/resources/saved_parameters/SETimesByT5Vaswani2017Kocmi2018_0-1715937924-model.params', 'datasets_filepath': '/content/drive/MyDrive/CS685-NLP-GroupProject/Code/singleNotebookFromPythonFilesStructure/resources/parsed_datasets/setimes/setimes_parsed-1715586293', 'output_filepath': '/content/drive/MyDrive/CS685-NLP-GroupProject/Code/singleNotebookFromPythonFilesStructure/resources/model_translations/SETimesByT5Vaswani2017Kocmi2018_0.json', 'model_hyperparameters': {'src_vocab_size': 91, 'tgt_vocab_size': 81, 'max_src_seq_len': 266, 'max_tgt_seq_len': 256, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 9, 'num_decoder_layers': 3, 'dim_feedforward': 2048, 'dropout': 0.1, 'activation': <function relu at 0x7bdd74037be0>, 'custom_encoder': None, 'custom_decoder': None, 'layer_norm_eps': 1e-05, 'batch_first': True, 'norm_first': False, 'bias': True, 'device': None, 'dtype': None}}
# Completed translation 0 of 9084 at 1715994630.7813418
# Memory usage summary:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |  74184 KiB | 131380 KiB |  19242 MiB |  19170 MiB |
# |       from large pool |  57472 KiB |  98304 KiB |    104 MiB |     48 MiB |
# |       from small pool |  16712 KiB |  33076 KiB |  19138 MiB |  19122 MiB |
# |---------------------------------------------------------------------------|
# | Active memory         |  74184 KiB | 131380 KiB |  19242 MiB |  19170 MiB |
# |       from large pool |  57472 KiB |  98304 KiB |    104 MiB |     48 MiB |
# |       from small pool |  16712 KiB |  33076 KiB |  19138 MiB |  19122 MiB |
# |---------------------------------------------------------------------------|
# | Requested memory      |  74115 KiB | 131311 KiB |  19237 MiB |  19165 MiB |
# |       from large pool |  57472 KiB |  98304 KiB |    104 MiB |     48 MiB |
# |       from small pool |  16643 KiB |  33007 KiB |  19133 MiB |  19117 MiB |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   | 106496 KiB | 137216 KiB | 137216 KiB |  30720 KiB |
# |       from large pool |  81920 KiB | 102400 KiB | 102400 KiB |  20480 KiB |
# |       from small pool |  24576 KiB |  34816 KiB |  34816 KiB |  10240 KiB |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |  32312 KiB |  34358 KiB |  20464 MiB |  20433 MiB |
# |       from large pool |  24448 KiB |  24448 KiB |    145 MiB |    122 MiB |
# |       from small pool |   7864 KiB |   9910 KiB |  20318 MiB |  20311 MiB |
# |---------------------------------------------------------------------------|
# | Allocations           |     440    |     620    |   76295    |   75855    |
# |       from large pool |      25    |      48    |      49    |      24    |
# |       from small pool |     415    |     595    |   76246    |   75831    |
# |---------------------------------------------------------------------------|
# | Active allocs         |     440    |     620    |   76295    |   75855    |
# |       from large pool |      25    |      48    |      49    |      24    |
# |       from small pool |     415    |     595    |   76246    |   75831    |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |      16    |      22    |      22    |       6    |
# |       from large pool |       4    |       5    |       5    |       1    |
# |       from small pool |      12    |      17    |      17    |       5    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |      11    |      19    |   31194    |   31183    |
# |       from large pool |       3    |       3    |       9    |       6    |
# |       from small pool |       8    |      16    |   31185    |   31177    |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|
#
# Translation0: {'source': "Kosova'da beş belediyede seçimler tekrarlanacakĢ", 'target': 'Five Kosovo municipalities to repeat electionĢ', 'translation': ''}
# /usr/local/lib/python3.10/dist-packages/torch/cuda/memory.py:330: FutureWarning: torch.cuda.reset_max_memory_allocated now calls torch.cuda.reset_peak_memory_stats, which resets /all/ peak memory stats.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/cuda/memory.py:356: FutureWarning: torch.cuda.reset_max_memory_cached now calls torch.cuda.reset_peak_memory_stats, which resets /all/ peak memory stats.
#   warnings.warn(
# Streaming output truncated to the last 5000 lines.
# |       from large pool |  57472 KiB |  57472 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16643 KiB |  29285 KiB |   1912 GiB |   1912 GiB |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   | 106496 KiB | 112640 KiB | 727040 KiB | 620544 KiB |
# |       from large pool |  81920 KiB |  81920 KiB | 102400 KiB |  20480 KiB |
# |       from small pool |  24576 KiB |  30720 KiB | 624640 KiB | 600064 KiB |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |  32312 KiB |  36359 KiB |   1988 GiB |   1987 GiB |
# |       from large pool |  24448 KiB |  24448 KiB |      0 GiB |      0 GiB |
# |       from small pool |   7864 KiB |  11911 KiB |   1987 GiB |   1987 GiB |
# |---------------------------------------------------------------------------|
# | Allocations           |     440    |     622    |    7618 K  |    7618 K  |
# |       from large pool |      25    |      25    |       0 K  |       0 K  |
# |       from small pool |     415    |     597    |    7618 K  |    7618 K  |
# |---------------------------------------------------------------------------|
# | Active allocs         |     440    |     622    |    7618 K  |    7618 K  |
# |       from large pool |      25    |      25    |       0 K  |       0 K  |
# |       from small pool |     415    |     597    |    7618 K  |    7618 K  |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |      16    |      19    |     310    |     294    |
# |       from large pool |       4    |       4    |       5    |       1    |
# |       from small pool |      12    |      15    |     305    |     293    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |      11    |      25    |    3109 K  |    3109 K  |
# |       from large pool |       3    |       3    |       0 K  |       0 K  |
# |       from small pool |       8    |      22    |    3109 K  |    3109 K  |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|
#
# Translation100: {'source': "Prentiç hakkında Kosova'da tutuklama emri bulunuyor.Ģ", 'target': 'Prentic had been under an arrest warrant in Kosovo.Ģ', 'translation': ''}
# Completed translation 101 of 9084 at 1715994903.3317335
# Completed translation 102 of 9084 at 1715994906.0790741
# Completed translation 103 of 9084 at 1715994908.779539
# Completed translation 104 of 9084 at 1715994911.4564497
# Completed translation 105 of 9084 at 1715994914.117194
# Completed translation 106 of 9084 at 1715994916.8215845
# Completed translation 107 of 9084 at 1715994919.5127618
# Completed translation 108 of 9084 at 1715994922.1853707
# Completed translation 109 of 9084 at 1715994924.8610077
# Completed translation 110 of 9084 at 1715994927.5687072
# Completed translation 111 of 9084 at 1715994930.2714207
# Completed translation 112 of 9084 at 1715994932.9744086
# Completed translation 113 of 9084 at 1715994935.660313
# Completed translation 114 of 9084 at 1715994938.3535106
# Completed translation 115 of 9084 at 1715994941.104278
# Completed translation 116 of 9084 at 1715994943.7812264
# Completed translation 117 of 9084 at 1715994946.4772112
# Completed translation 118 of 9084 at 1715994949.1655777
# Completed translation 119 of 9084 at 1715994951.8653178
# Completed translation 120 of 9084 at 1715994954.6168606
# Completed translation 121 of 9084 at 1715994957.3242843
# Completed translation 122 of 9084 at 1715994960.0099952
# Completed translation 123 of 9084 at 1715994962.6935844
# Completed translation 124 of 9084 at 1715994965.4897168
# Completed translation 125 of 9084 at 1715994968.1977396
# Completed translation 126 of 9084 at 1715994970.8785827
# Completed translation 127 of 9084 at 1715994973.5924242
# Completed translation 128 of 9084 at 1715994976.2994256
# Completed translation 129 of 9084 at 1715994979.0429592
# Completed translation 130 of 9084 at 1715994981.7291656
# Completed translation 131 of 9084 at 1715994984.412315
# Completed translation 132 of 9084 at 1715994987.0822585
# Completed translation 133 of 9084 at 1715994989.8021803
# Completed translation 134 of 9084 at 1715994992.5156918
# Completed translation 135 of 9084 at 1715994995.1922822
# Completed translation 136 of 9084 at 1715994997.870257
# Completed translation 137 of 9084 at 1715995000.5946424
# Completed translation 138 of 9084 at 1715995003.2703695
# Completed translation 139 of 9084 at 1715995005.9606962
# Completed translation 140 of 9084 at 1715995008.6396127
# Completed translation 141 of 9084 at 1715995011.3237853
# Completed translation 142 of 9084 at 1715995014.0222588
# Completed translation 143 of 9084 at 1715995016.6872475
# Completed translation 144 of 9084 at 1715995019.3436081
# Completed translation 145 of 9084 at 1715995022.013883
# Completed translation 146 of 9084 at 1715995024.7145913
# Completed translation 147 of 9084 at 1715995027.4777555
# Completed translation 148 of 9084 at 1715995030.1703134
# Completed translation 149 of 9084 at 1715995032.8414512
# Completed translation 150 of 9084 at 1715995035.5205724
# Completed translation 151 of 9084 at 1715995038.2340496
# Completed translation 152 of 9084 at 1715995040.9275458
# Completed translation 153 of 9084 at 1715995043.6186187
# Completed translation 154 of 9084 at 1715995046.2889454
# Completed translation 155 of 9084 at 1715995048.967115
# Completed translation 156 of 9084 at 1715995051.7128286
# Completed translation 157 of 9084 at 1715995054.3932924
# Completed translation 158 of 9084 at 1715995057.0707805
# Completed translation 159 of 9084 at 1715995059.741678
# Completed translation 160 of 9084 at 1715995062.491633
# Completed translation 161 of 9084 at 1715995065.1766796
# Completed translation 162 of 9084 at 1715995067.854173
# Completed translation 163 of 9084 at 1715995070.5203815
# Completed translation 164 of 9084 at 1715995073.217627
# Completed translation 165 of 9084 at 1715995075.9085925
# Completed translation 166 of 9084 at 1715995078.5896988
# Completed translation 167 of 9084 at 1715995081.2462978
# Completed translation 168 of 9084 at 1715995083.905158
# Completed translation 169 of 9084 at 1715995086.620314
# Completed translation 170 of 9084 at 1715995089.305983
# Completed translation 171 of 9084 at 1715995091.986832
# Completed translation 172 of 9084 at 1715995094.6636992
# Completed translation 173 of 9084 at 1715995097.3508477
# Completed translation 174 of 9084 at 1715995100.0768642
# Completed translation 175 of 9084 at 1715995102.7371192
# Completed translation 176 of 9084 at 1715995105.3969007
# Completed translation 177 of 9084 at 1715995108.0538008
# Completed translation 178 of 9084 at 1715995110.729898
# Completed translation 179 of 9084 at 1715995113.4305034
# Completed translation 180 of 9084 at 1715995116.0975244
# Completed translation 181 of 9084 at 1715995118.748655
# Completed translation 182 of 9084 at 1715995121.4224973
# Completed translation 183 of 9084 at 1715995124.154281
# Completed translation 184 of 9084 at 1715995126.8477626
# Completed translation 185 of 9084 at 1715995129.5167005
# Completed translation 186 of 9084 at 1715995132.1886108
# Completed translation 187 of 9084 at 1715995134.8994944
# Completed translation 188 of 9084 at 1715995137.6185443
# Completed translation 189 of 9084 at 1715995140.304572
# Completed translation 190 of 9084 at 1715995142.9704368
# Completed translation 191 of 9084 at 1715995145.651859
# Completed translation 192 of 9084 at 1715995148.4191825
# Completed translation 193 of 9084 at 1715995151.1099284
# Completed translation 194 of 9084 at 1715995153.7931886
# Completed translation 195 of 9084 at 1715995156.4555058
# Completed translation 196 of 9084 at 1715995159.1585965
# Completed translation 197 of 9084 at 1715995161.8726377
# Completed translation 198 of 9084 at 1715995164.5583527
# Completed translation 199 of 9084 at 1715995167.2306337
# Completed translation 200 of 9084 at 1715995169.9120708
# Memory usage summary:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |  74184 KiB |  87570 KiB |   3841 GiB |   3841 GiB |
# |       from large pool |  57472 KiB |  57472 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16712 KiB |  30098 KiB |   3841 GiB |   3841 GiB |
# |---------------------------------------------------------------------------|
# | Active memory         |  74184 KiB |  87570 KiB |   3841 GiB |   3841 GiB |
# |       from large pool |  57472 KiB |  57472 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16712 KiB |  30098 KiB |   3841 GiB |   3841 GiB |
# |---------------------------------------------------------------------------|
# | Requested memory      |  74115 KiB |  87486 KiB |   3840 GiB |   3840 GiB |
# |       from large pool |  57472 KiB |  57472 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16643 KiB |  30014 KiB |   3840 GiB |   3840 GiB |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   | 106496 KiB | 114688 KiB |   1316 MiB |   1212 MiB |
# |       from large pool |  81920 KiB |  81920 KiB |    100 MiB |     20 MiB |
# |       from small pool |  24576 KiB |  32768 KiB |   1216 MiB |   1192 MiB |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |  32312 KiB |  36378 KiB |   4009 GiB |   4009 GiB |
# |       from large pool |  24448 KiB |  24448 KiB |      0 GiB |      0 GiB |
# |       from small pool |   7864 KiB |  11930 KiB |   4009 GiB |   4009 GiB |
# |---------------------------------------------------------------------------|
# | Allocations           |     440    |     622    |   15161 K  |   15161 K  |
# |       from large pool |      25    |      25    |       0 K  |       0 K  |
# |       from small pool |     415    |     597    |   15161 K  |   15161 K  |
# |---------------------------------------------------------------------------|
# | Active allocs         |     440    |     622    |   15161 K  |   15161 K  |
# |       from large pool |      25    |      25    |       0 K  |       0 K  |
# |       from small pool |     415    |     597    |   15161 K  |   15161 K  |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |      16    |      20    |     613    |     597    |
# |       from large pool |       4    |       4    |       5    |       1    |
# |       from small pool |      12    |      16    |     608    |     596    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |      11    |      26    |    6247 K  |    6247 K  |
# |       from large pool |       3    |       3    |       0 K  |       0 K  |
# |       from small pool |       8    |      23    |    6247 K  |    6247 K  |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|
#
# Translation200: {'source': 'İkinci Ekonomi Forumunda bölgesel fırsatlara değinildiĢ', 'target': 'Second Economic Forum highlights regional opportunitiesĢ', 'translation': ''}
# Completed translation 201 of 9084 at 1715995172.6437743
# Completed translation 202 of 9084 at 1715995175.3261604
# Completed translation 203 of 9084 at 1715995178.0079358
# Completed translation 204 of 9084 at 1715995180.6766589
# Completed translation 205 of 9084 at 1715995183.3388925
# Completed translation 206 of 9084 at 1715995185.9966972
# Completed translation 207 of 9084 at 1715995188.6647866
# Completed translation 208 of 9084 at 1715995191.3274446
# Completed translation 209 of 9084 at 1715995193.9852607
# Completed translation 210 of 9084 at 1715995196.69255
# Completed translation 211 of 9084 at 1715995199.387386
# Completed translation 212 of 9084 at 1715995202.0612247
# Completed translation 213 of 9084 at 1715995204.7351363
# Completed translation 214 of 9084 at 1715995207.40534
# Completed translation 215 of 9084 at 1715995210.0924573
# Completed translation 216 of 9084 at 1715995212.756247
# Completed translation 217 of 9084 at 1715995215.438475
# Completed translation 218 of 9084 at 1715995218.0955403
# Completed translation 219 of 9084 at 1715995220.7949693
# Completed translation 220 of 9084 at 1715995223.485509
# Completed translation 221 of 9084 at 1715995226.1614528
# Completed translation 222 of 9084 at 1715995228.8269727
# Completed translation 223 of 9084 at 1715995231.507894
# Completed translation 224 of 9084 at 1715995234.203057
# Completed translation 225 of 9084 at 1715995236.8740351
# Completed translation 226 of 9084 at 1715995239.5497074
# Completed translation 227 of 9084 at 1715995242.2206054
# Completed translation 228 of 9084 at 1715995244.8927386
# Completed translation 229 of 9084 at 1715995247.6070876
# Completed translation 230 of 9084 at 1715995250.2754934
# Completed translation 231 of 9084 at 1715995252.9307587
# Completed translation 232 of 9084 at 1715995255.5915256
# Completed translation 233 of 9084 at 1715995258.3474524
# Completed translation 234 of 9084 at 1715995261.0456345
# Completed translation 235 of 9084 at 1715995263.7498636
# Completed translation 236 of 9084 at 1715995266.4299047
# Completed translation 237 of 9084 at 1715995269.1536944
# Completed translation 238 of 9084 at 1715995271.887851
# Completed translation 239 of 9084 at 1715995274.5866373
# Completed translation 240 of 9084 at 1715995277.284697
# Completed translation 241 of 9084 at 1715995279.9688272
# Completed translation 242 of 9084 at 1715995282.7496114
# Completed translation 243 of 9084 at 1715995285.4277701
# Completed translation 244 of 9084 at 1715995288.1154625
# Completed translation 245 of 9084 at 1715995290.7718582
# Completed translation 246 of 9084 at 1715995293.4664469
# Completed translation 247 of 9084 at 1715995296.136009
# Completed translation 248 of 9084 at 1715995298.8183799
# Completed translation 249 of 9084 at 1715995301.4794464
# Completed translation 250 of 9084 at 1715995304.142594
# Completed translation 251 of 9084 at 1715995306.8402162
# Completed translation 252 of 9084 at 1715995309.5170364
# Completed translation 253 of 9084 at 1715995312.1891024
# Completed translation 254 of 9084 at 1715995314.8569205
# Completed translation 255 of 9084 at 1715995317.5545208
# Completed translation 256 of 9084 at 1715995320.264894
# Completed translation 257 of 9084 at 1715995322.9470782
# Completed translation 258 of 9084 at 1715995325.6317275
# Completed translation 259 of 9084 at 1715995328.3083975
# Completed translation 260 of 9084 at 1715995331.0664568
# Completed translation 261 of 9084 at 1715995333.7668555
# Completed translation 262 of 9084 at 1715995336.4606957
# Completed translation 263 of 9084 at 1715995339.1258302
# Completed translation 264 of 9084 at 1715995341.8478515
# Completed translation 265 of 9084 at 1715995344.5589256
# Completed translation 266 of 9084 at 1715995347.2424693
# Completed translation 267 of 9084 at 1715995349.931985
# Completed translation 268 of 9084 at 1715995352.5978866
# Completed translation 269 of 9084 at 1715995355.359307
# Completed translation 270 of 9084 at 1715995358.0432525
# Completed translation 271 of 9084 at 1715995360.7171507
# Completed translation 272 of 9084 at 1715995363.387733
# Completed translation 273 of 9084 at 1715995366.092118
# Completed translation 274 of 9084 at 1715995368.812741
# Completed translation 275 of 9084 at 1715995371.487766
# Completed translation 276 of 9084 at 1715995374.1675792
# Completed translation 277 of 9084 at 1715995376.8393865
# Completed translation 278 of 9084 at 1715995379.6551101
# Completed translation 279 of 9084 at 1715995382.342556
# Completed translation 280 of 9084 at 1715995385.019167
# Completed translation 281 of 9084 at 1715995387.6969726
# Completed translation 282 of 9084 at 1715995390.4052963
# Completed translation 283 of 9084 at 1715995393.1440585
# Completed translation 284 of 9084 at 1715995395.8538206
# Completed translation 285 of 9084 at 1715995398.5454574
# Completed translation 286 of 9084 at 1715995401.2351623
# Completed translation 287 of 9084 at 1715995404.0182278
# Completed translation 288 of 9084 at 1715995406.7264342
# Completed translation 289 of 9084 at 1715995409.3903415
# Completed translation 290 of 9084 at 1715995412.069139
# Completed translation 291 of 9084 at 1715995414.7734642
# Completed translation 292 of 9084 at 1715995417.4795902
# Completed translation 293 of 9084 at 1715995420.1600764
# Completed translation 294 of 9084 at 1715995422.840332
# Completed translation 295 of 9084 at 1715995425.5174277
# Completed translation 296 of 9084 at 1715995428.1992934
# Completed translation 297 of 9084 at 1715995430.8813922
# Completed translation 298 of 9084 at 1715995433.5525582
# Completed translation 299 of 9084 at 1715995436.2148688
# Completed translation 300 of 9084 at 1715995438.8900254
# Memory usage summary:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |  74184 KiB |  88371 KiB |   5792 GiB |   5792 GiB |
# |       from large pool |  57472 KiB |  57472 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16712 KiB |  30899 KiB |   5792 GiB |   5792 GiB |
# |---------------------------------------------------------------------------|
# | Active memory         |  74184 KiB |  88371 KiB |   5792 GiB |   5792 GiB |
# |       from large pool |  57472 KiB |  57472 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16712 KiB |  30899 KiB |   5792 GiB |   5792 GiB |
# |---------------------------------------------------------------------------|
# | Requested memory      |  74115 KiB |  88288 KiB |   5791 GiB |   5791 GiB |
# |       from large pool |  57472 KiB |  57472 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16643 KiB |  30816 KiB |   5791 GiB |   5791 GiB |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   | 106496 KiB | 114688 KiB |   2010 MiB |   1906 MiB |
# |       from large pool |  81920 KiB |  81920 KiB |    100 MiB |     20 MiB |
# |       from small pool |  24576 KiB |  32768 KiB |   1910 MiB |   1886 MiB |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |  32312 KiB |  38007 KiB |   6058 GiB |   6058 GiB |
# |       from large pool |  24448 KiB |  24448 KiB |      0 GiB |      0 GiB |
# |       from small pool |   7864 KiB |  13559 KiB |   6058 GiB |   6058 GiB |
# |---------------------------------------------------------------------------|
# | Allocations           |     440    |     622    |   22704 K  |   22703 K  |
# |       from large pool |      25    |      25    |       0 K  |       0 K  |
# |       from small pool |     415    |     597    |   22704 K  |   22703 K  |
# |---------------------------------------------------------------------------|
# | Active allocs         |     440    |     622    |   22704 K  |   22703 K  |
# |       from large pool |      25    |      25    |       0 K  |       0 K  |
# |       from small pool |     415    |     597    |   22704 K  |   22703 K  |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |      16    |      20    |     960    |     944    |
# |       from large pool |       4    |       4    |       5    |       1    |
# |       from small pool |      12    |      16    |     955    |     943    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |      11    |      25    |    9419 K  |    9419 K  |
# |       from large pool |       3    |       3    |       0 K  |       0 K  |
# |       from small pool |       8    |      22    |    9419 K  |    9419 K  |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|
#
# Translation300: {'source': 'Fuara 46 ülkeden binlerce katılımcı ilgi gösterdi.Ģ', 'target': 'The expo attracted thousands of participants from 46 countries.Ģ', 'translation': ''}
# Completed translation 301 of 9084 at 1715995441.6072714
# Completed translation 302 of 9084 at 1715995444.3247604
# Completed translation 303 of 9084 at 1715995447.0319233
# Completed translation 304 of 9084 at 1715995449.7032676
# Completed translation 305 of 9084 at 1715995452.420532
# Completed translation 306 of 9084 at 1715995455.1274538
# Completed translation 307 of 9084 at 1715995457.8163664
# Completed translation 308 of 9084 at 1715995460.4839547
# Completed translation 309 of 9084 at 1715995463.1474721
# Completed translation 310 of 9084 at 1715995465.8535283
# Completed translation 311 of 9084 at 1715995468.5454476
# Completed translation 312 of 9084 at 1715995471.2293544
# Completed translation 313 of 9084 at 1715995473.8962686
# Completed translation 314 of 9084 at 1715995476.6265194
# Completed translation 315 of 9084 at 1715995479.3192503
# Completed translation 316 of 9084 at 1715995482.0047078
# Completed translation 317 of 9084 at 1715995484.6854022
# Completed translation 318 of 9084 at 1715995487.3762164
# Completed translation 319 of 9084 at 1715995490.087663
# Completed translation 320 of 9084 at 1715995492.7585726
# Completed translation 321 of 9084 at 1715995495.4671824
# Completed translation 322 of 9084 at 1715995498.151765
# Completed translation 323 of 9084 at 1715995500.860342
# Completed translation 324 of 9084 at 1715995503.5745084
# Completed translation 325 of 9084 at 1715995506.2698522
# Completed translation 326 of 9084 at 1715995508.9665928
# Completed translation 327 of 9084 at 1715995511.6158834
# Completed translation 328 of 9084 at 1715995514.3057837
# Completed translation 329 of 9084 at 1715995516.998475
# Completed translation 330 of 9084 at 1715995519.6868918
# Completed translation 331 of 9084 at 1715995522.3543355
# Completed translation 332 of 9084 at 1715995525.0454507
# Completed translation 333 of 9084 at 1715995527.7416942
# Completed translation 334 of 9084 at 1715995530.4191506
# Completed translation 335 of 9084 at 1715995533.1010158
# Completed translation 336 of 9084 at 1715995535.7781863
# Completed translation 337 of 9084 at 1715995538.5065174
# Completed translation 338 of 9084 at 1715995541.204509
# Completed translation 339 of 9084 at 1715995543.8625987
# Completed translation 340 of 9084 at 1715995546.5227106
# Completed translation 341 of 9084 at 1715995549.189562
# Completed translation 342 of 9084 at 1715995551.8877983
# Completed translation 343 of 9084 at 1715995554.5903628
# Completed translation 344 of 9084 at 1715995557.2874966
# Completed translation 345 of 9084 at 1715995559.9418166
# Completed translation 346 of 9084 at 1715995562.6166003
# Completed translation 347 of 9084 at 1715995565.3104377
# Completed translation 348 of 9084 at 1715995567.9973466
# Completed translation 349 of 9084 at 1715995570.6630669
# Completed translation 350 of 9084 at 1715995573.3485885
# Completed translation 351 of 9084 at 1715995576.048136
# Completed translation 352 of 9084 at 1715995578.7322574
# Completed translation 353 of 9084 at 1715995581.410613
# Completed translation 354 of 9084 at 1715995584.0817618
# Completed translation 355 of 9084 at 1715995586.774536
# Completed translation 356 of 9084 at 1715995589.4717178
# Completed translation 357 of 9084 at 1715995592.1458583
# Completed translation 358 of 9084 at 1715995594.8289251
# Completed translation 359 of 9084 at 1715995597.5246675
# Completed translation 360 of 9084 at 1715995600.3213656
# Completed translation 361 of 9084 at 1715995603.035359
# Completed translation 362 of 9084 at 1715995605.7349923
# Completed translation 363 of 9084 at 1715995608.4105403
# Completed translation 364 of 9084 at 1715995611.1265502
# Completed translation 365 of 9084 at 1715995613.837806
# Completed translation 366 of 9084 at 1715995616.5129414
# Completed translation 367 of 9084 at 1715995619.202394
# Completed translation 368 of 9084 at 1715995621.8960602
# Completed translation 369 of 9084 at 1715995624.6073835
# Completed translation 370 of 9084 at 1715995627.3377852
# Completed translation 371 of 9084 at 1715995630.0236173
# Completed translation 372 of 9084 at 1715995632.6853647
# Completed translation 373 of 9084 at 1715995635.3853009
# Completed translation 374 of 9084 at 1715995638.0497198
# Completed translation 375 of 9084 at 1715995640.7497833
# Completed translation 376 of 9084 at 1715995643.4272957
# Completed translation 377 of 9084 at 1715995646.1070046
# Completed translation 378 of 9084 at 1715995648.777716
# Completed translation 379 of 9084 at 1715995651.4457765
# Completed translation 380 of 9084 at 1715995654.1190414
# Completed translation 381 of 9084 at 1715995656.7906048
# Completed translation 382 of 9084 at 1715995659.4677477
# Completed translation 383 of 9084 at 1715995662.1728866
# Completed translation 384 of 9084 at 1715995664.8774023
# Completed translation 385 of 9084 at 1715995667.5590842
# Completed translation 386 of 9084 at 1715995670.2312436
# Completed translation 387 of 9084 at 1715995672.9370048
# Completed translation 388 of 9084 at 1715995675.6241288
# Completed translation 389 of 9084 at 1715995678.313374
# Completed translation 390 of 9084 at 1715995680.9862638
# Completed translation 391 of 9084 at 1715995683.67661
# Completed translation 392 of 9084 at 1715995686.354428
# Completed translation 393 of 9084 at 1715995689.0416417
# Completed translation 394 of 9084 at 1715995691.7135572
# Completed translation 395 of 9084 at 1715995694.3636127
# Completed translation 396 of 9084 at 1715995697.064414
# Completed translation 397 of 9084 at 1715995699.7328465
# Completed translation 398 of 9084 at 1715995702.41027
# Completed translation 399 of 9084 at 1715995705.0885744
# Completed translation 400 of 9084 at 1715995707.7880104
# Memory usage summary:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |  74184 KiB |  88795 KiB |   7762 GiB |   7762 GiB |
# |       from large pool |  57472 KiB |  57472 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16712 KiB |  31323 KiB |   7762 GiB |   7762 GiB |
# |---------------------------------------------------------------------------|
# | Active memory         |  74184 KiB |  88795 KiB |   7762 GiB |   7762 GiB |
# |       from large pool |  57472 KiB |  57472 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16712 KiB |  31323 KiB |   7762 GiB |   7762 GiB |
# |---------------------------------------------------------------------------|
# | Requested memory      |  74115 KiB |  88712 KiB |   7760 GiB |   7760 GiB |
# |       from large pool |  57472 KiB |  57472 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16643 KiB |  31240 KiB |   7760 GiB |   7760 GiB |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   | 106496 KiB | 114688 KiB |   2784 MiB |   2680 MiB |
# |       from large pool |  81920 KiB |  81920 KiB |    100 MiB |     20 MiB |
# |       from small pool |  24576 KiB |  32768 KiB |   2684 MiB |   2660 MiB |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |  32312 KiB |  36362 KiB |   8123 GiB |   8123 GiB |
# |       from large pool |  24448 KiB |  24448 KiB |      0 GiB |      0 GiB |
# |       from small pool |   7864 KiB |  11914 KiB |   8123 GiB |   8123 GiB |
# |---------------------------------------------------------------------------|
# | Allocations           |     440    |     622    |   30246 K  |   30246 K  |
# |       from large pool |      25    |      25    |       0 K  |       0 K  |
# |       from small pool |     415    |     597    |   30246 K  |   30246 K  |
# |---------------------------------------------------------------------------|
# | Active allocs         |     440    |     622    |   30246 K  |   30246 K  |
# |       from large pool |      25    |      25    |       0 K  |       0 K  |
# |       from small pool |     415    |     597    |   30246 K  |   30246 K  |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |      16    |      20    |    1347    |    1331    |
# |       from large pool |       4    |       4    |       5    |       1    |
# |       from small pool |      12    |      16    |    1342    |    1330    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |      11    |      24    |   12622 K  |   12622 K  |
# |       from large pool |       3    |       3    |       0 K  |       0 K  |
# |       from small pool |       8    |      21    |   12622 K  |   12622 K  |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|
#
# Translation400: {'source': 'Bosna-Hersek\'teki her bir vatandaşa karşı sorumluyum."Ģ', 'target': 'I have an obligation to every citizen of Bosnia and Herzegovina.Ģ', 'translation': ''}
# Completed translation 401 of 9084 at 1715995710.4953144
# Completed translation 402 of 9084 at 1715995713.1469736
# Completed translation 403 of 9084 at 1715995715.8278017
# Completed translation 404 of 9084 at 1715995718.5105019
# Completed translation 405 of 9084 at 1715995721.225387
# Completed translation 406 of 9084 at 1715995723.933579
# Completed translation 407 of 9084 at 1715995726.6007774
# Completed translation 408 of 9084 at 1715995729.2926955
# Completed translation 409 of 9084 at 1715995731.9881566
# Completed translation 410 of 9084 at 1715995734.6784008
# Completed translation 411 of 9084 at 1715995737.3611753
# Completed translation 412 of 9084 at 1715995740.0213716
# Completed translation 413 of 9084 at 1715995742.6827729
# Completed translation 414 of 9084 at 1715995745.3608477
# Completed translation 415 of 9084 at 1715995748.0581691
# Completed translation 416 of 9084 at 1715995750.748577
# Completed translation 417 of 9084 at 1715995753.4376838
# Completed translation 418 of 9084 at 1715995756.1348498
# Completed translation 419 of 9084 at 1715995758.827047
# Completed translation 420 of 9084 at 1715995761.5387697
# Completed translation 421 of 9084 at 1715995764.239882
# Completed translation 422 of 9084 at 1715995766.9509037
# Completed translation 423 of 9084 at 1715995769.6432254
# Completed translation 424 of 9084 at 1715995772.3622978
# Completed translation 425 of 9084 at 1715995775.068197
# Completed translation 426 of 9084 at 1715995777.7288227
# Completed translation 427 of 9084 at 1715995780.4327104
# Completed translation 428 of 9084 at 1715995783.140337
# Completed translation 429 of 9084 at 1715995785.822643
# Completed translation 430 of 9084 at 1715995788.4808426
# Completed translation 431 of 9084 at 1715995791.155367
# Completed translation 432 of 9084 at 1715995793.826528
# Completed translation 433 of 9084 at 1715995796.5083792
# Completed translation 434 of 9084 at 1715995799.1797197
# Completed translation 435 of 9084 at 1715995801.8486507
# Completed translation 436 of 9084 at 1715995804.503285
# Completed translation 437 of 9084 at 1715995807.1765835
# Completed translation 438 of 9084 at 1715995809.864537
# Completed translation 439 of 9084 at 1715995812.5426898
# Completed translation 440 of 9084 at 1715995815.2184062
# Completed translation 441 of 9084 at 1715995817.8595753
# Completed translation 442 of 9084 at 1715995820.5248206
# Completed translation 443 of 9084 at 1715995823.2413797
# Completed translation 444 of 9084 at 1715995825.9318767
# Completed translation 445 of 9084 at 1715995828.6343856
# Completed translation 446 of 9084 at 1715995831.3175225
# Completed translation 447 of 9084 at 1715995834.0437758
# Completed translation 448 of 9084 at 1715995836.7338743
# Completed translation 449 of 9084 at 1715995839.401028
# Completed translation 450 of 9084 at 1715995842.10896
# Completed translation 451 of 9084 at 1715995844.812247
# Completed translation 452 of 9084 at 1715995847.5508773
# Completed translation 453 of 9084 at 1715995850.2403762
# Completed translation 454 of 9084 at 1715995852.9447014
# Completed translation 455 of 9084 at 1715995855.6387758
# Completed translation 456 of 9084 at 1715995858.339186
# Completed translation 457 of 9084 at 1715995861.0138373
# Completed translation 458 of 9084 at 1715995863.6986017
# Completed translation 459 of 9084 at 1715995866.3936088
# Completed translation 460 of 9084 at 1715995869.079878
# Completed translation 461 of 9084 at 1715995871.75382
# Completed translation 462 of 9084 at 1715995874.4286318
# Completed translation 463 of 9084 at 1715995877.0950105
# Completed translation 464 of 9084 at 1715995879.7615228
# Completed translation 465 of 9084 at 1715995882.460679
# Completed translation 466 of 9084 at 1715995885.1491728
# Completed translation 467 of 9084 at 1715995887.7953532
# Completed translation 468 of 9084 at 1715995890.5070083
# Completed translation 469 of 9084 at 1715995893.1708848
# Completed translation 470 of 9084 at 1715995895.8564937
# Completed translation 471 of 9084 at 1715995898.5403178
# Completed translation 472 of 9084 at 1715995901.2208538
# Completed translation 473 of 9084 at 1715995903.9208052
# Completed translation 474 of 9084 at 1715995906.6210537
# Completed translation 475 of 9084 at 1715995909.318177
# Completed translation 476 of 9084 at 1715995912.009439
# Completed translation 477 of 9084 at 1715995914.7067943
# Completed translation 478 of 9084 at 1715995917.3817058
# Completed translation 479 of 9084 at 1715995920.0732253
# Completed translation 480 of 9084 at 1715995922.7704942
# Completed translation 481 of 9084 at 1715995925.4756887
# Completed translation 482 of 9084 at 1715995928.1610057
# Completed translation 483 of 9084 at 1715995930.8718007
# Completed translation 484 of 9084 at 1715995933.573762
# Completed translation 485 of 9084 at 1715995936.279053
# Completed translation 486 of 9084 at 1715995938.977931
# Completed translation 487 of 9084 at 1715995941.656654
# Completed translation 488 of 9084 at 1715995944.357279
# Completed translation 489 of 9084 at 1715995947.0603077
# Completed translation 490 of 9084 at 1715995949.7351084
# Completed translation 491 of 9084 at 1715995952.3961391
# Completed translation 492 of 9084 at 1715995955.0668526
# Completed translation 493 of 9084 at 1715995957.7492425
# Completed translation 494 of 9084 at 1715995960.4301724
# Completed translation 495 of 9084 at 1715995963.1507173
# Completed translation 496 of 9084 at 1715995965.83548
# Completed translation 497 of 9084 at 1715995968.553009
# Completed translation 498 of 9084 at 1715995971.2687054
# Completed translation 499 of 9084 at 1715995973.976248
# Completed translation 500 of 9084 at 1715995976.6706839
# Memory usage summary:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |  74184 KiB |  89555 KiB |   9751 GiB |   9751 GiB |
# |       from large pool |  57472 KiB |  57472 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16712 KiB |  32083 KiB |   9751 GiB |   9751 GiB |
# |---------------------------------------------------------------------------|
# | Active memory         |  74184 KiB |  89555 KiB |   9751 GiB |   9751 GiB |
# |       from large pool |  57472 KiB |  57472 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16712 KiB |  32083 KiB |   9751 GiB |   9751 GiB |
# |---------------------------------------------------------------------------|
# | Requested memory      |  74115 KiB |  89473 KiB |   9749 GiB |   9749 GiB |
# |       from large pool |  57472 KiB |  57472 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16643 KiB |  32001 KiB |   9749 GiB |   9749 GiB |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   | 106496 KiB | 114688 KiB |   3584 MiB |   3480 MiB |
# |       from large pool |  81920 KiB |  81920 KiB |    100 MiB |     20 MiB |
# |       from small pool |  24576 KiB |  32768 KiB |   3484 MiB |   3460 MiB |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |  32312 KiB |  38342 KiB |  10218 GiB |  10218 GiB |
# |       from large pool |  24448 KiB |  24448 KiB |      0 GiB |      0 GiB |
# |       from small pool |   7864 KiB |  13894 KiB |  10218 GiB |  10218 GiB |
# |---------------------------------------------------------------------------|
# | Allocations           |     440    |     622    |   37789 K  |   37788 K  |
# |       from large pool |      25    |      25    |       0 K  |       0 K  |
# |       from small pool |     415    |     597    |   37789 K  |   37788 K  |
# |---------------------------------------------------------------------------|
# | Active allocs         |     440    |     622    |   37789 K  |   37788 K  |
# |       from large pool |      25    |      25    |       0 K  |       0 K  |
# |       from small pool |     415    |     597    |   37789 K  |   37788 K  |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |      16    |      20    |    1747    |    1731    |
# |       from large pool |       4    |       4    |       5    |       1    |
# |       from small pool |      12    |      16    |    1742    |    1730    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |      11    |      27    |   15853 K  |   15853 K  |
# |       from large pool |       3    |       3    |       0 K  |       0 K  |
# |       from small pool |       8    |      24    |   15853 K  |   15853 K  |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|
#
# Translation500: {'source': 'Popüler bir gazete olan Vatan ise "Obama kalpleri kazandı." dedi.Ģ', 'target': 'Vatan, a popular daily, concluded "Obama has won hearts."Ģ', 'translation': ''}
# Completed translation 501 of 9084 at 1715995979.3786597
# Completed translation 502 of 9084 at 1715995982.0715737
# Completed translation 503 of 9084 at 1715995984.7624848
# Completed translation 504 of 9084 at 1715995987.481119
# Completed translation 505 of 9084 at 1715995990.1666265
# Completed translation 506 of 9084 at 1715995992.878797
# Completed translation 507 of 9084 at 1715995995.5737238
# Completed translation 508 of 9084 at 1715995998.2885668
# Completed translation 509 of 9084 at 1715996000.9739869
# ...
# Completed translation 3285 of 9084 at 1716003558.4286494
# Completed translation 3286 of 9084 at 1716003561.1713107
# Completed translation 3287 of 9084 at 1716003563.8947604
# Completed translation 3288 of 9084 at 1716003566.6372213
# Completed translation 3289 of 9084 at 1716003569.3326607
# Completed translation 3290 of 9084 at 1716003572.1208074
# Completed translation 3291 of 9084 at 1716003574.847213
# Completed translation 3292 of 9084 at 1716003577.562177
# Completed translation 3293 of 9084 at 1716003580.2694051
# Completed translation 3294 of 9084 at 1716003583.039549
# Completed translation 3295 of 9084 at 1716003585.7972484
# Completed translation 3296 of 9084 at 1716003588.5210829
# Completed translation 3297 of 9084 at 1716003591.246154
# Completed translation 3298 of 9084 at 1716003593.9463317
# Completed translation 3299 of 9084 at 1716003596.7458231
# Completed translation 3300 of 9084 at 1716003599.478464
# Memory usage summary:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |  74184 KiB | 102199 KiB |  71180 GiB |  71180 GiB |
# |       from large pool |  57472 KiB |  69760 KiB |     46 GiB |     46 GiB |
# |       from small pool |  16712 KiB |  42219 KiB |  71133 GiB |  71133 GiB |
# |---------------------------------------------------------------------------|
# | Active memory         |  74184 KiB | 102199 KiB |  71180 GiB |  71180 GiB |
# |       from large pool |  57472 KiB |  69760 KiB |     46 GiB |     46 GiB |
# |       from small pool |  16712 KiB |  42219 KiB |  71133 GiB |  71133 GiB |
# |---------------------------------------------------------------------------|
# | Requested memory      |  74115 KiB | 101502 KiB |  71167 GiB |  71167 GiB |
# |       from large pool |  57472 KiB |  69152 KiB |     43 GiB |     43 GiB |
# |       from small pool |  16643 KiB |  42147 KiB |  71124 GiB |  71124 GiB |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   | 106496 KiB | 126976 KiB |  41190 MiB |  41086 MiB |
# |       from large pool |  81920 KiB |  81920 KiB |    100 MiB |     20 MiB |
# |       from small pool |  24576 KiB |  45056 KiB |  41090 MiB |  41066 MiB |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |  32312 KiB |  42477 KiB |  75283 GiB |  75283 GiB |
# |       from large pool |  24448 KiB |  24448 KiB |     46 GiB |     46 GiB |
# |       from small pool |   7864 KiB |  18029 KiB |  75236 GiB |  75236 GiB |
# |---------------------------------------------------------------------------|
# | Allocations           |     440    |     623    |  248982 K  |  248981 K  |
# |       from large pool |      25    |      35    |      41 K  |      41 K  |
# |       from small pool |     415    |     598    |  248940 K  |  248940 K  |
# |---------------------------------------------------------------------------|
# | Active allocs         |     440    |     623    |  248982 K  |  248981 K  |
# |       from large pool |      25    |      35    |      41 K  |      41 K  |
# |       from small pool |     415    |     598    |  248940 K  |  248940 K  |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |      16    |      26    |   20550    |   20534    |
# |       from large pool |       4    |       4    |       5    |       1    |
# |       from small pool |      12    |      22    |   20545    |   20533    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |      11    |      28    |  105118 K  |  105118 K  |
# |       from large pool |       3    |       4    |      25 K  |      25 K  |
# |       from small pool |       8    |      25    |  105092 K  |  105092 K  |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|
#
# Translation3300: {'source': "ABD başkanı, bunun yerine Washington ve Ankara'nın sorunla başa çıkmak için birlikte çalışmaları gerektiğini söyledi.Ģ", 'target': 'Instead, the US president said, Washington and Ankara should work together to combat the problem.Ģ', 'translation': ''}
# Completed translation 3301 of 9084 at 1716003602.2983172
# Completed translation 3302 of 9084 at 1716003605.0140288
# Completed translation 3303 of 9084 at 1716003607.7772737
# Completed translation 3304 of 9084 at 1716003610.5441632
# Completed translation 3305 of 9084 at 1716003613.2645917
# Completed translation 3306 of 9084 at 1716003615.988387
# Completed translation 3307 of 9084 at 1716003618.7915344
# Completed translation 3308 of 9084 at 1716003621.7743564
# Completed translation 3309 of 9084 at 1716003624.4857492
# Completed translation 3310 of 9084 at 1716003627.2213016
# Completed translation 3311 of 9084 at 1716003629.9831488
# Completed translation 3312 of 9084 at 1716003632.75644
# Completed translation 3313 of 9084 at 1716003635.5274544
# Completed translation 3314 of 9084 at 1716003638.2911463
# Completed translation 3315 of 9084 at 1716003641.0305593
# Completed translation 3316 of 9084 at 1716003643.758366
# Completed translation 3317 of 9084 at 1716003646.5139265
# Completed translation 3318 of 9084 at 1716003649.2537584
# Completed translation 3319 of 9084 at 1716003651.97935
# Completed translation 3320 of 9084 at 1716003654.690224
# Completed translation 3321 of 9084 at 1716003657.401037
# Completed translation 3322 of 9084 at 1716003660.1096957
# Completed translation 3323 of 9084 at 1716003662.825345
# Completed translation 3324 of 9084 at 1716003665.5298586
# Completed translation 3325 of 9084 at 1716003668.24768
# Completed translation 3326 of 9084 at 1716003671.0001628
# Completed translation 3327 of 9084 at 1716003673.7257566
# Completed translation 3328 of 9084 at 1716003676.4268532
# Completed translation 3329 of 9084 at 1716003679.1195066
# Completed translation 3330 of 9084 at 1716003681.8512099
# Completed translation 3331 of 9084 at 1716003684.5903647
# Completed translation 3332 of 9084 at 1716003687.2851791
# Completed translation 3333 of 9084 at 1716003690.0118198
# Completed translation 3334 of 9084 at 1716003692.736161
# Completed translation 3335 of 9084 at 1716003695.4708548
# Completed translation 3336 of 9084 at 1716003698.162041
# Completed translation 3337 of 9084 at 1716003700.870508
# Completed translation 3338 of 9084 at 1716003703.5787065
# Completed translation 3339 of 9084 at 1716003706.310761
# Completed translation 3340 of 9084 at 1716003709.0414312
# Completed translation 3341 of 9084 at 1716003711.7676618
# Completed translation 3342 of 9084 at 1716003714.454929
# Completed translation 3343 of 9084 at 1716003717.1725676
# Completed translation 3344 of 9084 at 1716003719.9064815
# Completed translation 3345 of 9084 at 1716003722.6260388
# Completed translation 3346 of 9084 at 1716003725.3260548
# Completed translation 3347 of 9084 at 1716003728.157707
# Completed translation 3348 of 9084 at 1716003730.9745457
# Completed translation 3349 of 9084 at 1716003733.7441335
# Completed translation 3350 of 9084 at 1716003736.4897418
# Completed translation 3351 of 9084 at 1716003739.1969695
# Completed translation 3352 of 9084 at 1716003741.8918343
# Completed translation 3353 of 9084 at 1716003744.6955743
# Completed translation 3354 of 9084 at 1716003747.447965
# Completed translation 3355 of 9084 at 1716003750.1586099
# Completed translation 3356 of 9084 at 1716003752.8924172
# Completed translation 3357 of 9084 at 1716003755.6136477
# Completed translation 3358 of 9084 at 1716003758.3605237
# Completed translation 3359 of 9084 at 1716003761.073639
# Completed translation 3360 of 9084 at 1716003763.7707393
# Completed translation 3361 of 9084 at 1716003766.4874437
# Completed translation 3362 of 9084 at 1716003769.1978161
# Completed translation 3363 of 9084 at 1716003771.9211364
# Completed translation 3364 of 9084 at 1716003774.6536667
# Completed translation 3365 of 9084 at 1716003777.3649778
# Completed translation 3366 of 9084 at 1716003780.1101103
# Completed translation 3367 of 9084 at 1716003782.893028
# Completed translation 3368 of 9084 at 1716003785.642022
# Completed translation 3369 of 9084 at 1716003788.4063506
# Completed translation 3370 of 9084 at 1716003791.1664968
# Completed translation 3371 of 9084 at 1716003793.919599
# Completed translation 3372 of 9084 at 1716003796.673786
# Completed translation 3373 of 9084 at 1716003799.4065847
# Completed translation 3374 of 9084 at 1716003802.1364148
# Completed translation 3375 of 9084 at 1716003804.8625941
# Completed translation 3376 of 9084 at 1716003807.5752587
# Completed translation 3377 of 9084 at 1716003810.2981927
# Completed translation 3378 of 9084 at 1716003813.0114274
# Completed translation 3379 of 9084 at 1716003815.7441683
# Completed translation 3380 of 9084 at 1716003818.47751
# Completed translation 3381 of 9084 at 1716003821.2211137
# Completed translation 3382 of 9084 at 1716003823.9399347
# Completed translation 3383 of 9084 at 1716003826.664938
# Completed translation 3384 of 9084 at 1716003829.4178116
# Completed translation 3385 of 9084 at 1716003832.1442304
# Completed translation 3386 of 9084 at 1716003834.8580046
# Completed translation 3387 of 9084 at 1716003837.5681107
# Completed translation 3388 of 9084 at 1716003840.2946033
# Completed translation 3389 of 9084 at 1716003843.0149627
# Completed translation 3390 of 9084 at 1716003845.7231874
# Completed translation 3391 of 9084 at 1716003848.4336827
# Completed translation 3392 of 9084 at 1716003851.1478703
# Completed translation 3393 of 9084 at 1716003853.8811145
# Completed translation 3394 of 9084 at 1716003856.612085
# Completed translation 3395 of 9084 at 1716003859.3200245
# Completed translation 3396 of 9084 at 1716003862.033
# Completed translation 3397 of 9084 at 1716003864.7511508
# Completed translation 3398 of 9084 at 1716003867.4933393
# Completed translation 3399 of 9084 at 1716003870.2319505
# Completed translation 3400 of 9084 at 1716003872.9173002
# Memory usage summary:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |  74184 KiB | 102487 KiB |  73580 GiB |  73580 GiB |
# |       from large pool |  57472 KiB |  69760 KiB |     69 GiB |     69 GiB |
# |       from small pool |  16712 KiB |  42583 KiB |  73511 GiB |  73511 GiB |
# |---------------------------------------------------------------------------|
# | Active memory         |  74184 KiB | 102487 KiB |  73580 GiB |  73580 GiB |
# |       from large pool |  57472 KiB |  69760 KiB |     69 GiB |     69 GiB |
# |       from small pool |  16712 KiB |  42583 KiB |  73511 GiB |  73511 GiB |
# |---------------------------------------------------------------------------|
# | Requested memory      |  74115 KiB | 101710 KiB |  73565 GiB |  73565 GiB |
# |       from large pool |  57472 KiB |  69072 KiB |     64 GiB |     63 GiB |
# |       from small pool |  16643 KiB |  42511 KiB |  73501 GiB |  73501 GiB |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   | 106496 KiB | 126976 KiB |  43036 MiB |  42932 MiB |
# |       from large pool |  81920 KiB |  81920 KiB |    100 MiB |     20 MiB |
# |       from small pool |  24576 KiB |  45056 KiB |  42936 MiB |  42912 MiB |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |  32312 KiB |  43536 KiB |  77812 GiB |  77812 GiB |
# |       from large pool |  24448 KiB |  24448 KiB |     69 GiB |     69 GiB |
# |       from small pool |   7864 KiB |  19088 KiB |  77743 GiB |  77743 GiB |
# |---------------------------------------------------------------------------|
# | Allocations           |     440    |     622    |  256524 K  |  256524 K  |
# |       from large pool |      25    |      35    |      61 K  |      61 K  |
# |       from small pool |     415    |     597    |  256463 K  |  256462 K  |
# |---------------------------------------------------------------------------|
# | Active allocs         |     440    |     622    |  256524 K  |  256524 K  |
# |       from large pool |      25    |      35    |      61 K  |      61 K  |
# |       from small pool |     415    |     597    |  256463 K  |  256462 K  |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |      16    |      26    |   21473    |   21457    |
# |       from large pool |       4    |       4    |       5    |       1    |
# |       from small pool |      12    |      22    |   21468    |   21456    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |      11    |      27    |  108284 K  |  108284 K  |
# |       from large pool |       3    |       4    |      37 K  |      37 K  |
# |       from small pool |       8    |      24    |  108246 K  |  108246 K  |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|
#
# Translation3400: {'source': 'Yabancı şirketler bile maaşların yarısını banka hesaplarına yatırıp diğer yarısını elden nakit veriyorlar." diyor.Ģ', 'target': 'Even foreign companies are now paying half of the wages into accounts and half cash-in-hand," he writes.Ģ', 'translation': ''}
# Completed translation 3401 of 9084 at 1716003875.682755
# Completed translation 3402 of 9084 at 1716003878.4100423
# Completed translation 3403 of 9084 at 1716003881.1188436
# Completed translation 3404 of 9084 at 1716003883.8347971
# Completed translation 3405 of 9084 at 1716003886.5266206
# Completed translation 3406 of 9084 at 1716003889.218893
# Completed translation 3407 of 9084 at 1716003891.94091
# Completed translation 3408 of 9084 at 1716003894.6275046
# Completed translation 3409 of 9084 at 1716003897.3389874
# Completed translation 3410 of 9084 at 1716003900.036834
# Completed translation 3411 of 9084 at 1716003902.7572525
# Completed translation 3412 of 9084 at 1716003905.4606879
# Completed translation 3413 of 9084 at 1716003908.1717534
# Completed translation 3414 of 9084 at 1716003910.8789833
# Completed translation 3415 of 9084 at 1716003913.6351588
# Completed translation 3416 of 9084 at 1716003916.5891201
# Completed translation 3417 of 9084 at 1716003919.3229275
