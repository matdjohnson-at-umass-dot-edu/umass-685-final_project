# %%
from google.colab import drive

import json
import random
import time
from typing import Optional

import torch
import numpy as np

drive.mount('/content/drive', force_remount=True)
root_filepath = '/content/drive/MyDrive/CS685-NLP-GroupProject/Code/singleNotebookFromPythonFilesStructure/'
is_remote_execution = True
torch.set_printoptions(threshold=100000, edgeitems=10000, linewidth=100000)
torch.device("cuda")


# 16M Turkish
SETimesByT5Vaswani2017Kocmi2018_0 = {
    'runner_hyperparameters_name': 'SETimesByT5Vaswani2017Kocmi2018_0',
    'model_parameter_filepath': root_filepath + "resources/saved_parameters/SETimesByT5Vaswani2017Kocmi2018_0-1715937924-model.params",
    'datasets_filepath': root_filepath + "resources/parsed_datasets/setimes/setimes_parsed-1715586293",
    'output_filepath': root_filepath + "resources/model_translations/SETimesByT5Vaswani2017Kocmi2018_0.json",
    'model_hyperparameters': {
        'src_vocab_size': 91,
        'tgt_vocab_size': 81,
        'max_src_seq_len': 266,
        'max_tgt_seq_len': 256,
        'd_model': 256,
        'nhead': 8,
        # number of encoders is 3 times that of decoders, following Xue 2021 - ByT5 - Sec 3.1
        'num_encoder_layers': 9,
        'num_decoder_layers': 3,
        'dim_feedforward': 2048,
        'dropout': 0.1,
        'activation': torch.nn.functional.relu,
        'custom_encoder': None,
        'custom_decoder': None,
        'layer_norm_eps': 1e-5,
        'batch_first': True,
        'norm_first': False,
        'bias': True,
        'device': None,
        'dtype': None
    }
}

# 15M Turkish
SETimesByT5Vaswani2017Kocmi2018_1 = {
    'runner_hyperparameters_name': 'SETimesByT5Vaswani2017Kocmi2018_1',
    'model_parameter_filepath': root_filepath + "resources/saved_parameters/SETimesByT5Vaswani2017Kocmi2018_1-1715937961-model.params",
    'datasets_filepath': root_filepath + "resources/parsed_datasets/setimes/setimes_parsed-1715586974",
    'output_filepath': root_filepath + "resources/model_translations/SETimesByT5Vaswani2017Kocmi2018_1.json",
    'model_hyperparameters': {
        'src_vocab_size': 91,
        'tgt_vocab_size': 81,
        'max_src_seq_len': 266,
        'max_tgt_seq_len': 256,
        'd_model': 256,
        'nhead': 8,
        # number of encoders is 3 times that of decoders, following Xue 2021 - ByT5 - Sec 3.1
        'num_encoder_layers': 9,
        'num_decoder_layers': 3,
        'dim_feedforward': 1796,
        'dropout': 0.1,
        'activation': torch.nn.functional.relu,
        'custom_encoder': None,
        'custom_decoder': None,
        'layer_norm_eps': 1e-5,
        'batch_first': True,
        'norm_first': False,
        'bias': True,
        'device': None,
        'dtype': None
    }
}

# 4M Turkish
SETimesByT5Vaswani2017Kocmi2018_2 = {
    'runner_hyperparameters_name': 'SETimesByT5Vaswani2017Kocmi2018_2',
    'model_parameter_filepath': root_filepath + "resources/saved_parameters/SETimesByT5Vaswani2017Kocmi2018_2-1715936459-model.params",
    'datasets_filepath': root_filepath + "resources/parsed_datasets/setimes/setimes_parsed-1715586361",
    'output_filepath': root_filepath + "resources/model_translations/SETimesByT5Vaswani2017Kocmi2018_2.json",
    'model_hyperparameters': {
        'src_vocab_size': 91,
        'tgt_vocab_size': 81,
        'max_src_seq_len': 266,
        'max_tgt_seq_len': 256,
        'd_model': 128,
        'nhead': 8,
        # number of encoders is 3 times that of decoders, following Xue 2021 - ByT5 - Sec 3.1
        'num_encoder_layers': 9,
        'num_decoder_layers': 3,
        'dim_feedforward': 1024,
        'dropout': 0.1,
        'activation': torch.nn.functional.relu,
        'custom_encoder': None,
        'custom_decoder': None,
        'layer_norm_eps': 1e-5,
        'batch_first': True,
        'norm_first': False,
        'bias': True,
        'device': None,
        'dtype': None
    }
}

# 16M Kazakh
NewsCommentaryByT5Vaswani2017Kocmi2018_0 = {
    'runner_hyperparameters_name': 'NewsCommentaryByT5Vaswani2017Kocmi2018_0',
    'model_parameter_filepath': root_filepath + "resources/saved_parameters/NewsCommentaryByT5Vaswani2017Kocmi2018_0-1715965639-model.params",
    'datasets_filepath': root_filepath + "resources/parsed_datasets/SMTNewsCommentary/SMTNewsCommentary_parsed-1715949808",
    'output_filepath': root_filepath + "resources/model_translations/NewsCommentaryByT5Vaswani2017Kocmi2018_0.json",
    'model_hyperparameters': {
        'src_vocab_size': 150,
        'tgt_vocab_size': 81,
        'max_src_seq_len': 266,
        'max_tgt_seq_len': 256,
        'd_model': 256,
        'nhead': 8,
        # number of encoders is 3 times that of decoders, following Xue 2021 - ByT5 - Sec 3.1
        'num_encoder_layers': 9,
        'num_decoder_layers': 3,
        'dim_feedforward': 2048,
        'dropout': 0.1,
        'activation': torch.nn.functional.relu,
        'custom_encoder': None,
        'custom_decoder': None,
        'layer_norm_eps': 1e-5,
        'batch_first': True,
        'norm_first': False,
        'bias': True,
        'device': None,
        'dtype': None
    }
}

# 15M Kazakh
NewsCommentaryByT5Vaswani2017Kocmi2018_1 = {
    'runner_hyperparameters_name': 'NewsCommentaryByT5Vaswani2017Kocmi2018_1',
    'model_parameter_filepath': root_filepath + "resources/saved_parameters/NewsCommentaryByT5Vaswani2017Kocmi2018_1-1715966141-model.params",
    'datasets_filepath': root_filepath + "resources/parsed_datasets/SMTNewsCommentary/SMTNewsCommentary_parsed-1715949808",
    'output_filepath': root_filepath + "resources/model_translations/NewsCommentaryByT5Vaswani2017Kocmi2018_1.json",
    'model_hyperparameters': {
        'src_vocab_size': 150,
        'tgt_vocab_size': 81,
        'max_src_seq_len': 266,
        'max_tgt_seq_len': 256,
        'd_model': 256,
        'nhead': 8,
        # number of encoders is 3 times that of decoders, following Xue 2021 - ByT5 - Sec 3.1
        'num_encoder_layers': 9,
        'num_decoder_layers': 3,
        'dim_feedforward': 1796,
        'dropout': 0.1,
        'activation': torch.nn.functional.relu,
        'custom_encoder': None,
        'custom_decoder': None,
        'layer_norm_eps': 1e-5,
        'batch_first': True,
        'norm_first': False,
        'bias': True,
        'device': None,
        'dtype': None
    }
}

# 4M Kazakh
NewsCommentaryByT5Vaswani2017Kocmi2018_2 = {
    'runner_hyperparameters_name': 'NewsCommentaryByT5Vaswani2017Kocmi2018_2',
    'model_parameter_filepath': root_filepath + "resources/saved_parameters/NewsCommentaryByT5Vaswani2017Kocmi2018_2-1715965581-model.params",
    'datasets_filepath': root_filepath + "resources/parsed_datasets/SMTNewsCommentary/SMTNewsCommentary_parsed-1715949808",
    'output_filepath': root_filepath + "resources/model_translations/NewsCommentaryByT5Vaswani2017Kocmi2018_2.json",
    'model_hyperparameters': {
        'src_vocab_size': 150,
        'tgt_vocab_size': 81,
        'max_src_seq_len': 266,
        'max_tgt_seq_len': 256,
        'd_model': 128,
        'nhead': 8,
        # number of encoders is 3 times that of decoders, following Xue 2021 - ByT5 - Sec 3.1
        'num_encoder_layers': 9,
        'num_decoder_layers': 3,
        'dim_feedforward': 1024,
        'dropout': 0.1,
        'activation': torch.nn.functional.relu,
        'custom_encoder': None,
        'custom_decoder': None,
        'layer_norm_eps': 1e-5,
        'batch_first': True,
        'norm_first': False,
        'bias': True,
        'device': None,
        'dtype': None
    }
}


class DatasetHolder:

    def __init__(self):
        self.unknown_vocabulary_type = None
        self.padding_vocabulary_type = None
        self.end_of_sequence_type = None
        self.target_vocab = None
        self.target_vocab_array = None
        self.target_vocab_counts = None
        self.source_vocab = None
        self.source_vocab_array = None
        self.source_vocab_counts = None
        self.target_encodings = None
        self.target_encodings_train = None
        self.target_encodings_test = None
        self.source_encodings = None
        self.source_encodings_train = None
        self.source_encodings_test = None
        self.max_src_seq_obs = 0
        self.max_tgt_seq_obs = 0

    def get_unknown_vocabulary_type(self):
        return self.unknown_vocabulary_type

    def set_unknown_vocabulary_type(self, unknown_vocabulary_type):
        self.unknown_vocabulary_type = unknown_vocabulary_type

    def get_padding_vocabulary_type(self):
        return self.padding_vocabulary_type

    def set_padding_vocabulary_type(self, padding_vocabulary_type):
        self.padding_vocabulary_type = padding_vocabulary_type

    def get_end_of_sequence_vocabulary_type(self):
        return self.end_of_sequence_type

    def set_end_of_sequence_vocabulary_type(self, end_of_sequence_type):
        self.end_of_sequence_type = end_of_sequence_type

    def get_target_vocab(self):
        return self.target_vocab

    def set_target_vocab(self, target_vocab):
        self.target_vocab = target_vocab

    def get_target_vocab_numpy(self):
        if self.target_vocab_array is None:
            self.target_vocab_array = np.array(self.target_vocab)
        return self.target_vocab_array

    def get_target_vocab_counts(self):
        return self.target_vocab_counts

    def set_target_vocab_counts(self, target_vocab_counts):
        self.target_vocab_counts = target_vocab_counts

    def get_source_vocab(self):
        return self.source_vocab

    def set_source_vocab(self, source_vocab):
        self.source_vocab = source_vocab

    def get_source_vocab_numpy(self):
        if self.source_vocab_array is None:
            self.source_vocab_array = np.array(self.source_vocab)
        return self.source_vocab_array

    def get_source_vocab_counts(self):
        return self.source_vocab_counts

    def set_source_vocab_counts(self, source_vocab_counts):
        self.source_vocab_counts = source_vocab_counts

    def get_target_encodings(self):
        return self.target_encodings

    def set_target_encodings(self, target_encodings):
        del self.target_encodings
        self.target_encodings = target_encodings
        if is_remote_execution:
            torch.cuda.empty_cache()

    def get_source_encodings(self):
        return self.source_encodings

    def set_source_encodings(self, source_encodings):
        del self.source_encodings
        self.source_encodings = source_encodings
        if is_remote_execution:
            torch.cuda.empty_cache()

    def get_target_encodings_train(self):
        return self.target_encodings_train

    def set_target_encodings_train(self, target_encodings_train):
        del self.target_encodings_train
        self.target_encodings_train = target_encodings_train
        if is_remote_execution:
            torch.cuda.empty_cache()

    def get_source_encodings_train(self):
        return self.source_encodings_train

    def set_source_encodings_train(self, source_encodings_train):
        del self.source_encodings_train
        self.source_encodings_train = source_encodings_train
        if is_remote_execution:
            torch.cuda.empty_cache()

    def get_target_encodings_test(self):
        return self.target_encodings_test

    def set_target_encodings_test(self, target_encodings_test):
        del self.target_encodings_test
        self.target_encodings_test = target_encodings_test
        if is_remote_execution:
            torch.cuda.empty_cache()

    def get_source_encodings_test(self):
        return self.source_encodings_test

    def set_source_encodings_test(self, source_encodings_test):
        del self.source_encodings_test
        self.source_encodings_test = source_encodings_test
        if is_remote_execution:
            torch.cuda.empty_cache()

    def get_max_src_seq_obs(self):
        return self.max_src_seq_obs

    def set_max_src_seq_obs(self, max_src_seq_obs):
        self.max_src_seq_obs = max_src_seq_obs

    def get_max_tgt_seq_obs(self):
        return self.max_tgt_seq_obs

    def set_max_tgt_seq_obs(self, max_tgt_seq_obs):
        self.max_tgt_seq_obs = max_tgt_seq_obs

# class name matches file name
class transformer_vaswani2017(torch.nn.Transformer):

    def __init__(self,
                 model_hyperparameters):
        super().__init__(
            d_model=model_hyperparameters['d_model'],
            nhead=model_hyperparameters['nhead'],
            num_encoder_layers=model_hyperparameters['num_encoder_layers'],
            num_decoder_layers=model_hyperparameters['num_decoder_layers'],
            dim_feedforward=model_hyperparameters['dim_feedforward'],
            dropout=model_hyperparameters['dropout'],
            activation=model_hyperparameters['activation'],
            custom_encoder=model_hyperparameters['custom_encoder'],
            custom_decoder=model_hyperparameters['custom_decoder'],
            layer_norm_eps=model_hyperparameters['layer_norm_eps'],
            batch_first=model_hyperparameters['batch_first'],
            norm_first=model_hyperparameters['norm_first'],
            bias=model_hyperparameters['bias'],
            device=model_hyperparameters['device'],
            dtype=model_hyperparameters['dtype']
        )
        self.model_hyperparameters = model_hyperparameters
        # add one for the end of sequence token
        self.max_src_seq_len = model_hyperparameters['max_src_seq_len'] + 1
        self.max_tgt_seq_len = model_hyperparameters['max_tgt_seq_len'] + 1
        self.src_embeddings = torch.nn.Embedding(
            model_hyperparameters['src_vocab_size'],
            model_hyperparameters['d_model']
        )
        self.tgt_embeddings = torch.nn.Embedding(
            model_hyperparameters['tgt_vocab_size'],
            model_hyperparameters['d_model']
        )
        self.src_pos_enc = torch.nn.Embedding(
            self.max_src_seq_len,
            model_hyperparameters['d_model']
        ).requires_grad_(False)
        self.tgt_pos_enc = torch.nn.Embedding(
            self.max_tgt_seq_len,
            model_hyperparameters['d_model']
        ).requires_grad_(False)
        self.linear_output_projection_1 = torch.nn.Linear(
            self.max_tgt_seq_len,
            1,
            bias=False
        )
        self.linear_output_projection_2 = torch.nn.Linear(
            model_hyperparameters['d_model'],
            model_hyperparameters['tgt_vocab_size'],
            bias=False
        )
        self.logsoftmax_output = torch.nn.LogSoftmax(dim=1)
        self.model_hyperparameters = model_hyperparameters
        self.tgt_mask_cache = {}
        for i in range(0, self.max_tgt_seq_len + 1):
            tgt_mask = self.generate_square_subsequent_mask(i)
            if is_remote_execution:
                self.tgt_mask_cache[i] = tgt_mask.to(device="cuda")
            self.tgt_mask_cache[i] = tgt_mask
        self.indices_cache = {}
        for i in range(0, max([self.max_src_seq_len, self.max_tgt_seq_len]) + 1):
            indices = torch.tensor(np.arange(0, i), dtype=torch.long)
            if is_remote_execution:
                indices = indices.to(device="cuda")
            self.indices_cache[i] = indices

    def forward(self,
                src: torch.Tensor,
                tgt: torch.Tensor,
                src_mask: Optional[torch.Tensor] = None,
                tgt_mask: Optional[torch.Tensor] = None,
                memory_mask: Optional[torch.Tensor] = None,
                src_key_padding_mask: Optional[torch.Tensor] = None,
                tgt_key_padding_mask: Optional[torch.Tensor] = None,
                memory_key_padding_mask: Optional[torch.Tensor] = None,
                src_is_causal: Optional[bool] = None,
                tgt_is_causal: Optional[bool] = True,
                memory_is_causal: bool = False) -> torch.Tensor:
        if len(src.shape) == 1:
            src = src.unsqueeze(dim=0)
        if len(tgt.shape) == 1:
            tgt = tgt.unsqueeze(dim=0)
        src_embedding_pos_enc = self.src_embeddings(src) + self.src_pos_enc(self.indices_cache[src.shape[1]])
        tgt_embedding_pos_enc = self.tgt_embeddings(tgt) + self.tgt_pos_enc(self.indices_cache[tgt.shape[1]])
        tgt_mask = self.tgt_mask_cache[tgt.shape[1]]
        transformer_output = super().forward(src_embedding_pos_enc, tgt_embedding_pos_enc, src_mask,
                                             tgt_mask, memory_mask, src_key_padding_mask,
                                             tgt_key_padding_mask, memory_key_padding_mask,
                                             src_is_causal, tgt_is_causal, memory_is_causal)
        transformer_output = torch.swapaxes(transformer_output, -1, -2)
        transformer_output = torch.nn.functional.pad(
            transformer_output,
            (0, self.max_tgt_seq_len - transformer_output.shape[2]),
            value=0
        )
        output = self.logsoftmax_output(
            self.linear_output_projection_2(
                torch.squeeze(
                    self.linear_output_projection_1(
                        transformer_output
                    ),
                    dim=2
                )
            )
        )
        del src_embedding_pos_enc
        del tgt_embedding_pos_enc
        del transformer_output
        return output

    def freeze_target_embeddings(self):
        del self.tgt_embeddings
        self.tgt_embeddings = torch.nn.Embedding(
            self.model_hyperparameters['tgt_vocab_size'],
            self.model_hyperparameters['d_model']
        ).requires_grad_(False)
        del self.linear_output_projection_1
        self.linear_output_projection_1 = torch.nn.Linear(
            self.max_tgt_seq_len,
            1,
            bias=False
        ).requires_grad_(False)
        del self.linear_output_projection_2
        self.linear_output_projection_2 = torch.nn.Linear(
            self.model_hyperparameters['d_model'],
            self.model_hyperparameters['tgt_vocab_size'],
            bias=False
        ).requires_grad_(False)

    def set_source_embeddings_for_transfer_learning(self, source_embeddings_dim):
        del self.src_embeddings
        self.src_embeddings = torch.nn.Embedding(
            source_embeddings_dim,
            self.model_hyperparameters['d_model']
        )


class Runner:

    def __init__(self):
        self.runner_hyperparameters = SETimesByT5Vaswani2017Kocmi2018_1
        self.model_hyperparameters = self.runner_hyperparameters['model_hyperparameters']
        self.runner_hyperparameters_name = self.runner_hyperparameters['runner_hyperparameters_name']
        self.model_parameter_filepath = self.runner_hyperparameters['model_parameter_filepath']
        self.datasets_filepath = self.runner_hyperparameters['datasets_filepath']
        self.output_filepath = self.runner_hyperparameters['output_filepath']
        self.max_target_sequence_length = self.runner_hyperparameters['model_hyperparameters']['max_tgt_seq_len']
        self.dataset_holder: DatasetHolder = None
        self.model = None
        print(f"Initialized runner {self.runner_hyperparameters_name} with parameters {self.runner_hyperparameters}")

    def load_dataset(self):
        self.dataset_holder = torch.load(self.datasets_filepath)

    def load_model(self):
        self.model = transformer_vaswani2017(model_hyperparameters=self.model_hyperparameters)
        self.model.freeze_target_embeddings()
        if is_remote_execution:
            model_parameters = torch.load(self.model_parameter_filepath, map_location=torch.device('cuda'))
        else:
            model_parameters = torch.load(self.model_parameter_filepath, map_location=torch.device('cpu'))
        self.model.load_state_dict(model_parameters)
        if is_remote_execution:
            self.model.cuda()
        self.model.eval()

    def evaluate_model(self):
        outputs = list()
        source_vocab_numpy = self.dataset_holder.get_source_vocab_numpy()
        target_vocab_numpy = self.dataset_holder.get_target_vocab_numpy()
        assert len(self.dataset_holder.get_source_encodings_test()) == len(self.dataset_holder.get_target_encodings_test())
        for i in range(0, len(self.dataset_holder.get_source_encodings_test())):
            if is_remote_execution:
                source_encoding = self.dataset_holder.get_source_encodings_test()[i].to(device="cuda")
                target_encoding = self.dataset_holder.get_target_encodings_test()[i].to(device="cuda")
            else:
                source_encoding = self.dataset_holder.get_source_encodings_test()[i].to(device="cpu")
                target_encoding = self.dataset_holder.get_target_encodings_test()[i].to(device="cpu")
            j = 0
            end_of_sequence = False
            while j < self.model_hyperparameters['max_tgt_seq_len'] and end_of_sequence == False:
                target_encoding_slice = torch.tensor_split(target_encoding, [j], dim=0)
                output_logits = self.model.forward(
                    source_encoding,
                    target_encoding_slice[0]
                ).detach().to(device="cpu").flatten().numpy()
                output_logits_sort_pairs = list()
                for k in range(0, len(output_logits)):
                    output_logits_sort_pairs.append([output_logits[k], k])
                output_logits_sorted = sorted(output_logits_sort_pairs, key=lambda logit_pair: logit_pair[0], reverse=True)
                output_sort_index = 0
                # don't pick mark up characters or whitespace if first term
                if j == 0:
                    while output_logits_sorted[output_sort_index][1] in (0, 1, 2, 7):
                        output_sort_index = output_sort_index + 1
                else:
                    # don't repeat unknown, padding, or spaces
                    if (prediction_encoding[j-1] == 0
                            or prediction_encoding[j-1] == 1
                            or prediction_encoding[j-1] == 7):
                        while (output_logits_sorted[output_sort_index][1] == 0
                               or output_logits_sorted[output_sort_index][1] == 1
                               or output_logits_sorted[output_sort_index][1] == 7):
                            output_sort_index = output_sort_index + 1
                output_vocab_index = output_logits_sorted[output_sort_index][1]
                # index = output_vocab_index # always outputs "Krrrr...<eos>"
                index = min(random.randint(output_vocab_index, output_vocab_index + 3), len(output_logits_sorted))
                if j == 0:
                    prediction_encoding = torch.tensor([output_logits_sorted[index][1]], dtype=torch.float)
                else:
                    prediction_encoding = torch.cat([prediction_encoding, torch.tensor([output_logits_sorted[index][1]], dtype=torch.float)])
                if prediction_encoding[j] == self.dataset_holder.get_target_vocab().index(
                        self.dataset_holder.get_end_of_sequence_vocabulary_type()):
                    end_of_sequence = True
                j = j + 1
            decoded_source = np.take(source_vocab_numpy, source_encoding.detach().to(device="cpu").flatten().numpy())
            decoded_target = np.take(target_vocab_numpy, target_encoding.detach().to(device="cpu").flatten().numpy())
            decoded_translation = np.take(target_vocab_numpy, prediction_encoding.detach().to(device="cpu", dtype=torch.int32).numpy())
            outputs.append({
                "source": "".join(decoded_source.tolist()),
                "target": "".join(decoded_target.tolist()),
                "translation": "".join(decoded_translation.tolist())
            })
            del source_encoding
            del target_encoding
            del prediction_encoding
            del target_encoding_slice
            del decoded_source
            del decoded_target
            del decoded_translation
            print(f"Completed translation {i} of {len(self.dataset_holder.get_source_encodings_test())} at {time.time()}")
            if is_remote_execution:
                torch.cuda.empty_cache()
                if i % 100 == 0:
                    print(f"Memory usage summary:")
                    print(f"{torch.cuda.memory_summary()}")
                    torch.cuda.reset_max_memory_allocated()
                    torch.cuda.reset_max_memory_cached()
                    torch.cuda.reset_peak_memory_stats()
            if i % 100 == 0 or i == len(self.dataset_holder.get_source_encodings_test()) - 1:
                print(f"Translation{i}: {outputs[i]}")
                output_file = open(self.output_filepath, "w")
                output_file.write(json.dumps(outputs, ensure_ascii=False, indent=1))
                output_file.close()


runner = Runner()
runner.load_dataset()
runner.load_model()
runner.evaluate_model()
# Out:
# Mounted at /content/drive
# Initialized runner SETimesByT5Vaswani2017Kocmi2018_1 with parameters {'runner_hyperparameters_name': 'SETimesByT5Vaswani2017Kocmi2018_1', 'model_parameter_filepath': '/content/drive/MyDrive/CS685-NLP-GroupProject/Code/singleNotebookFromPythonFilesStructure/resources/saved_parameters/SETimesByT5Vaswani2017Kocmi2018_1-1715937961-model.params', 'datasets_filepath': '/content/drive/MyDrive/CS685-NLP-GroupProject/Code/singleNotebookFromPythonFilesStructure/resources/parsed_datasets/setimes/setimes_parsed-1715586974', 'output_filepath': '/content/drive/MyDrive/CS685-NLP-GroupProject/Code/singleNotebookFromPythonFilesStructure/resources/model_translations/SETimesByT5Vaswani2017Kocmi2018_1.json', 'model_hyperparameters': {'src_vocab_size': 91, 'tgt_vocab_size': 81, 'max_src_seq_len': 266, 'max_tgt_seq_len': 256, 'd_model': 256, 'nhead': 8, 'num_encoder_layers': 9, 'num_decoder_layers': 3, 'dim_feedforward': 1796, 'dropout': 0.1, 'activation': <function relu at 0x782e94947be0>, 'custom_encoder': None, 'custom_decoder': None, 'layer_norm_eps': 1e-05, 'batch_first': True, 'norm_first': False, 'bias': True, 'device': None, 'dtype': None}}
# Completed translation 0 of 9084 at 1715995051.7034273
# Memory usage summary:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |  69578 KiB | 122168 KiB |  18960 MiB |  18893 MiB |
# |       from large pool |  52872 KiB |  89104 KiB |     95 MiB |     43 MiB |
# |       from small pool |  16706 KiB |  33064 KiB |  18865 MiB |  18849 MiB |
# |---------------------------------------------------------------------------|
# | Active memory         |  69578 KiB | 122168 KiB |  18960 MiB |  18893 MiB |
# |       from large pool |  52872 KiB |  89104 KiB |     95 MiB |     43 MiB |
# |       from small pool |  16706 KiB |  33064 KiB |  18865 MiB |  18849 MiB |
# |---------------------------------------------------------------------------|
# | Requested memory      |  68055 KiB | 119191 KiB |  18951 MiB |  18885 MiB |
# |       from large pool |  51424 KiB |  86208 KiB |     92 MiB |     42 MiB |
# |       from small pool |  16631 KiB |  32983 KiB |  18859 MiB |  18843 MiB |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |  86016 KiB | 137216 KiB | 137216 KiB |  51200 KiB |
# |       from large pool |  61440 KiB | 102400 KiB | 102400 KiB |  40960 KiB |
# |       from small pool |  24576 KiB |  34816 KiB |  34816 KiB |  10240 KiB |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |  16438 KiB |  38316 KiB |  20176 MiB |  20160 MiB |
# |       from large pool |   8568 KiB |  31256 KiB |    129 MiB |    121 MiB |
# |       from small pool |   7870 KiB |   9916 KiB |  20046 MiB |  20038 MiB |
# |---------------------------------------------------------------------------|
# | Allocations           |     440    |     620    |   76295    |   75855    |
# |       from large pool |      25    |      48    |      49    |      24    |
# |       from small pool |     415    |     595    |   76246    |   75831    |
# |---------------------------------------------------------------------------|
# | Active allocs         |     440    |     620    |   76295    |   75855    |
# |       from large pool |      25    |      48    |      49    |      24    |
# |       from small pool |     415    |     595    |   76246    |   75831    |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |      15    |      22    |      22    |       7    |
# |       from large pool |       3    |       5    |       5    |       2    |
# |       from small pool |      12    |      17    |      17    |       5    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |      10    |      19    |   29389    |   29379    |
# |       from large pool |       2    |       2    |       8    |       6    |
# |       from small pool |       8    |      17    |   29381    |   29373    |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|
#
# Translation0: {'source': "BH Başbakanı USS Harry S. Truman'ı Ziyaret EttiĢ", 'target': 'BiH Prime Minister Visits USS Harry S. TrumanĢ', 'translation': ''}
# /usr/local/lib/python3.10/dist-packages/torch/cuda/memory.py:330: FutureWarning: torch.cuda.reset_max_memory_allocated now calls torch.cuda.reset_peak_memory_stats, which resets /all/ peak memory stats.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/cuda/memory.py:356: FutureWarning: torch.cuda.reset_max_memory_cached now calls torch.cuda.reset_peak_memory_stats, which resets /all/ peak memory stats.
#   warnings.warn(
# Completed translation 1 of 9084 at 1715995054.3768227
# Completed translation 2 of 9084 at 1715995057.0813577
# Completed translation 3 of 9084 at 1715995059.7689526
# Completed translation 4 of 9084 at 1715995062.4462204
# Completed translation 5 of 9084 at 1715995065.1056085
# Completed translation 6 of 9084 at 1715995067.7579944
# Completed translation 7 of 9084 at 1715995070.452796
# Completed translation 8 of 9084 at 1715995073.131837
# Completed translation 9 of 9084 at 1715995075.7968078
# Completed translation 10 of 9084 at 1715995078.442836
# Completed translation 11 of 9084 at 1715995081.110066
# Completed translation 12 of 9084 at 1715995083.8519027
# Completed translation 13 of 9084 at 1715995086.5096586
# Completed translation 14 of 9084 at 1715995089.1555097
# Completed translation 15 of 9084 at 1715995091.814815
# Completed translation 16 of 9084 at 1715995094.534016
# Completed translation 17 of 9084 at 1715995097.1963906
# Completed translation 18 of 9084 at 1715995099.8533142
# Completed translation 19 of 9084 at 1715995102.4774752
# Completed translation 20 of 9084 at 1715995105.160227
# Completed translation 21 of 9084 at 1715995107.8653202
# Completed translation 22 of 9084 at 1715995110.542835
# Completed translation 23 of 9084 at 1715995113.1720371
# Completed translation 24 of 9084 at 1715995115.812785
# Completed translation 25 of 9084 at 1715995118.573144
# Completed translation 26 of 9084 at 1715995121.2298017
# Completed translation 27 of 9084 at 1715995123.8501248
# Completed translation 28 of 9084 at 1715995126.481453
# Completed translation 29 of 9084 at 1715995129.1749082
# Completed translation 30 of 9084 at 1715995131.93838
# Completed translation 31 of 9084 at 1715995134.6359837
# Completed translation 32 of 9084 at 1715995137.2903903
# Completed translation 33 of 9084 at 1715995139.9618719
# Completed translation 34 of 9084 at 1715995142.694225
# Completed translation 35 of 9084 at 1715995145.3446066
# Completed translation 36 of 9084 at 1715995147.9691029
# Completed translation 37 of 9084 at 1715995150.634304
# Completed translation 38 of 9084 at 1715995153.3208053
# Completed translation 39 of 9084 at 1715995156.0196218
# Completed translation 40 of 9084 at 1715995158.6702142
# Completed translation 41 of 9084 at 1715995161.336923
# Completed translation 42 of 9084 at 1715995163.9842567
# Completed translation 43 of 9084 at 1715995166.6999884
# Completed translation 44 of 9084 at 1715995169.3670888
# Completed translation 45 of 9084 at 1715995172.026418
# Completed translation 46 of 9084 at 1715995174.676082
# Completed translation 47 of 9084 at 1715995177.3296282
# Completed translation 48 of 9084 at 1715995180.01206
# Completed translation 49 of 9084 at 1715995182.685893
# Completed translation 50 of 9084 at 1715995185.4179251
# Completed translation 51 of 9084 at 1715995188.0546
# Completed translation 52 of 9084 at 1715995190.69085
# Completed translation 53 of 9084 at 1715995193.4055367
# Completed translation 54 of 9084 at 1715995196.0652523
# Completed translation 55 of 9084 at 1715995198.6991713
# Completed translation 56 of 9084 at 1715995201.3370383
# Completed translation 57 of 9084 at 1715995203.9918733
# Completed translation 58 of 9084 at 1715995206.6367953
# Completed translation 59 of 9084 at 1715995209.2877917
# Completed translation 60 of 9084 at 1715995211.9335012
# Completed translation 61 of 9084 at 1715995214.613459
# Completed translation 62 of 9084 at 1715995217.2909653
# Completed translation 63 of 9084 at 1715995219.9522967
# Completed translation 64 of 9084 at 1715995222.6129904
# Completed translation 65 of 9084 at 1715995225.2471879
# Completed translation 66 of 9084 at 1715995227.8749785
# Completed translation 67 of 9084 at 1715995230.5374606
# Completed translation 68 of 9084 at 1715995233.1873724
# Completed translation 69 of 9084 at 1715995235.8224068
# Completed translation 70 of 9084 at 1715995238.491178
# Completed translation 71 of 9084 at 1715995241.1784449
# Completed translation 72 of 9084 at 1715995243.833254
# Completed translation 73 of 9084 at 1715995246.4732168
# Completed translation 74 of 9084 at 1715995249.1162155
# Completed translation 75 of 9084 at 1715995251.75639
# Completed translation 76 of 9084 at 1715995254.417248
# Completed translation 77 of 9084 at 1715995257.0818048
# Completed translation 78 of 9084 at 1715995259.7430205
# Completed translation 79 of 9084 at 1715995262.3805065
# Completed translation 80 of 9084 at 1715995265.0331235
# Completed translation 81 of 9084 at 1715995267.6677887
# Completed translation 82 of 9084 at 1715995270.3267636
# Completed translation 83 of 9084 at 1715995272.9838986
# Completed translation 84 of 9084 at 1715995275.618051
# Completed translation 85 of 9084 at 1715995278.2551076
# Completed translation 86 of 9084 at 1715995280.902039
# Completed translation 87 of 9084 at 1715995283.5466495
# Completed translation 88 of 9084 at 1715995286.219097
# Completed translation 89 of 9084 at 1715995288.9417012
# Completed translation 90 of 9084 at 1715995291.5858119
# Completed translation 91 of 9084 at 1715995294.2618787
# Completed translation 92 of 9084 at 1715995296.9589224
# Completed translation 93 of 9084 at 1715995299.6533895
# Completed translation 94 of 9084 at 1715995302.3333874
# Completed translation 95 of 9084 at 1715995305.0317795
# Completed translation 96 of 9084 at 1715995307.6823022
# Completed translation 97 of 9084 at 1715995310.3355331
# Completed translation 98 of 9084 at 1715995313.0616097
# Completed translation 99 of 9084 at 1715995315.7059216
# Completed translation 100 of 9084 at 1715995318.3756332
# Memory usage summary:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |  69578 KiB |  81731 KiB |   1882 GiB |   1882 GiB |
# |       from large pool |  52872 KiB |  52872 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16706 KiB |  28859 KiB |   1882 GiB |   1882 GiB |
# |---------------------------------------------------------------------------|
# | Active memory         |  69578 KiB |  81731 KiB |   1882 GiB |   1882 GiB |
# |       from large pool |  52872 KiB |  52872 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16706 KiB |  28859 KiB |   1882 GiB |   1882 GiB |
# |---------------------------------------------------------------------------|
# | Requested memory      |  68055 KiB |  80191 KiB |   1882 GiB |   1882 GiB |
# |       from large pool |  51424 KiB |  51424 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16631 KiB |  28767 KiB |   1882 GiB |   1882 GiB |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |  86016 KiB |  92160 KiB | 614400 KiB | 528384 KiB |
# |       from large pool |  61440 KiB |  61440 KiB | 102400 KiB |  40960 KiB |
# |       from small pool |  24576 KiB |  30720 KiB | 512000 KiB | 487424 KiB |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |  16438 KiB |  20481 KiB |   1955 GiB |   1955 GiB |
# |       from large pool |   8568 KiB |   8568 KiB |      0 GiB |      0 GiB |
# |       from small pool |   7870 KiB |  11913 KiB |   1955 GiB |   1955 GiB |
# |---------------------------------------------------------------------------|
# | Allocations           |     440    |     623    |    7618 K  |    7618 K  |
# |       from large pool |      25    |      25    |       0 K  |       0 K  |
# |       from small pool |     415    |     598    |    7618 K  |    7618 K  |
# |---------------------------------------------------------------------------|
# | Active allocs         |     440    |     623    |    7618 K  |    7618 K  |
# |       from large pool |      25    |      25    |       0 K  |       0 K  |
# |       from small pool |     415    |     598    |    7618 K  |    7618 K  |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |      15    |      18    |     255    |     240    |
# |       from large pool |       3    |       3    |       5    |       2    |
# |       from small pool |      12    |      15    |     250    |     238    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |      10    |      23    |    2952 K  |    2952 K  |
# |       from large pool |       2    |       2    |       0 K  |       0 K  |
# |       from small pool |       8    |      21    |    2952 K  |    2952 K  |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|
#
# Translation100: {'source': 'Romanya Depremden Zarar Gören Binaları GüçlendirecekĢ', 'target': 'Romania to Reinforce Earthquake-Endangered BuildingsĢ', 'translation': ''}
# Completed translation 101 of 9084 at 1715995321.0640235
# Completed translation 102 of 9084 at 1715995323.7322295
# Completed translation 103 of 9084 at 1715995326.4284778
# Completed translation 104 of 9084 at 1715995329.0837827
# Completed translation 105 of 9084 at 1715995331.7485409
# Completed translation 106 of 9084 at 1715995334.4200478
# Completed translation 107 of 9084 at 1715995337.0850139
# Completed translation 108 of 9084 at 1715995339.8007245
# Completed translation 109 of 9084 at 1715995342.5051143
# Completed translation 110 of 9084 at 1715995345.151564
# Completed translation 111 of 9084 at 1715995347.835049
# Completed translation 112 of 9084 at 1715995350.5459056
# Completed translation 113 of 9084 at 1715995353.1809487
# Completed translation 114 of 9084 at 1715995355.8464596
# Completed translation 115 of 9084 at 1715995358.5032642
# Completed translation 116 of 9084 at 1715995361.2264469
# Completed translation 117 of 9084 at 1715995363.9096053
# Completed translation 118 of 9084 at 1715995366.592188
# Completed translation 119 of 9084 at 1715995369.2506704
# Completed translation 120 of 9084 at 1715995371.9088085
# Completed translation 121 of 9084 at 1715995374.6130664
# Completed translation 122 of 9084 at 1715995377.2466488
# Completed translation 123 of 9084 at 1715995379.8763206
# Completed translation 124 of 9084 at 1715995382.5178158
# Completed translation 125 of 9084 at 1715995385.2072966
# Completed translation 126 of 9084 at 1715995387.8600829
# Completed translation 127 of 9084 at 1715995390.5561016
# Completed translation 128 of 9084 at 1715995393.1923132
# Completed translation 129 of 9084 at 1715995395.8808
# Completed translation 130 of 9084 at 1715995398.6025639
# Completed translation 131 of 9084 at 1715995401.2778182
# Completed translation 132 of 9084 at 1715995403.9340718
# Completed translation 133 of 9084 at 1715995406.5801537
# Completed translation 134 of 9084 at 1715995409.267688
# Completed translation 135 of 9084 at 1715995411.9418871
# Completed translation 136 of 9084 at 1715995414.6444056
# Completed translation 137 of 9084 at 1715995417.2817485
# Completed translation 138 of 9084 at 1715995419.9376163
# Completed translation 139 of 9084 at 1715995422.5995393
# Completed translation 140 of 9084 at 1715995425.2673273
# Completed translation 141 of 9084 at 1715995427.9438415
# Completed translation 142 of 9084 at 1715995430.586644
# Completed translation 143 of 9084 at 1715995433.2567015
# Completed translation 144 of 9084 at 1715995435.9330516
# Completed translation 145 of 9084 at 1715995438.6228528
# Completed translation 146 of 9084 at 1715995441.2578533
# Completed translation 147 of 9084 at 1715995443.9069347
# Completed translation 148 of 9084 at 1715995446.5880923
# Completed translation 149 of 9084 at 1715995449.2480726
# Completed translation 150 of 9084 at 1715995451.9056897
# Completed translation 151 of 9084 at 1715995454.55639
# Completed translation 152 of 9084 at 1715995457.2152786
# Completed translation 153 of 9084 at 1715995459.9271653
# Completed translation 154 of 9084 at 1715995462.570205
# Completed translation 155 of 9084 at 1715995465.2439914
# Completed translation 156 of 9084 at 1715995467.9211278
# Completed translation 157 of 9084 at 1715995470.6266122
# Completed translation 158 of 9084 at 1715995473.3487587
# Completed translation 159 of 9084 at 1715995476.0140157
# Completed translation 160 of 9084 at 1715995478.643878
# Completed translation 161 of 9084 at 1715995481.2961717
# Completed translation 162 of 9084 at 1715995484.006424
# Completed translation 163 of 9084 at 1715995486.6554506
# Completed translation 164 of 9084 at 1715995489.3101814
# Completed translation 165 of 9084 at 1715995491.9772274
# Completed translation 166 of 9084 at 1715995494.6647131
# Completed translation 167 of 9084 at 1715995497.340173
# Completed translation 168 of 9084 at 1715995499.9909744
# Completed translation 169 of 9084 at 1715995502.6296904
# Completed translation 170 of 9084 at 1715995505.2858784
# Completed translation 171 of 9084 at 1715995507.9635382
# Completed translation 172 of 9084 at 1715995510.6076386
# Completed translation 173 of 9084 at 1715995513.2884555
# Completed translation 174 of 9084 at 1715995515.9408028
# Completed translation 175 of 9084 at 1715995518.6152225
# Completed translation 176 of 9084 at 1715995521.284461
# Completed translation 177 of 9084 at 1715995523.923012
# Completed translation 178 of 9084 at 1715995526.5675864
# Completed translation 179 of 9084 at 1715995529.2273998
# Completed translation 180 of 9084 at 1715995531.906482
# Completed translation 181 of 9084 at 1715995534.525727
# Completed translation 182 of 9084 at 1715995537.1723347
# Completed translation 183 of 9084 at 1715995539.8254888
# Completed translation 184 of 9084 at 1715995542.4695816
# Completed translation 185 of 9084 at 1715995545.1598825
# Completed translation 186 of 9084 at 1715995547.8004878
# Completed translation 187 of 9084 at 1715995550.47327
# Completed translation 188 of 9084 at 1715995553.1452165
# Completed translation 189 of 9084 at 1715995555.8207674
# Completed translation 190 of 9084 at 1715995558.485837
# Completed translation 191 of 9084 at 1715995561.1615272
# Completed translation 192 of 9084 at 1715995563.8006012
# Completed translation 193 of 9084 at 1715995566.4440277
# Completed translation 194 of 9084 at 1715995569.117523
# Completed translation 195 of 9084 at 1715995571.7692313
# Completed translation 196 of 9084 at 1715995574.4345014
# Completed translation 197 of 9084 at 1715995577.1117191
# Completed translation 198 of 9084 at 1715995579.7876554
# Completed translation 199 of 9084 at 1715995582.4311576
# Completed translation 200 of 9084 at 1715995585.065048
# Memory usage summary:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |  69578 KiB |  82360 KiB |   3781 GiB |   3781 GiB |
# |       from large pool |  52872 KiB |  52872 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16706 KiB |  29488 KiB |   3781 GiB |   3781 GiB |
# |---------------------------------------------------------------------------|
# | Active memory         |  69578 KiB |  82360 KiB |   3781 GiB |   3781 GiB |
# |       from large pool |  52872 KiB |  52872 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16706 KiB |  29488 KiB |   3781 GiB |   3781 GiB |
# |---------------------------------------------------------------------------|
# | Requested memory      |  68055 KiB |  80821 KiB |   3780 GiB |   3780 GiB |
# |       from large pool |  51424 KiB |  51424 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16631 KiB |  29397 KiB |   3780 GiB |   3780 GiB |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |  86016 KiB |  92160 KiB |   1194 MiB |   1110 MiB |
# |       from large pool |  61440 KiB |  61440 KiB |    100 MiB |     40 MiB |
# |       from small pool |  24576 KiB |  30720 KiB |   1094 MiB |   1070 MiB |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |  16438 KiB |  20454 KiB |   3932 GiB |   3932 GiB |
# |       from large pool |   8568 KiB |   8568 KiB |      0 GiB |      0 GiB |
# |       from small pool |   7870 KiB |  11886 KiB |   3932 GiB |   3932 GiB |
# |---------------------------------------------------------------------------|
# | Allocations           |     440    |     621    |   15161 K  |   15161 K  |
# |       from large pool |      25    |      25    |       0 K  |       0 K  |
# |       from small pool |     415    |     596    |   15161 K  |   15161 K  |
# |---------------------------------------------------------------------------|
# | Active allocs         |     440    |     621    |   15161 K  |   15161 K  |
# |       from large pool |      25    |      25    |       0 K  |       0 K  |
# |       from small pool |     415    |     596    |   15161 K  |   15161 K  |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |      15    |      18    |     552    |     537    |
# |       from large pool |       3    |       3    |       5    |       2    |
# |       from small pool |      12    |      15    |     547    |     535    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |      10    |      22    |    5925 K  |    5925 K  |
# |       from large pool |       2    |       2    |       0 K  |       0 K  |
# |       from small pool |       8    |      20    |    5925 K  |    5925 K  |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|
#
# Translation200: {'source': 'Bu hafta ayrıca: Korsanlar Sırp web sitelerini hedef aldılar.Ģ', 'target': 'Also this week: hackers target Serbian websites.Ģ', 'translation': ''}
# Completed translation 201 of 9084 at 1715995587.741105
# Completed translation 202 of 9084 at 1715995590.405129
# Completed translation 203 of 9084 at 1715995593.0889323
# Completed translation 204 of 9084 at 1715995595.7301445
# Completed translation 205 of 9084 at 1715995598.3549554
# Completed translation 206 of 9084 at 1715995600.9728324
# Completed translation 207 of 9084 at 1715995603.628927
# Completed translation 208 of 9084 at 1715995606.2745166
# Completed translation 209 of 9084 at 1715995608.9623866
# Completed translation 210 of 9084 at 1715995611.6032717
# Completed translation 211 of 9084 at 1715995614.2223105
# Completed translation 212 of 9084 at 1715995616.9293897
# Completed translation 213 of 9084 at 1715995619.6410964
# Completed translation 214 of 9084 at 1715995622.295537
# Completed translation 215 of 9084 at 1715995624.9151614
# Completed translation 216 of 9084 at 1715995627.58684
# Completed translation 217 of 9084 at 1715995630.2592263
# Completed translation 218 of 9084 at 1715995632.8850636
# Completed translation 219 of 9084 at 1715995635.526879
# Completed translation 220 of 9084 at 1715995638.2006922
# Completed translation 221 of 9084 at 1715995640.8992703
# Completed translation 222 of 9084 at 1715995643.570436
# Completed translation 223 of 9084 at 1715995646.2405148
# Completed translation 224 of 9084 at 1715995648.9281363
# Completed translation 225 of 9084 at 1715995651.615385
# Completed translation 226 of 9084 at 1715995654.2890456
# Completed translation 227 of 9084 at 1715995656.9449697
# Completed translation 228 of 9084 at 1715995659.5582094
# Completed translation 229 of 9084 at 1715995662.225325
# Completed translation 230 of 9084 at 1715995664.914356
# Completed translation 231 of 9084 at 1715995667.5663269
# Completed translation 232 of 9084 at 1715995670.2025487
# Completed translation 233 of 9084 at 1715995672.8576446
# Completed translation 234 of 9084 at 1715995675.523975
# Completed translation 235 of 9084 at 1715995678.2301455
# Completed translation 236 of 9084 at 1715995680.8908503
# Completed translation 237 of 9084 at 1715995683.524374
# Completed translation 238 of 9084 at 1715995686.1765635
# Completed translation 239 of 9084 at 1715995688.827626
# Completed translation 240 of 9084 at 1715995691.505107
# Completed translation 241 of 9084 at 1715995694.1494935
# Completed translation 242 of 9084 at 1715995696.8035114
# Completed translation 243 of 9084 at 1715995699.449423
# Completed translation 244 of 9084 at 1715995702.1404848
# Completed translation 245 of 9084 at 1715995704.808899
# Completed translation 246 of 9084 at 1715995707.4428418
# Completed translation 247 of 9084 at 1715995710.102024
# Completed translation 248 of 9084 at 1715995712.7496264
# Completed translation 249 of 9084 at 1715995715.4967146
# Completed translation 250 of 9084 at 1715995718.1459253
# Completed translation 251 of 9084 at 1715995720.8058786
# Completed translation 252 of 9084 at 1715995723.4688935
# Completed translation 253 of 9084 at 1715995726.116901
# Completed translation 254 of 9084 at 1715995728.791193
# Completed translation 255 of 9084 at 1715995731.4531894
# Completed translation 256 of 9084 at 1715995734.079894
# Completed translation 257 of 9084 at 1715995736.7383504
# Completed translation 258 of 9084 at 1715995739.4134827
# Completed translation 259 of 9084 at 1715995742.0730107
# Completed translation 260 of 9084 at 1715995744.7114637
# Completed translation 261 of 9084 at 1715995747.3618097
# Completed translation 262 of 9084 at 1715995750.0423815
# Completed translation 263 of 9084 at 1715995752.6919236
# Completed translation 264 of 9084 at 1715995755.3228781
# Completed translation 265 of 9084 at 1715995757.9625459
# Completed translation 266 of 9084 at 1715995760.5993097
# Completed translation 267 of 9084 at 1715995763.2661054
# Completed translation 268 of 9084 at 1715995765.9155476
# Completed translation 269 of 9084 at 1715995768.5665712
# Completed translation 270 of 9084 at 1715995771.2215035
# Completed translation 271 of 9084 at 1715995773.9122236
# Completed translation 272 of 9084 at 1715995776.578437
# Completed translation 273 of 9084 at 1715995779.227496
# Completed translation 274 of 9084 at 1715995781.8486073
# Completed translation 275 of 9084 at 1715995784.482253
# Completed translation 276 of 9084 at 1715995787.1492112
# Completed translation 277 of 9084 at 1715995789.7912247
# Completed translation 278 of 9084 at 1715995792.4080956
# Completed translation 279 of 9084 at 1715995795.0459352
# Completed translation 280 of 9084 at 1715995797.7027617
# Completed translation 281 of 9084 at 1715995800.3653755
# Completed translation 282 of 9084 at 1715995803.0276656
# Completed translation 283 of 9084 at 1715995805.6573565
# Completed translation 284 of 9084 at 1715995808.2966764
# Completed translation 285 of 9084 at 1715995810.9559026
# Completed translation 286 of 9084 at 1715995813.6445215
# Completed translation 287 of 9084 at 1715995816.3063974
# Completed translation 288 of 9084 at 1715995818.9254956
# Completed translation 289 of 9084 at 1715995821.5610251
# Completed translation 290 of 9084 at 1715995824.24069
# Completed translation 291 of 9084 at 1715995826.909249
# Completed translation 292 of 9084 at 1715995829.5364435
# Completed translation 293 of 9084 at 1715995832.1619895
# Completed translation 294 of 9084 at 1715995834.8511882
# Completed translation 295 of 9084 at 1715995837.5372443
# Completed translation 296 of 9084 at 1715995840.210439
# Completed translation 297 of 9084 at 1715995842.8631036
# Completed translation 298 of 9084 at 1715995845.515817
# Completed translation 299 of 9084 at 1715995848.2051
# Completed translation 300 of 9084 at 1715995850.8668587
# Memory usage summary:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |  69578 KiB |  83060 KiB |   5706 GiB |   5706 GiB |
# |       from large pool |  52872 KiB |  52872 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16706 KiB |  30188 KiB |   5706 GiB |   5706 GiB |
# |---------------------------------------------------------------------------|
# | Active memory         |  69578 KiB |  83060 KiB |   5706 GiB |   5706 GiB |
# |       from large pool |  52872 KiB |  52872 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16706 KiB |  30188 KiB |   5706 GiB |   5706 GiB |
# |---------------------------------------------------------------------------|
# | Requested memory      |  68055 KiB |  81518 KiB |   5705 GiB |   5705 GiB |
# |       from large pool |  51424 KiB |  51424 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16631 KiB |  30094 KiB |   5705 GiB |   5705 GiB |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |  86016 KiB |  92160 KiB |   1794 MiB |   1710 MiB |
# |       from large pool |  61440 KiB |  61440 KiB |    100 MiB |     40 MiB |
# |       from small pool |  24576 KiB |  30720 KiB |   1694 MiB |   1670 MiB |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |  16438 KiB |  20496 KiB |   5951 GiB |   5951 GiB |
# |       from large pool |   8568 KiB |   8568 KiB |      0 GiB |      0 GiB |
# |       from small pool |   7870 KiB |  11928 KiB |   5951 GiB |   5951 GiB |
# |---------------------------------------------------------------------------|
# | Allocations           |     440    |     623    |   22704 K  |   22703 K  |
# |       from large pool |      25    |      25    |       0 K  |       0 K  |
# |       from small pool |     415    |     598    |   22704 K  |   22703 K  |
# |---------------------------------------------------------------------------|
# | Active allocs         |     440    |     623    |   22704 K  |   22703 K  |
# |       from large pool |      25    |      25    |       0 K  |       0 K  |
# |       from small pool |     415    |     598    |   22704 K  |   22703 K  |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |      15    |      18    |     852    |     837    |
# |       from large pool |       3    |       3    |       5    |       2    |
# |       from small pool |      12    |      15    |     847    |     835    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |      10    |      23    |    8961 K  |    8961 K  |
# |       from large pool |       2    |       2    |       0 K  |       0 K  |
# |       from small pool |       8    |      21    |    8961 K  |    8961 K  |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|
#
# Translation300: {'source': '"Bir Zamanlar Kardeştiler" tarihi bir dostluğun öyküsünü anlatıyorĢ', 'target': '"Once Brothers" documents an historic friendshipĢ', 'translation': ''}
# Completed translation 301 of 9084 at 1715995853.5404477
# Completed translation 302 of 9084 at 1715995856.1687775
# Completed translation 303 of 9084 at 1715995858.8445592
# Completed translation 304 of 9084 at 1715995861.5500247
# Completed translation 305 of 9084 at 1715995864.1989212
# Completed translation 306 of 9084 at 1715995866.839387
# Completed translation 307 of 9084 at 1715995869.4797857
# Completed translation 308 of 9084 at 1715995872.15972
# Completed translation 309 of 9084 at 1715995874.8072608
# Completed translation 310 of 9084 at 1715995877.4680867
# Completed translation 311 of 9084 at 1715995880.116272
# Completed translation 312 of 9084 at 1715995882.7836435
# Completed translation 313 of 9084 at 1715995885.437809
# Completed translation 314 of 9084 at 1715995888.072635
# Completed translation 315 of 9084 at 1715995890.7295318
# Completed translation 316 of 9084 at 1715995893.3754377
# Completed translation 317 of 9084 at 1715995896.0272517
# Completed translation 318 of 9084 at 1715995898.6984782
# Completed translation 319 of 9084 at 1715995901.3781102
# Completed translation 320 of 9084 at 1715995904.0099378
# Completed translation 321 of 9084 at 1715995906.6630087
# Completed translation 322 of 9084 at 1715995909.3229597
# Completed translation 323 of 9084 at 1715995911.9674425
# Completed translation 324 of 9084 at 1715995914.6023571
# Completed translation 325 of 9084 at 1715995917.2170331
# Completed translation 326 of 9084 at 1715995919.8533328
# Completed translation 327 of 9084 at 1715995922.5294902
# Completed translation 328 of 9084 at 1715995925.1745288
# Completed translation 329 of 9084 at 1715995927.820695
# Completed translation 330 of 9084 at 1715995930.4629238
# Completed translation 331 of 9084 at 1715995933.1368418
# Completed translation 332 of 9084 at 1715995935.7895513
# Completed translation 333 of 9084 at 1715995938.4326448
# Completed translation 334 of 9084 at 1715995941.0661058
# Completed translation 335 of 9084 at 1715995943.7398305
# Completed translation 336 of 9084 at 1715995946.3932369
# Completed translation 337 of 9084 at 1715995949.0343518
# Completed translation 338 of 9084 at 1715995951.6796305
# Completed translation 339 of 9084 at 1715995954.305368
# Completed translation 340 of 9084 at 1715995956.989162
# Completed translation 341 of 9084 at 1715995959.6639135
# Completed translation 342 of 9084 at 1715995962.3162053
# Completed translation 343 of 9084 at 1715995964.9726803
# Completed translation 344 of 9084 at 1715995967.6067255
# Completed translation 345 of 9084 at 1715995970.24826
# Completed translation 346 of 9084 at 1715995972.89461
# Completed translation 347 of 9084 at 1715995975.5138843
# Completed translation 348 of 9084 at 1715995978.1548312
# Completed translation 349 of 9084 at 1715995980.7972398
# Completed translation 350 of 9084 at 1715995983.4389548
# Completed translation 351 of 9084 at 1715995986.1030412
# Completed translation 352 of 9084 at 1715995988.743624
# Completed translation 353 of 9084 at 1715995991.3787117
# Completed translation 354 of 9084 at 1715995994.0558043
# Completed translation 355 of 9084 at 1715995996.698027
# Completed translation 356 of 9084 at 1715995999.3374848
# Completed translation 357 of 9084 at 1715996001.9959424
# Completed translation 358 of 9084 at 1715996004.6678836
# Completed translation 359 of 9084 at 1715996007.3222733
# Completed translation 360 of 9084 at 1715996009.9812756
# Completed translation 361 of 9084 at 1715996012.6159859
# Completed translation 362 of 9084 at 1715996015.2487025
# Completed translation 363 of 9084 at 1715996017.8915458
# Completed translation 364 of 9084 at 1715996020.5602367
# Completed translation 365 of 9084 at 1715996023.2202396
# Completed translation 366 of 9084 at 1715996025.8499596
# Completed translation 367 of 9084 at 1715996028.4891682
# Completed translation 368 of 9084 at 1715996031.164006
# Completed translation 369 of 9084 at 1715996033.8052862
# Completed translation 370 of 9084 at 1715996036.4424553
# Completed translation 371 of 9084 at 1715996039.0791714
# Completed translation 372 of 9084 at 1715996041.7329648
# Completed translation 373 of 9084 at 1715996044.405969
# Completed translation 374 of 9084 at 1715996047.060827
# Completed translation 375 of 9084 at 1715996049.7002556
# Completed translation 376 of 9084 at 1715996052.332164
# Completed translation 377 of 9084 at 1715996055.0856483
# Completed translation 378 of 9084 at 1715996057.7300339
# Completed translation 379 of 9084 at 1715996060.4079373
# Completed translation 380 of 9084 at 1715996063.1003351
# Completed translation 381 of 9084 at 1715996065.7516418
# Completed translation 382 of 9084 at 1715996068.4528344
# Completed translation 383 of 9084 at 1715996071.1025372
# Completed translation 384 of 9084 at 1715996073.7769978
# Completed translation 385 of 9084 at 1715996076.442444
# Completed translation 386 of 9084 at 1715996079.091015
# Completed translation 387 of 9084 at 1715996081.7631967
# Completed translation 388 of 9084 at 1715996084.4076855
# Completed translation 389 of 9084 at 1715996087.0443676
# Completed translation 390 of 9084 at 1715996089.678961
# Completed translation 391 of 9084 at 1715996092.3478072
# Completed translation 392 of 9084 at 1715996095.0068
# Completed translation 393 of 9084 at 1715996097.6564038
# Completed translation 394 of 9084 at 1715996100.2901196
# Completed translation 395 of 9084 at 1715996102.947837
# Completed translation 396 of 9084 at 1715996105.6160698
# Completed translation 397 of 9084 at 1715996108.296352
# Completed translation 398 of 9084 at 1715996110.9474826
# Completed translation 399 of 9084 at 1715996113.6061368
# Completed translation 400 of 9084 at 1715996116.350125
# Memory usage summary:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |  69578 KiB |  83661 KiB |   7647 GiB |   7647 GiB |
# |       from large pool |  52872 KiB |  52872 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16706 KiB |  30789 KiB |   7647 GiB |   7647 GiB |
# |---------------------------------------------------------------------------|
# | Active memory         |  69578 KiB |  83661 KiB |   7647 GiB |   7647 GiB |
# |       from large pool |  52872 KiB |  52872 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16706 KiB |  30789 KiB |   7647 GiB |   7647 GiB |
# |---------------------------------------------------------------------------|
# | Requested memory      |  68055 KiB |  82120 KiB |   7645 GiB |   7645 GiB |
# |       from large pool |  51424 KiB |  51424 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16631 KiB |  30696 KiB |   7645 GiB |   7645 GiB |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |  86016 KiB |  94208 KiB |   2440 MiB |   2356 MiB |
# |       from large pool |  61440 KiB |  61440 KiB |    100 MiB |     40 MiB |
# |       from small pool |  24576 KiB |  32768 KiB |   2340 MiB |   2316 MiB |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |  16438 KiB |  22343 KiB |   7991 GiB |   7991 GiB |
# |       from large pool |   8568 KiB |   8568 KiB |      0 GiB |      0 GiB |
# |       from small pool |   7870 KiB |  13775 KiB |   7991 GiB |   7991 GiB |
# |---------------------------------------------------------------------------|
# | Allocations           |     440    |     621    |   30246 K  |   30246 K  |
# |       from large pool |      25    |      25    |       0 K  |       0 K  |
# |       from small pool |     415    |     596    |   30246 K  |   30246 K  |
# |---------------------------------------------------------------------------|
# | Active allocs         |     440    |     621    |   30246 K  |   30246 K  |
# |       from large pool |      25    |      25    |       0 K  |       0 K  |
# |       from small pool |     415    |     596    |   30246 K  |   30246 K  |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |      15    |      19    |    1175    |    1160    |
# |       from large pool |       3    |       3    |       5    |       2    |
# |       from small pool |      12    |      16    |    1170    |    1158    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |      10    |      24    |   11986 K  |   11986 K  |
# |       from large pool |       2    |       2    |       0 K  |       0 K  |
# |       from small pool |       8    |      22    |   11986 K  |   11986 K  |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|
#
# Translation400: {'source': '10 Ülkeden Uzmanlar Balkan Sinemasının Tarihini YazdıĢ', 'target': 'Specialists from 10 Countries Write History of Film in the BalkansĢ', 'translation': ''}
# Completed translation 401 of 9084 at 1715996119.0260317
# Completed translation 402 of 9084 at 1715996121.6720197
# Completed translation 403 of 9084 at 1715996124.3276167
# Completed translation 404 of 9084 at 1715996126.981531
# Completed translation 405 of 9084 at 1715996129.632851
# Completed translation 406 of 9084 at 1715996132.3102279
# Completed translation 407 of 9084 at 1715996134.9808574
# Completed translation 408 of 9084 at 1715996137.6391747
# Completed translation 409 of 9084 at 1715996140.2989118
# Completed translation 410 of 9084 at 1715996142.9602823
# Completed translation 411 of 9084 at 1715996145.6560838
# Completed translation 412 of 9084 at 1715996148.318295
# Completed translation 413 of 9084 at 1715996150.970564
# Completed translation 414 of 9084 at 1715996153.6235476
# Completed translation 415 of 9084 at 1715996156.253325
# Completed translation 416 of 9084 at 1715996158.908055
# Completed translation 417 of 9084 at 1715996161.5285184
# Completed translation 418 of 9084 at 1715996164.1855354
# Completed translation 419 of 9084 at 1715996166.8567138
# Completed translation 420 of 9084 at 1715996169.5133402
# Completed translation 421 of 9084 at 1715996172.1534138
# Completed translation 422 of 9084 at 1715996174.7856135
# Completed translation 423 of 9084 at 1715996177.434436
# Completed translation 424 of 9084 at 1715996180.089987
# Completed translation 425 of 9084 at 1715996182.7282226
# Completed translation 426 of 9084 at 1715996185.369418
# Completed translation 427 of 9084 at 1715996188.0194962
# Completed translation 428 of 9084 at 1715996190.6960967
# Completed translation 429 of 9084 at 1715996193.348196
# Completed translation 430 of 9084 at 1715996195.9831395
# Completed translation 431 of 9084 at 1715996198.6282933
# Completed translation 432 of 9084 at 1715996201.2887201
# Completed translation 433 of 9084 at 1715996203.966979
# Completed translation 434 of 9084 at 1715996206.6124125
# Completed translation 435 of 9084 at 1715996209.2684534
# Completed translation 436 of 9084 at 1715996211.900242
# Completed translation 437 of 9084 at 1715996214.555321
# Completed translation 438 of 9084 at 1715996217.2088532
# Completed translation 439 of 9084 at 1715996219.8862057
# Completed translation 440 of 9084 at 1715996222.5231464
# Completed translation 441 of 9084 at 1715996225.2020495
# Completed translation 442 of 9084 at 1715996227.8372016
# Completed translation 443 of 9084 at 1715996230.494036
# Completed translation 444 of 9084 at 1715996233.163987
# Completed translation 445 of 9084 at 1715996235.8125849
# Completed translation 446 of 9084 at 1715996238.4869719
# Completed translation 447 of 9084 at 1715996241.1390374
# Completed translation 448 of 9084 at 1715996243.79682
# Completed translation 449 of 9084 at 1715996246.4623742
# Completed translation 450 of 9084 at 1715996249.1788037
# Completed translation 451 of 9084 at 1715996251.8617084
# Completed translation 452 of 9084 at 1715996254.5117283
# Completed translation 453 of 9084 at 1715996257.1637874
# Completed translation 454 of 9084 at 1715996259.8286328
# Completed translation 455 of 9084 at 1715996262.4786386
# Completed translation 456 of 9084 at 1715996265.1369302
# Completed translation 457 of 9084 at 1715996267.7725265
# Completed translation 458 of 9084 at 1715996270.4159274
# Completed translation 459 of 9084 at 1715996273.0599382
# Completed translation 460 of 9084 at 1715996275.7471702
# Completed translation 461 of 9084 at 1715996278.4019108
# Completed translation 462 of 9084 at 1715996281.0600057
# Completed translation 463 of 9084 at 1715996283.702086
# Completed translation 464 of 9084 at 1715996286.3610427
# ...
# Completed translation 3180 of 9084 at 1716003569.3739874
# Completed translation 3181 of 9084 at 1716003572.0318484
# Completed translation 3182 of 9084 at 1716003574.7223222
# Completed translation 3183 of 9084 at 1716003577.407188
# Completed translation 3184 of 9084 at 1716003580.1284292
# Completed translation 3185 of 9084 at 1716003582.8331795
# Completed translation 3186 of 9084 at 1716003585.535696
# Completed translation 3187 of 9084 at 1716003588.2215126
# Completed translation 3188 of 9084 at 1716003590.9437106
# Completed translation 3189 of 9084 at 1716003593.6485279
# Completed translation 3190 of 9084 at 1716003596.356227
# Completed translation 3191 of 9084 at 1716003599.0852458
# Completed translation 3192 of 9084 at 1716003601.7917244
# Completed translation 3193 of 9084 at 1716003604.5046842
# Completed translation 3194 of 9084 at 1716003607.182917
# Completed translation 3195 of 9084 at 1716003609.8766768
# Completed translation 3196 of 9084 at 1716003612.5680995
# Completed translation 3197 of 9084 at 1716003615.2480986
# Completed translation 3198 of 9084 at 1716003617.9411833
# Completed translation 3199 of 9084 at 1716003620.6452553
# Completed translation 3200 of 9084 at 1716003623.3485012
# Memory usage summary:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |  69578 KiB |  93398 KiB |  67525 GiB |  67525 GiB |
# |       from large pool |  52872 KiB |  57537 KiB |      2 GiB |      2 GiB |
# |       from small pool |  16706 KiB |  40526 KiB |  67523 GiB |  67523 GiB |
# |---------------------------------------------------------------------------|
# | Active memory         |  69578 KiB |  93398 KiB |  67525 GiB |  67525 GiB |
# |       from large pool |  52872 KiB |  57537 KiB |      2 GiB |      2 GiB |
# |       from small pool |  16706 KiB |  40526 KiB |  67523 GiB |  67523 GiB |
# |---------------------------------------------------------------------------|
# | Requested memory      |  68055 KiB |  91871 KiB |  67511 GiB |  67511 GiB |
# |       from large pool |  51424 KiB |  55717 KiB |      2 GiB |      2 GiB |
# |       from small pool |  16631 KiB |  40447 KiB |  67509 GiB |  67509 GiB |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |  86016 KiB | 104448 KiB |  36390 MiB |  36306 MiB |
# |       from large pool |  61440 KiB |  61440 KiB |    100 MiB |     40 MiB |
# |       from small pool |  24576 KiB |  43008 KiB |  36290 MiB |  36266 MiB |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |  16438 KiB |  26399 KiB |  71745 GiB |  71745 GiB |
# |       from large pool |   8568 KiB |   8568 KiB |      2 GiB |      2 GiB |
# |       from small pool |   7870 KiB |  17831 KiB |  71743 GiB |  71743 GiB |
# |---------------------------------------------------------------------------|
# | Allocations           |     440    |     622    |  241439 K  |  241439 K  |
# |       from large pool |      25    |      29    |       2 K  |       2 K  |
# |       from small pool |     415    |     597    |  241437 K  |  241437 K  |
# |---------------------------------------------------------------------------|
# | Active allocs         |     440    |     622    |  241439 K  |  241439 K  |
# |       from large pool |      25    |      29    |       2 K  |       2 K  |
# |       from small pool |     415    |     597    |  241437 K  |  241437 K  |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |      15    |      24    |   18150    |   18135    |
# |       from large pool |       3    |       3    |       5    |       2    |
# |       from small pool |      12    |      21    |   18145    |   18133    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |      10    |      27    |   99482 K  |   99482 K  |
# |       from large pool |       2    |       3    |       1 K  |       1 K  |
# |       from small pool |       8    |      25    |   99481 K  |   99481 K  |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|
#
# Translation3200: {'source': 'Kültür Bakanı Razvan Theodorescu ile Eğitim Bakanı Alexandru Athanasiu beklenenin altında oy aldılar.Ģ', 'target': 'Culture Minister Razvan Theodorescu and Education Minister Alexandru Athanasiu got fewer votes than expected.Ģ', 'translation': 'sKKKDDPKKPD9KD99PP9K99PK99DDD99D9P9DPK9KKKDP9K9KDPDPD999KK99K9KP9PDDPDPK9K9DD999PPKDPKD)?)]ġ]])ġ)ġ)]ġ]ġ]ġ?ġ)ġ?]?)))]ġ]?ġ?ġ))?])ġġ]]))?ġ])])??ġ?)???ġ??ġ)ġ?ġ]]?ġ])ġ???)))ġ?ġ?ġ?ġġ]])??ġ)ġ])ġ??]]?]ġġ]ġ?ġ)?ġ)ġ]ġ?]])ġ)??)??ġ)])?ġ??ġ)))ġġ))??ġġ])??ġ))???])?]ġ?]ġ?'}
# Completed translation 3201 of 9084 at 1716003626.088421
# Completed translation 3202 of 9084 at 1716003628.8258562
# Completed translation 3203 of 9084 at 1716003631.4886847
# Completed translation 3204 of 9084 at 1716003634.1813555
# Completed translation 3205 of 9084 at 1716003636.9011555
# Completed translation 3206 of 9084 at 1716003639.6028185
# Completed translation 3207 of 9084 at 1716003642.299419
# Completed translation 3208 of 9084 at 1716003645.0175197
# Completed translation 3209 of 9084 at 1716003647.7280395
# Completed translation 3210 of 9084 at 1716003650.4533525
# Completed translation 3211 of 9084 at 1716003653.193255
# Completed translation 3212 of 9084 at 1716003655.9360125
# Completed translation 3213 of 9084 at 1716003658.6089962
# Completed translation 3214 of 9084 at 1716003661.3218665
# Completed translation 3215 of 9084 at 1716003664.0326316
# Completed translation 3216 of 9084 at 1716003666.7324982
# Completed translation 3217 of 9084 at 1716003669.4361882
# Completed translation 3218 of 9084 at 1716003672.1420846
# Completed translation 3219 of 9084 at 1716003674.872566
# Completed translation 3220 of 9084 at 1716003677.6321588
# Completed translation 3221 of 9084 at 1716003680.3266547
# Completed translation 3222 of 9084 at 1716003683.0204601
# Completed translation 3223 of 9084 at 1716003685.7079983
# Completed translation 3224 of 9084 at 1716003688.3795974
# Completed translation 3225 of 9084 at 1716003691.0706086
# Completed translation 3226 of 9084 at 1716003693.7393572
# Completed translation 3227 of 9084 at 1716003696.4277816
# Completed translation 3228 of 9084 at 1716003699.1229033
# Completed translation 3229 of 9084 at 1716003701.8391554
# Completed translation 3230 of 9084 at 1716003704.563003
# Completed translation 3231 of 9084 at 1716003707.2380872
# Completed translation 3232 of 9084 at 1716003709.940386
# Completed translation 3233 of 9084 at 1716003712.653991
# Completed translation 3234 of 9084 at 1716003715.359864
# Completed translation 3235 of 9084 at 1716003718.052519
# Completed translation 3236 of 9084 at 1716003720.736301
# Completed translation 3237 of 9084 at 1716003723.4412336
# Completed translation 3238 of 9084 at 1716003726.1533637
# Completed translation 3239 of 9084 at 1716003728.836551
# Completed translation 3240 of 9084 at 1716003731.4984229
# Completed translation 3241 of 9084 at 1716003734.2136474
# Completed translation 3242 of 9084 at 1716003736.9344232
# Completed translation 3243 of 9084 at 1716003739.6704924
# Completed translation 3244 of 9084 at 1716003742.3733075
# Completed translation 3245 of 9084 at 1716003745.068106
# Completed translation 3246 of 9084 at 1716003747.7677927
# Completed translation 3247 of 9084 at 1716003750.4963324
# Completed translation 3248 of 9084 at 1716003753.1849272
# Completed translation 3249 of 9084 at 1716003755.8707085
# Completed translation 3250 of 9084 at 1716003758.5742323
# Completed translation 3251 of 9084 at 1716003761.288268
# Completed translation 3252 of 9084 at 1716003764.024796
# Completed translation 3253 of 9084 at 1716003766.7082443
# Completed translation 3254 of 9084 at 1716003769.4059324
# Completed translation 3255 of 9084 at 1716003772.088448
# Completed translation 3256 of 9084 at 1716003774.785474
# Completed translation 3257 of 9084 at 1716003777.489793
# Completed translation 3258 of 9084 at 1716003780.1550548
# Completed translation 3259 of 9084 at 1716003782.8153431
# Completed translation 3260 of 9084 at 1716003785.514566
# Completed translation 3261 of 9084 at 1716003788.2158535
# Completed translation 3262 of 9084 at 1716003790.9194088
# Completed translation 3263 of 9084 at 1716003793.6023502
# Completed translation 3264 of 9084 at 1716003796.2979908
# Completed translation 3265 of 9084 at 1716003798.981461
# Completed translation 3266 of 9084 at 1716003801.74294
# Completed translation 3267 of 9084 at 1716003804.4498289
# Completed translation 3268 of 9084 at 1716003807.1334136
# Completed translation 3269 of 9084 at 1716003809.83571
# Completed translation 3270 of 9084 at 1716003812.5532672
# Completed translation 3271 of 9084 at 1716003815.2469509
# Completed translation 3272 of 9084 at 1716003817.945872
# Completed translation 3273 of 9084 at 1716003820.6288939
# Completed translation 3274 of 9084 at 1716003823.3371208
# Completed translation 3275 of 9084 at 1716003826.0287132
# Completed translation 3276 of 9084 at 1716003828.7172441
# Completed translation 3277 of 9084 at 1716003831.414805
# Completed translation 3278 of 9084 at 1716003834.11769
# Completed translation 3279 of 9084 at 1716003836.9128578
# Completed translation 3280 of 9084 at 1716003839.5854564
# Completed translation 3281 of 9084 at 1716003842.260202
# Completed translation 3282 of 9084 at 1716003844.9609058
# Completed translation 3283 of 9084 at 1716003847.6464458
# Completed translation 3284 of 9084 at 1716003850.338594
# Completed translation 3285 of 9084 at 1716003853.0328062
# Completed translation 3286 of 9084 at 1716003855.7519958
# Completed translation 3287 of 9084 at 1716003858.4728944
# Completed translation 3288 of 9084 at 1716003861.2054005
# Completed translation 3289 of 9084 at 1716003863.8874586
# Completed translation 3290 of 9084 at 1716003866.589139
# Completed translation 3291 of 9084 at 1716003869.3057532
# Completed translation 3292 of 9084 at 1716003871.9977708
# Completed translation 3293 of 9084 at 1716003874.7264583
# Completed translation 3294 of 9084 at 1716003877.4069762
# Completed translation 3295 of 9084 at 1716003880.0817647
# Completed translation 3296 of 9084 at 1716003882.7866068
# Completed translation 3297 of 9084 at 1716003885.4957085
# Completed translation 3298 of 9084 at 1716003888.1785123
# Completed translation 3299 of 9084 at 1716003890.8814151
# Completed translation 3300 of 9084 at 1716003893.5848362
# Memory usage summary:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |  69578 KiB |  95294 KiB |  69852 GiB |  69852 GiB |
# |       from large pool |  52872 KiB |  52872 KiB |      2 GiB |      2 GiB |
# |       from small pool |  16706 KiB |  42422 KiB |  69850 GiB |  69850 GiB |
# |---------------------------------------------------------------------------|
# | Active memory         |  69578 KiB |  95294 KiB |  69852 GiB |  69852 GiB |
# |       from large pool |  52872 KiB |  52872 KiB |      2 GiB |      2 GiB |
# |       from small pool |  16706 KiB |  42422 KiB |  69850 GiB |  69850 GiB |
# |---------------------------------------------------------------------------|
# | Requested memory      |  68055 KiB |  93747 KiB |  69838 GiB |  69838 GiB |
# |       from large pool |  51424 KiB |  51424 KiB |      2 GiB |      2 GiB |
# |       from small pool |  16631 KiB |  42323 KiB |  69836 GiB |  69836 GiB |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |  86016 KiB | 106496 KiB |  38114 MiB |  38030 MiB |
# |       from large pool |  61440 KiB |  61440 KiB |    100 MiB |     40 MiB |
# |       from small pool |  24576 KiB |  45056 KiB |  38014 MiB |  37990 MiB |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |  16438 KiB |  28691 KiB |  74222 GiB |  74222 GiB |
# |       from large pool |   8568 KiB |   8568 KiB |      2 GiB |      2 GiB |
# |       from small pool |   7870 KiB |  20123 KiB |  74220 GiB |  74220 GiB |
# |---------------------------------------------------------------------------|
# | Allocations           |     440    |     624    |  248982 K  |  248981 K  |
# |       from large pool |      25    |      25    |       2 K  |       2 K  |
# |       from small pool |     415    |     599    |  248980 K  |  248979 K  |
# |---------------------------------------------------------------------------|
# | Active allocs         |     440    |     624    |  248982 K  |  248981 K  |
# |       from large pool |      25    |      25    |       2 K  |       2 K  |
# |       from small pool |     415    |     599    |  248980 K  |  248979 K  |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |      15    |      25    |   19012    |   18997    |
# |       from large pool |       3    |       3    |       5    |       2    |
# |       from small pool |      12    |      22    |   19007    |   18995    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |      10    |      29    |  102578 K  |  102578 K  |
# |       from large pool |       2    |       2    |       1 K  |       1 K  |
# |       from small pool |       8    |      27    |  102577 K  |  102577 K  |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|
#
# Translation3300: {'source': "On Bulgar yüksek irtifa dağcısı, Everest dağına oksijen seti olmadan tırmanmak üzere Nepal'e doğru yola çıktı.Ģ", 'target': 'Ten Bulgarian alpinists left for Nepal, where they will attempt to climb Mt Everest without oxygen sets.Ģ', 'translation': 's9D9DK9KDK9PDD9DK9DKPDKK99PPPDPK9P9KK9DD9KKPK9PDP9DPP99K9P9DK9PDPDPDDKPP9KDDPPKPPP9KDPP]ġ)?)?)?])]ġġġ)?)ġġ))?]))?ġ]?ġ)))?ġġ)ġ?ġ?ġġ]))]?]?ġ)]ġ]ġ?????))ġġ?)]ġ?)]?]ġ]])]?))]ġ?]?]?))ġ?]ġ?))?)]?)?]ġ??ġ?)]])?)?)?ġ)?)?]???])??)]])ġġġ?)ġ)ġ)]?ġġ?)?)]]??ġ)]ġ]??ġ?]]ġ'}
# Completed translation 3301 of 9084 at 1716003896.3255882
# Completed translation 3302 of 9084 at 1716003899.0369413
# Completed translation 3303 of 9084 at 1716003901.7240314
# Completed translation 3304 of 9084 at 1716003904.423248
# Completed translation 3305 of 9084 at 1716003907.1245577
# Completed translation 3306 of 9084 at 1716003909.8306816
# Completed translation 3307 of 9084 at 1716003912.5393958
# Completed translation 3308 of 9084 at 1716003915.2187598
# Completed translation 3309 of 9084 at 1716003917.9105766
# Completed translation 3310 of 9084 at 1716003920.6276183
# Completed translation 3311 of 9084 at 1716003923.3230095
# Completed translation 3312 of 9084 at 1716003926.0451195
