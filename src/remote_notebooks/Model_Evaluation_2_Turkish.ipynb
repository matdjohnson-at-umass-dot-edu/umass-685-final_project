# %%
from google.colab import drive

import json
import random
import time
from typing import Optional

import torch
import numpy as np

drive.mount('/content/drive', force_remount=True)
root_filepath = '/content/drive/MyDrive/CS685-NLP-GroupProject/Code/singleNotebookFromPythonFilesStructure/'
is_remote_execution = True
torch.set_printoptions(threshold=100000, edgeitems=10000, linewidth=100000)
torch.device("cuda")


# 16M Turkish
SETimesByT5Vaswani2017Kocmi2018_0 = {
    'runner_hyperparameters_name': 'SETimesByT5Vaswani2017Kocmi2018_0',
    'model_parameter_filepath': root_filepath + "resources/saved_parameters/SETimesByT5Vaswani2017Kocmi2018_0-1715937924-model.params",
    'datasets_filepath': root_filepath + "resources/parsed_datasets/setimes/setimes_parsed-1715586293",
    'output_filepath': root_filepath + "resources/model_translations/SETimesByT5Vaswani2017Kocmi2018_0.json",
    'model_hyperparameters': {
        'src_vocab_size': 91,
        'tgt_vocab_size': 81,
        'max_src_seq_len': 266,
        'max_tgt_seq_len': 256,
        'd_model': 256,
        'nhead': 8,
        # number of encoders is 3 times that of decoders, following Xue 2021 - ByT5 - Sec 3.1
        'num_encoder_layers': 9,
        'num_decoder_layers': 3,
        'dim_feedforward': 2048,
        'dropout': 0.1,
        'activation': torch.nn.functional.relu,
        'custom_encoder': None,
        'custom_decoder': None,
        'layer_norm_eps': 1e-5,
        'batch_first': True,
        'norm_first': False,
        'bias': True,
        'device': None,
        'dtype': None
    }
}

# 15M Turkish
SETimesByT5Vaswani2017Kocmi2018_1 = {
    'runner_hyperparameters_name': 'SETimesByT5Vaswani2017Kocmi2018_1',
    'model_parameter_filepath': root_filepath + "resources/saved_parameters/SETimesByT5Vaswani2017Kocmi2018_1-1715937961-model.params",
    'datasets_filepath': root_filepath + "resources/parsed_datasets/setimes/setimes_parsed-1715586974",
    'output_filepath': root_filepath + "resources/model_translations/SETimesByT5Vaswani2017Kocmi2018_1.json",
    'model_hyperparameters': {
        'src_vocab_size': 91,
        'tgt_vocab_size': 81,
        'max_src_seq_len': 266,
        'max_tgt_seq_len': 256,
        'd_model': 256,
        'nhead': 8,
        # number of encoders is 3 times that of decoders, following Xue 2021 - ByT5 - Sec 3.1
        'num_encoder_layers': 9,
        'num_decoder_layers': 3,
        'dim_feedforward': 1796,
        'dropout': 0.1,
        'activation': torch.nn.functional.relu,
        'custom_encoder': None,
        'custom_decoder': None,
        'layer_norm_eps': 1e-5,
        'batch_first': True,
        'norm_first': False,
        'bias': True,
        'device': None,
        'dtype': None
    }
}

# 4M Turkish
SETimesByT5Vaswani2017Kocmi2018_2 = {
    'runner_hyperparameters_name': 'SETimesByT5Vaswani2017Kocmi2018_2',
    'model_parameter_filepath': root_filepath + "resources/saved_parameters/SETimesByT5Vaswani2017Kocmi2018_2-1715936459-model.params",
    'datasets_filepath': root_filepath + "resources/parsed_datasets/setimes/setimes_parsed-1715586361",
    'output_filepath': root_filepath + "resources/model_translations/SETimesByT5Vaswani2017Kocmi2018_2.json",
    'model_hyperparameters': {
        'src_vocab_size': 91,
        'tgt_vocab_size': 81,
        'max_src_seq_len': 266,
        'max_tgt_seq_len': 256,
        'd_model': 128,
        'nhead': 8,
        # number of encoders is 3 times that of decoders, following Xue 2021 - ByT5 - Sec 3.1
        'num_encoder_layers': 9,
        'num_decoder_layers': 3,
        'dim_feedforward': 1024,
        'dropout': 0.1,
        'activation': torch.nn.functional.relu,
        'custom_encoder': None,
        'custom_decoder': None,
        'layer_norm_eps': 1e-5,
        'batch_first': True,
        'norm_first': False,
        'bias': True,
        'device': None,
        'dtype': None
    }
}

# 16M Kazakh
NewsCommentaryByT5Vaswani2017Kocmi2018_0 = {
    'runner_hyperparameters_name': 'NewsCommentaryByT5Vaswani2017Kocmi2018_0',
    'model_parameter_filepath': root_filepath + "resources/saved_parameters/NewsCommentaryByT5Vaswani2017Kocmi2018_0-1715965639-model.params",
    'datasets_filepath': root_filepath + "resources/parsed_datasets/SMTNewsCommentary/SMTNewsCommentary_parsed-1715949808",
    'output_filepath': root_filepath + "resources/model_translations/NewsCommentaryByT5Vaswani2017Kocmi2018_0.json",
    'model_hyperparameters': {
        'src_vocab_size': 150,
        'tgt_vocab_size': 81,
        'max_src_seq_len': 266,
        'max_tgt_seq_len': 256,
        'd_model': 256,
        'nhead': 8,
        # number of encoders is 3 times that of decoders, following Xue 2021 - ByT5 - Sec 3.1
        'num_encoder_layers': 9,
        'num_decoder_layers': 3,
        'dim_feedforward': 2048,
        'dropout': 0.1,
        'activation': torch.nn.functional.relu,
        'custom_encoder': None,
        'custom_decoder': None,
        'layer_norm_eps': 1e-5,
        'batch_first': True,
        'norm_first': False,
        'bias': True,
        'device': None,
        'dtype': None
    }
}

# 15M Kazakh
NewsCommentaryByT5Vaswani2017Kocmi2018_1 = {
    'runner_hyperparameters_name': 'NewsCommentaryByT5Vaswani2017Kocmi2018_1',
    'model_parameter_filepath': root_filepath + "resources/saved_parameters/NewsCommentaryByT5Vaswani2017Kocmi2018_1-1715966141-model.params",
    'datasets_filepath': root_filepath + "resources/parsed_datasets/SMTNewsCommentary/SMTNewsCommentary_parsed-1715949808",
    'output_filepath': root_filepath + "resources/model_translations/NewsCommentaryByT5Vaswani2017Kocmi2018_1.json",
    'model_hyperparameters': {
        'src_vocab_size': 150,
        'tgt_vocab_size': 81,
        'max_src_seq_len': 266,
        'max_tgt_seq_len': 256,
        'd_model': 256,
        'nhead': 8,
        # number of encoders is 3 times that of decoders, following Xue 2021 - ByT5 - Sec 3.1
        'num_encoder_layers': 9,
        'num_decoder_layers': 3,
        'dim_feedforward': 1796,
        'dropout': 0.1,
        'activation': torch.nn.functional.relu,
        'custom_encoder': None,
        'custom_decoder': None,
        'layer_norm_eps': 1e-5,
        'batch_first': True,
        'norm_first': False,
        'bias': True,
        'device': None,
        'dtype': None
    }
}

# 4M Kazakh
NewsCommentaryByT5Vaswani2017Kocmi2018_2 = {
    'runner_hyperparameters_name': 'NewsCommentaryByT5Vaswani2017Kocmi2018_2',
    'model_parameter_filepath': root_filepath + "resources/saved_parameters/NewsCommentaryByT5Vaswani2017Kocmi2018_2-1715965581-model.params",
    'datasets_filepath': root_filepath + "resources/parsed_datasets/SMTNewsCommentary/SMTNewsCommentary_parsed-1715949808",
    'output_filepath': root_filepath + "resources/model_translations/NewsCommentaryByT5Vaswani2017Kocmi2018_2.json",
    'model_hyperparameters': {
        'src_vocab_size': 150,
        'tgt_vocab_size': 81,
        'max_src_seq_len': 266,
        'max_tgt_seq_len': 256,
        'd_model': 128,
        'nhead': 8,
        # number of encoders is 3 times that of decoders, following Xue 2021 - ByT5 - Sec 3.1
        'num_encoder_layers': 9,
        'num_decoder_layers': 3,
        'dim_feedforward': 1024,
        'dropout': 0.1,
        'activation': torch.nn.functional.relu,
        'custom_encoder': None,
        'custom_decoder': None,
        'layer_norm_eps': 1e-5,
        'batch_first': True,
        'norm_first': False,
        'bias': True,
        'device': None,
        'dtype': None
    }
}


class DatasetHolder:

    def __init__(self):
        self.unknown_vocabulary_type = None
        self.padding_vocabulary_type = None
        self.end_of_sequence_type = None
        self.target_vocab = None
        self.target_vocab_array = None
        self.target_vocab_counts = None
        self.source_vocab = None
        self.source_vocab_array = None
        self.source_vocab_counts = None
        self.target_encodings = None
        self.target_encodings_train = None
        self.target_encodings_test = None
        self.source_encodings = None
        self.source_encodings_train = None
        self.source_encodings_test = None
        self.max_src_seq_obs = 0
        self.max_tgt_seq_obs = 0

    def get_unknown_vocabulary_type(self):
        return self.unknown_vocabulary_type

    def set_unknown_vocabulary_type(self, unknown_vocabulary_type):
        self.unknown_vocabulary_type = unknown_vocabulary_type

    def get_padding_vocabulary_type(self):
        return self.padding_vocabulary_type

    def set_padding_vocabulary_type(self, padding_vocabulary_type):
        self.padding_vocabulary_type = padding_vocabulary_type

    def get_end_of_sequence_vocabulary_type(self):
        return self.end_of_sequence_type

    def set_end_of_sequence_vocabulary_type(self, end_of_sequence_type):
        self.end_of_sequence_type = end_of_sequence_type

    def get_target_vocab(self):
        return self.target_vocab

    def set_target_vocab(self, target_vocab):
        self.target_vocab = target_vocab

    def get_target_vocab_numpy(self):
        if self.target_vocab_array is None:
            self.target_vocab_array = np.array(self.target_vocab)
        return self.target_vocab_array

    def get_target_vocab_counts(self):
        return self.target_vocab_counts

    def set_target_vocab_counts(self, target_vocab_counts):
        self.target_vocab_counts = target_vocab_counts

    def get_source_vocab(self):
        return self.source_vocab

    def set_source_vocab(self, source_vocab):
        self.source_vocab = source_vocab

    def get_source_vocab_numpy(self):
        if self.source_vocab_array is None:
            self.source_vocab_array = np.array(self.source_vocab)
        return self.source_vocab_array

    def get_source_vocab_counts(self):
        return self.source_vocab_counts

    def set_source_vocab_counts(self, source_vocab_counts):
        self.source_vocab_counts = source_vocab_counts

    def get_target_encodings(self):
        return self.target_encodings

    def set_target_encodings(self, target_encodings):
        del self.target_encodings
        self.target_encodings = target_encodings
        if is_remote_execution:
            torch.cuda.empty_cache()

    def get_source_encodings(self):
        return self.source_encodings

    def set_source_encodings(self, source_encodings):
        del self.source_encodings
        self.source_encodings = source_encodings
        if is_remote_execution:
            torch.cuda.empty_cache()

    def get_target_encodings_train(self):
        return self.target_encodings_train

    def set_target_encodings_train(self, target_encodings_train):
        del self.target_encodings_train
        self.target_encodings_train = target_encodings_train
        if is_remote_execution:
            torch.cuda.empty_cache()

    def get_source_encodings_train(self):
        return self.source_encodings_train

    def set_source_encodings_train(self, source_encodings_train):
        del self.source_encodings_train
        self.source_encodings_train = source_encodings_train
        if is_remote_execution:
            torch.cuda.empty_cache()

    def get_target_encodings_test(self):
        return self.target_encodings_test

    def set_target_encodings_test(self, target_encodings_test):
        del self.target_encodings_test
        self.target_encodings_test = target_encodings_test
        if is_remote_execution:
            torch.cuda.empty_cache()

    def get_source_encodings_test(self):
        return self.source_encodings_test

    def set_source_encodings_test(self, source_encodings_test):
        del self.source_encodings_test
        self.source_encodings_test = source_encodings_test
        if is_remote_execution:
            torch.cuda.empty_cache()

    def get_max_src_seq_obs(self):
        return self.max_src_seq_obs

    def set_max_src_seq_obs(self, max_src_seq_obs):
        self.max_src_seq_obs = max_src_seq_obs

    def get_max_tgt_seq_obs(self):
        return self.max_tgt_seq_obs

    def set_max_tgt_seq_obs(self, max_tgt_seq_obs):
        self.max_tgt_seq_obs = max_tgt_seq_obs

# class name matches file name
class transformer_vaswani2017(torch.nn.Transformer):

    def __init__(self,
                 model_hyperparameters):
        super().__init__(
            d_model=model_hyperparameters['d_model'],
            nhead=model_hyperparameters['nhead'],
            num_encoder_layers=model_hyperparameters['num_encoder_layers'],
            num_decoder_layers=model_hyperparameters['num_decoder_layers'],
            dim_feedforward=model_hyperparameters['dim_feedforward'],
            dropout=model_hyperparameters['dropout'],
            activation=model_hyperparameters['activation'],
            custom_encoder=model_hyperparameters['custom_encoder'],
            custom_decoder=model_hyperparameters['custom_decoder'],
            layer_norm_eps=model_hyperparameters['layer_norm_eps'],
            batch_first=model_hyperparameters['batch_first'],
            norm_first=model_hyperparameters['norm_first'],
            bias=model_hyperparameters['bias'],
            device=model_hyperparameters['device'],
            dtype=model_hyperparameters['dtype']
        )
        self.model_hyperparameters = model_hyperparameters
        # add one for the end of sequence token
        self.max_src_seq_len = model_hyperparameters['max_src_seq_len'] + 1
        self.max_tgt_seq_len = model_hyperparameters['max_tgt_seq_len'] + 1
        self.src_embeddings = torch.nn.Embedding(
            model_hyperparameters['src_vocab_size'],
            model_hyperparameters['d_model']
        )
        self.tgt_embeddings = torch.nn.Embedding(
            model_hyperparameters['tgt_vocab_size'],
            model_hyperparameters['d_model']
        )
        self.src_pos_enc = torch.nn.Embedding(
            self.max_src_seq_len,
            model_hyperparameters['d_model']
        ).requires_grad_(False)
        self.tgt_pos_enc = torch.nn.Embedding(
            self.max_tgt_seq_len,
            model_hyperparameters['d_model']
        ).requires_grad_(False)
        self.linear_output_projection_1 = torch.nn.Linear(
            self.max_tgt_seq_len,
            1,
            bias=False
        )
        self.linear_output_projection_2 = torch.nn.Linear(
            model_hyperparameters['d_model'],
            model_hyperparameters['tgt_vocab_size'],
            bias=False
        )
        self.logsoftmax_output = torch.nn.LogSoftmax(dim=1)
        self.model_hyperparameters = model_hyperparameters
        self.tgt_mask_cache = {}
        for i in range(0, self.max_tgt_seq_len + 1):
            tgt_mask = self.generate_square_subsequent_mask(i)
            if is_remote_execution:
                self.tgt_mask_cache[i] = tgt_mask.to(device="cuda")
            self.tgt_mask_cache[i] = tgt_mask
        self.indices_cache = {}
        for i in range(0, max([self.max_src_seq_len, self.max_tgt_seq_len]) + 1):
            indices = torch.tensor(np.arange(0, i), dtype=torch.long)
            if is_remote_execution:
                indices = indices.to(device="cuda")
            self.indices_cache[i] = indices

    def forward(self,
                src: torch.Tensor,
                tgt: torch.Tensor,
                src_mask: Optional[torch.Tensor] = None,
                tgt_mask: Optional[torch.Tensor] = None,
                memory_mask: Optional[torch.Tensor] = None,
                src_key_padding_mask: Optional[torch.Tensor] = None,
                tgt_key_padding_mask: Optional[torch.Tensor] = None,
                memory_key_padding_mask: Optional[torch.Tensor] = None,
                src_is_causal: Optional[bool] = None,
                tgt_is_causal: Optional[bool] = True,
                memory_is_causal: bool = False) -> torch.Tensor:
        if len(src.shape) == 1:
            src = src.unsqueeze(dim=0)
        if len(tgt.shape) == 1:
            tgt = tgt.unsqueeze(dim=0)
        src_embedding_pos_enc = self.src_embeddings(src) + self.src_pos_enc(self.indices_cache[src.shape[1]])
        tgt_embedding_pos_enc = self.tgt_embeddings(tgt) + self.tgt_pos_enc(self.indices_cache[tgt.shape[1]])
        tgt_mask = self.tgt_mask_cache[tgt.shape[1]]
        transformer_output = super().forward(src_embedding_pos_enc, tgt_embedding_pos_enc, src_mask,
                                             tgt_mask, memory_mask, src_key_padding_mask,
                                             tgt_key_padding_mask, memory_key_padding_mask,
                                             src_is_causal, tgt_is_causal, memory_is_causal)
        transformer_output = torch.swapaxes(transformer_output, -1, -2)
        transformer_output = torch.nn.functional.pad(
            transformer_output,
            (0, self.max_tgt_seq_len - transformer_output.shape[2]),
            value=0
        )
        output = self.logsoftmax_output(
            self.linear_output_projection_2(
                torch.squeeze(
                    self.linear_output_projection_1(
                        transformer_output
                    ),
                    dim=2
                )
            )
        )
        del src_embedding_pos_enc
        del tgt_embedding_pos_enc
        del transformer_output
        return output

    def freeze_target_embeddings(self):
        del self.tgt_embeddings
        self.tgt_embeddings = torch.nn.Embedding(
            self.model_hyperparameters['tgt_vocab_size'],
            self.model_hyperparameters['d_model']
        ).requires_grad_(False)
        del self.linear_output_projection_1
        self.linear_output_projection_1 = torch.nn.Linear(
            self.max_tgt_seq_len,
            1,
            bias=False
        ).requires_grad_(False)
        del self.linear_output_projection_2
        self.linear_output_projection_2 = torch.nn.Linear(
            self.model_hyperparameters['d_model'],
            self.model_hyperparameters['tgt_vocab_size'],
            bias=False
        ).requires_grad_(False)

    def set_source_embeddings_for_transfer_learning(self, source_embeddings_dim):
        del self.src_embeddings
        self.src_embeddings = torch.nn.Embedding(
            source_embeddings_dim,
            self.model_hyperparameters['d_model']
        )


class Runner:

    def __init__(self):
        self.runner_hyperparameters = SETimesByT5Vaswani2017Kocmi2018_2
        self.model_hyperparameters = self.runner_hyperparameters['model_hyperparameters']
        self.runner_hyperparameters_name = self.runner_hyperparameters['runner_hyperparameters_name']
        self.model_parameter_filepath = self.runner_hyperparameters['model_parameter_filepath']
        self.datasets_filepath = self.runner_hyperparameters['datasets_filepath']
        self.output_filepath = self.runner_hyperparameters['output_filepath']
        self.max_target_sequence_length = self.runner_hyperparameters['model_hyperparameters']['max_tgt_seq_len']
        self.dataset_holder: DatasetHolder = None
        self.model = None
        print(f"Initialized runner {self.runner_hyperparameters_name} with parameters {self.runner_hyperparameters}")

    def load_dataset(self):
        self.dataset_holder = torch.load(self.datasets_filepath)

    def load_model(self):
        self.model = transformer_vaswani2017(model_hyperparameters=self.model_hyperparameters)
        self.model.freeze_target_embeddings()
        if is_remote_execution:
            model_parameters = torch.load(self.model_parameter_filepath, map_location=torch.device('cuda'))
        else:
            model_parameters = torch.load(self.model_parameter_filepath, map_location=torch.device('cpu'))
        self.model.load_state_dict(model_parameters)
        if is_remote_execution:
            self.model.cuda()
        self.model.eval()

    def evaluate_model(self):
        outputs = list()
        source_vocab_numpy = self.dataset_holder.get_source_vocab_numpy()
        target_vocab_numpy = self.dataset_holder.get_target_vocab_numpy()
        assert len(self.dataset_holder.get_source_encodings_test()) == len(self.dataset_holder.get_target_encodings_test())
        for i in range(0, len(self.dataset_holder.get_source_encodings_test())):
            if is_remote_execution:
                source_encoding = self.dataset_holder.get_source_encodings_test()[i].to(device="cuda")
                target_encoding = self.dataset_holder.get_target_encodings_test()[i].to(device="cuda")
            else:
                source_encoding = self.dataset_holder.get_source_encodings_test()[i].to(device="cpu")
                target_encoding = self.dataset_holder.get_target_encodings_test()[i].to(device="cpu")
            j = 0
            end_of_sequence = False
            while j < self.model_hyperparameters['max_tgt_seq_len'] and end_of_sequence == False:
                target_encoding_slice = torch.tensor_split(target_encoding, [j], dim=0)
                output_logits = self.model.forward(
                    source_encoding,
                    target_encoding_slice[0]
                ).detach().to(device="cpu").flatten().numpy()
                output_logits_sort_pairs = list()
                for k in range(0, len(output_logits)):
                    output_logits_sort_pairs.append([output_logits[k], k])
                output_logits_sorted = sorted(output_logits_sort_pairs, key=lambda logit_pair: logit_pair[0], reverse=True)
                output_sort_index = 0
                # don't pick mark up characters or whitespace if first term
                if j == 0:
                    while output_logits_sorted[output_sort_index][1] in (0, 1, 2, 7):
                        output_sort_index = output_sort_index + 1
                else:
                    # don't repeat unknown, padding, or spaces
                    if (prediction_encoding[j-1] == 0
                            or prediction_encoding[j-1] == 1
                            or prediction_encoding[j-1] == 7):
                        while (output_logits_sorted[output_sort_index][1] == 0
                               or output_logits_sorted[output_sort_index][1] == 1
                               or output_logits_sorted[output_sort_index][1] == 7):
                            output_sort_index = output_sort_index + 1
                output_vocab_index = output_logits_sorted[output_sort_index][1]
                # index = output_vocab_index # always outputs "Krrrr...<eos>"
                index = min(random.randint(output_vocab_index, output_vocab_index + 3), len(output_logits_sorted))
                if j == 0:
                    prediction_encoding = torch.tensor([output_logits_sorted[index][1]], dtype=torch.float)
                else:
                    prediction_encoding = torch.cat([prediction_encoding, torch.tensor([output_logits_sorted[index][1]], dtype=torch.float)])
                if prediction_encoding[j] == self.dataset_holder.get_target_vocab().index(
                        self.dataset_holder.get_end_of_sequence_vocabulary_type()):
                    end_of_sequence = True
                j = j + 1
            decoded_source = np.take(source_vocab_numpy, source_encoding.detach().to(device="cpu").flatten().numpy())
            decoded_target = np.take(target_vocab_numpy, target_encoding.detach().to(device="cpu").flatten().numpy())
            decoded_translation = np.take(target_vocab_numpy, prediction_encoding.detach().to(device="cpu", dtype=torch.int32).numpy())
            outputs.append({
                "source": "".join(decoded_source.tolist()),
                "target": "".join(decoded_target.tolist()),
                "translation": "".join(decoded_translation.tolist())
            })
            del source_encoding
            del target_encoding
            del prediction_encoding
            del target_encoding_slice
            del decoded_source
            del decoded_target
            del decoded_translation
            print(f"Completed translation {i} of {len(self.dataset_holder.get_source_encodings_test())} at {time.time()}")
            if is_remote_execution:
                torch.cuda.empty_cache()
                if i % 100 == 0:
                    print(f"Memory usage summary:")
                    print(f"{torch.cuda.memory_summary()}")
                    torch.cuda.reset_max_memory_allocated()
                    torch.cuda.reset_max_memory_cached()
                    torch.cuda.reset_peak_memory_stats()
            if i % 100 == 0 or i == len(self.dataset_holder.get_source_encodings_test()) - 1:
                print(f"Translation{i}: {outputs[i]}")
                output_file = open(self.output_filepath, "w")
                output_file.write(json.dumps(outputs, ensure_ascii=False, indent=1))
                output_file.close()


runner = Runner()
runner.load_dataset()
runner.load_model()
runner.evaluate_model()
# Out:
# Mounted at /content/drive
# Initialized runner SETimesByT5Vaswani2017Kocmi2018_2 with parameters {'runner_hyperparameters_name': 'SETimesByT5Vaswani2017Kocmi2018_2', 'model_parameter_filepath': '/content/drive/MyDrive/CS685-NLP-GroupProject/Code/singleNotebookFromPythonFilesStructure/resources/saved_parameters/SETimesByT5Vaswani2017Kocmi2018_2-1715936459-model.params', 'datasets_filepath': '/content/drive/MyDrive/CS685-NLP-GroupProject/Code/singleNotebookFromPythonFilesStructure/resources/parsed_datasets/setimes/setimes_parsed-1715586361', 'output_filepath': '/content/drive/MyDrive/CS685-NLP-GroupProject/Code/singleNotebookFromPythonFilesStructure/resources/model_translations/SETimesByT5Vaswani2017Kocmi2018_2.json', 'model_hyperparameters': {'src_vocab_size': 91, 'tgt_vocab_size': 81, 'max_src_seq_len': 266, 'max_tgt_seq_len': 256, 'd_model': 128, 'nhead': 8, 'num_encoder_layers': 9, 'num_decoder_layers': 3, 'dim_feedforward': 1024, 'dropout': 0.1, 'activation': <function relu at 0x78d32803fbe0>, 'custom_encoder': None, 'custom_decoder': None, 'layer_norm_eps': 1e-05, 'batch_first': True, 'norm_first': False, 'bias': True, 'device': None, 'dtype': None}}
# Completed translation 0 of 9084 at 1715995028.966063
# Memory usage summary:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |  25298 KiB |  33609 KiB |  16899 MiB |  16874 MiB |
# |       from large pool |   8320 KiB |   8320 KiB |      8 MiB |      0 MiB |
# |       from small pool |  16978 KiB |  33609 KiB |  16891 MiB |  16874 MiB |
# |---------------------------------------------------------------------------|
# | Active memory         |  25298 KiB |  33609 KiB |  16899 MiB |  16874 MiB |
# |       from large pool |   8320 KiB |   8320 KiB |      8 MiB |      0 MiB |
# |       from small pool |  16978 KiB |  33609 KiB |  16891 MiB |  16874 MiB |
# |---------------------------------------------------------------------------|
# | Requested memory      |  25230 KiB |  33540 KiB |  16894 MiB |  16869 MiB |
# |       from large pool |   8320 KiB |   8320 KiB |      8 MiB |      0 MiB |
# |       from small pool |  16910 KiB |  33540 KiB |  16886 MiB |  16869 MiB |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |  45056 KiB |  55296 KiB |  55296 KiB |  10240 KiB |
# |       from large pool |  20480 KiB |  20480 KiB |  20480 KiB |      0 KiB |
# |       from small pool |  24576 KiB |  34816 KiB |  34816 KiB |  10240 KiB |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |  19757 KiB |  19757 KiB |  17383 MiB |  17364 MiB |
# |       from large pool |  12160 KiB |  12160 KiB |     11 MiB |      0 MiB |
# |       from small pool |   7597 KiB |   8423 KiB |  17371 MiB |  17364 MiB |
# |---------------------------------------------------------------------------|
# | Allocations           |     440    |     620    |   76295    |   75855    |
# |       from large pool |       1    |       1    |       1    |       0    |
# |       from small pool |     439    |     619    |   76294    |   75855    |
# |---------------------------------------------------------------------------|
# | Active allocs         |     440    |     620    |   76295    |   75855    |
# |       from large pool |       1    |       1    |       1    |       0    |
# |       from small pool |     439    |     619    |   76294    |   75855    |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |      13    |      18    |      18    |       5    |
# |       from large pool |       1    |       1    |       1    |       0    |
# |       from small pool |      12    |      17    |      17    |       5    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |       7    |      17    |   29651    |   29644    |
# |       from large pool |       1    |       1    |       1    |       0    |
# |       from small pool |       6    |      16    |   29650    |   29644    |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|
#
# Translation0: {'source': "Hellas Sat'ın sunduğu başlıca hizmetler şunlar:Ģ", 'target': 'The main services that Hellas Sat offers are:Ģ', 'translation': 'K%2222H6H%66626%%2%66266266H%%2H%H%%2262%662%H6H%6%66%HH22H2H%%H2H62HHH%2%66%66%62HH2H6H%62H%H262H666%6%%%%2%626%H2H%2%HH%626H%6266%%%H%HH2HH%6HH66%H62H26H%6%HH222%H66%6H%6%%H%%6H6H6H2226H6H22H6HH2HHHH62HH2H2%H26%%%2%%66H%6%222%%HHHH%HH2H666%6H6HHH26%62H%2'}
# /usr/local/lib/python3.10/dist-packages/torch/cuda/memory.py:330: FutureWarning: torch.cuda.reset_max_memory_allocated now calls torch.cuda.reset_peak_memory_stats, which resets /all/ peak memory stats.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/cuda/memory.py:356: FutureWarning: torch.cuda.reset_max_memory_cached now calls torch.cuda.reset_peak_memory_stats, which resets /all/ peak memory stats.
#   warnings.warn(
# Completed translation 1 of 9084 at 1715995031.8213103
# Completed translation 2 of 9084 at 1715995034.4945464
# Completed translation 3 of 9084 at 1715995037.0840218
# Completed translation 4 of 9084 at 1715995039.7246919
# Completed translation 5 of 9084 at 1715995042.4942021
# Completed translation 6 of 9084 at 1715995045.0934072
# Completed translation 7 of 9084 at 1715995047.7175388
# Completed translation 8 of 9084 at 1715995050.3283713
# Completed translation 9 of 9084 at 1715995052.9355671
# Completed translation 10 of 9084 at 1715995055.5310268
# Completed translation 11 of 9084 at 1715995058.1220808
# Completed translation 12 of 9084 at 1715995060.7460568
# Completed translation 13 of 9084 at 1715995063.3723419
# Completed translation 14 of 9084 at 1715995065.9708838
# Completed translation 15 of 9084 at 1715995068.598269
# Completed translation 16 of 9084 at 1715995071.2671328
# Completed translation 17 of 9084 at 1715995073.9612746
# Completed translation 18 of 9084 at 1715995076.7590468
# Completed translation 19 of 9084 at 1715995079.5263913
# Completed translation 20 of 9084 at 1715995082.1473198
# Completed translation 21 of 9084 at 1715995084.7478201
# Completed translation 22 of 9084 at 1715995087.3433106
# Completed translation 23 of 9084 at 1715995090.032044
# Completed translation 24 of 9084 at 1715995092.7353022
# Completed translation 25 of 9084 at 1715995095.5311344
# Completed translation 26 of 9084 at 1715995098.1269526
# Completed translation 27 of 9084 at 1715995100.7339876
# Completed translation 28 of 9084 at 1715995103.3523636
# Completed translation 29 of 9084 at 1715995105.9530814
# Completed translation 30 of 9084 at 1715995108.556254
# Completed translation 31 of 9084 at 1715995111.145291
# Completed translation 32 of 9084 at 1715995113.7557461
# Completed translation 33 of 9084 at 1715995116.4812543
# Completed translation 34 of 9084 at 1715995119.0954566
# Completed translation 35 of 9084 at 1715995121.7056901
# Completed translation 36 of 9084 at 1715995124.3182197
# Completed translation 37 of 9084 at 1715995126.9398375
# Completed translation 38 of 9084 at 1715995129.575455
# Completed translation 39 of 9084 at 1715995132.245782
# Completed translation 40 of 9084 at 1715995134.8685198
# Completed translation 41 of 9084 at 1715995137.4887736
# Completed translation 42 of 9084 at 1715995140.0989633
# Completed translation 43 of 9084 at 1715995142.7479815
# Completed translation 44 of 9084 at 1715995145.5395112
# Completed translation 45 of 9084 at 1715995148.1983378
# Completed translation 46 of 9084 at 1715995150.7917662
# Completed translation 47 of 9084 at 1715995153.4418867
# Completed translation 48 of 9084 at 1715995156.1470392
# Completed translation 49 of 9084 at 1715995158.7726047
# Completed translation 50 of 9084 at 1715995161.5408452
# Completed translation 51 of 9084 at 1715995164.223129
# Completed translation 52 of 9084 at 1715995166.9270287
# Completed translation 53 of 9084 at 1715995169.542258
# Completed translation 54 of 9084 at 1715995172.3544712
# Completed translation 55 of 9084 at 1715995174.9629922
# Completed translation 56 of 9084 at 1715995177.6997478
# Completed translation 57 of 9084 at 1715995180.3587153
# Completed translation 58 of 9084 at 1715995183.1221285
# Completed translation 59 of 9084 at 1715995185.8579962
# Completed translation 60 of 9084 at 1715995188.7903314
# Completed translation 61 of 9084 at 1715995191.3881905
# Completed translation 62 of 9084 at 1715995194.182831
# Completed translation 63 of 9084 at 1715995196.9783428
# Completed translation 64 of 9084 at 1715995199.7184334
# Completed translation 65 of 9084 at 1715995202.7067614
# Completed translation 66 of 9084 at 1715995205.3013055
# Completed translation 67 of 9084 at 1715995208.0075936
# Completed translation 68 of 9084 at 1715995210.6185505
# Completed translation 69 of 9084 at 1715995213.2305546
# Completed translation 70 of 9084 at 1715995215.8719914
# Completed translation 71 of 9084 at 1715995218.5578492
# Completed translation 72 of 9084 at 1715995221.280152
# Completed translation 73 of 9084 at 1715995223.9602225
# Completed translation 74 of 9084 at 1715995226.776509
# Completed translation 75 of 9084 at 1715995229.4428618
# Completed translation 76 of 9084 at 1715995232.0433145
# Completed translation 77 of 9084 at 1715995234.6478157
# Completed translation 78 of 9084 at 1715995237.261232
# Completed translation 79 of 9084 at 1715995239.9092975
# Completed translation 80 of 9084 at 1715995242.7250948
# Completed translation 81 of 9084 at 1715995245.4013112
# Completed translation 82 of 9084 at 1715995248.0322459
# Completed translation 83 of 9084 at 1715995250.6769598
# Completed translation 84 of 9084 at 1715995253.384801
# Completed translation 85 of 9084 at 1715995255.9942133
# Completed translation 86 of 9084 at 1715995258.5830915
# Completed translation 87 of 9084 at 1715995261.2186837
# Completed translation 88 of 9084 at 1715995263.9306352
# Completed translation 89 of 9084 at 1715995266.5500832
# Completed translation 90 of 9084 at 1715995269.1747367
# Completed translation 91 of 9084 at 1715995271.8987284
# Completed translation 92 of 9084 at 1715995274.5193596
# Completed translation 93 of 9084 at 1715995277.170358
# Completed translation 94 of 9084 at 1715995279.825609
# Completed translation 95 of 9084 at 1715995282.429822
# Completed translation 96 of 9084 at 1715995285.0607488
# Completed translation 97 of 9084 at 1715995288.035321
# Completed translation 98 of 9084 at 1715995290.6356165
# Completed translation 99 of 9084 at 1715995293.4503634
# Completed translation 100 of 9084 at 1715995296.0547523
# Memory usage summary:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |  25298 KiB |  32168 KiB |   1676 GiB |   1676 GiB |
# |       from large pool |   8320 KiB |   8320 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16978 KiB |  23848 KiB |   1676 GiB |   1676 GiB |
# |---------------------------------------------------------------------------|
# | Active memory         |  25298 KiB |  32168 KiB |   1676 GiB |   1676 GiB |
# |       from large pool |   8320 KiB |   8320 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16978 KiB |  23848 KiB |   1676 GiB |   1676 GiB |
# |---------------------------------------------------------------------------|
# | Requested memory      |  25230 KiB |  32084 KiB |   1675 GiB |   1675 GiB |
# |       from large pool |   8320 KiB |   8320 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16910 KiB |  23764 KiB |   1675 GiB |   1675 GiB |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |  45056 KiB |  45056 KiB |  55296 KiB |  10240 KiB |
# |       from large pool |  20480 KiB |  20480 KiB |  20480 KiB |      0 KiB |
# |       from small pool |  24576 KiB |  24576 KiB |  34816 KiB |  10240 KiB |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |  19757 KiB |  19757 KiB |   1676 GiB |   1676 GiB |
# |       from large pool |  12160 KiB |  12160 KiB |      0 GiB |      0 GiB |
# |       from small pool |   7597 KiB |   7597 KiB |   1676 GiB |   1676 GiB |
# |---------------------------------------------------------------------------|
# | Allocations           |     440    |     623    |    7618 K  |    7618 K  |
# |       from large pool |       1    |       1    |       0 K  |       0 K  |
# |       from small pool |     439    |     622    |    7618 K  |    7618 K  |
# |---------------------------------------------------------------------------|
# | Active allocs         |     440    |     623    |    7618 K  |    7618 K  |
# |       from large pool |       1    |       1    |       0 K  |       0 K  |
# |       from small pool |     439    |     622    |    7618 K  |    7618 K  |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |      13    |      13    |      18    |       5    |
# |       from large pool |       1    |       1    |       1    |       0    |
# |       from small pool |      12    |      12    |      17    |       5    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |       7    |      20    |    2789 K  |    2789 K  |
# |       from large pool |       1    |       1    |       0 K  |       0 K  |
# |       from small pool |       6    |      19    |    2789 K  |    2789 K  |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|
#
# Translation100: {'source': "Zagreb ABD'yle Dokunulmazlık Anlaşması İmzalamaya YakınĢ", 'target': 'Zagreb Likely to Sign Immunity Agreement with USĢ', 'translation': 'K6%HH%%%6H6%%2%62H2H666H%H%%%6%%2HH2H%H%%266%6%222H6%%6H%%H2%%2%6%%26H622%2626H6%%H6%22%H2H26%6%%22%6%%6%%H%%H%%62%2222H%26%2%6%HH%%22%6H%HHH%%622%666HH%HH%%2%%H226%6H%6%266HH2%H%%%2%%HH2%%222%2%62266%62%%6H6HH%H6H%22222H%2H6H6HH66%%6%%6%62%%H22266%%22%26H'}
# Completed translation 101 of 9084 at 1715995298.6846576
# Completed translation 102 of 9084 at 1715995301.4272745
# Completed translation 103 of 9084 at 1715995304.0931413
# Completed translation 104 of 9084 at 1715995306.7343388
# Completed translation 105 of 9084 at 1715995309.4253256
# Completed translation 106 of 9084 at 1715995312.123716
# Completed translation 107 of 9084 at 1715995314.759147
# Completed translation 108 of 9084 at 1715995317.423946
# Completed translation 109 of 9084 at 1715995320.0001261
# Completed translation 110 of 9084 at 1715995322.6019573
# Completed translation 111 of 9084 at 1715995325.2187939
# Completed translation 112 of 9084 at 1715995327.8919864
# Completed translation 113 of 9084 at 1715995330.7548642
# Completed translation 114 of 9084 at 1715995333.3573935
# Completed translation 115 of 9084 at 1715995335.953251
# Completed translation 116 of 9084 at 1715995338.545741
# Completed translation 117 of 9084 at 1715995341.1702855
# Completed translation 118 of 9084 at 1715995343.7928307
# Completed translation 119 of 9084 at 1715995346.4115107
# Completed translation 120 of 9084 at 1715995349.0274484
# Completed translation 121 of 9084 at 1715995351.9356856
# Completed translation 122 of 9084 at 1715995354.5649056
# Completed translation 123 of 9084 at 1715995357.230607
# Completed translation 124 of 9084 at 1715995359.9620051
# Completed translation 125 of 9084 at 1715995362.7169023
# Completed translation 126 of 9084 at 1715995365.335804
# Completed translation 127 of 9084 at 1715995367.9516177
# Completed translation 128 of 9084 at 1715995370.6291475
# Completed translation 129 of 9084 at 1715995373.2637415
# Completed translation 130 of 9084 at 1715995375.877676
# Completed translation 131 of 9084 at 1715995378.5659294
# Completed translation 132 of 9084 at 1715995381.1921484
# Completed translation 133 of 9084 at 1715995383.8835633
# Completed translation 134 of 9084 at 1715995386.4762435
# Completed translation 135 of 9084 at 1715995389.145937
# Completed translation 136 of 9084 at 1715995391.9934797
# Completed translation 137 of 9084 at 1715995394.645511
# Completed translation 138 of 9084 at 1715995397.4014316
# Completed translation 139 of 9084 at 1715995400.0891333
# Completed translation 140 of 9084 at 1715995402.692494
# Completed translation 141 of 9084 at 1715995405.2972527
# Completed translation 142 of 9084 at 1715995407.933106
# Completed translation 143 of 9084 at 1715995410.5797048
# Completed translation 144 of 9084 at 1715995413.2036464
# Completed translation 145 of 9084 at 1715995415.8558924
# Completed translation 146 of 9084 at 1715995418.4578195
# Completed translation 147 of 9084 at 1715995421.0941584
# Completed translation 148 of 9084 at 1715995423.7202113
# Completed translation 149 of 9084 at 1715995426.35255
# Completed translation 150 of 9084 at 1715995428.9728365
# Completed translation 151 of 9084 at 1715995431.5797462
# Completed translation 152 of 9084 at 1715995434.2065258
# Completed translation 153 of 9084 at 1715995436.8272603
# Completed translation 154 of 9084 at 1715995439.4529088
# Completed translation 155 of 9084 at 1715995442.2157629
# Completed translation 156 of 9084 at 1715995444.8919654
# Completed translation 157 of 9084 at 1715995447.5155485
# Completed translation 158 of 9084 at 1715995450.1806912
# Completed translation 159 of 9084 at 1715995452.8402023
# Completed translation 160 of 9084 at 1715995455.5248718
# Completed translation 161 of 9084 at 1715995458.1727967
# Completed translation 162 of 9084 at 1715995460.8114028
# Completed translation 163 of 9084 at 1715995463.439232
# Completed translation 164 of 9084 at 1715995466.0512972
# Completed translation 165 of 9084 at 1715995468.6924098
# Completed translation 166 of 9084 at 1715995471.3276474
# Completed translation 167 of 9084 at 1715995474.0692067
# Completed translation 168 of 9084 at 1715995476.730719
# Completed translation 169 of 9084 at 1715995479.3851476
# Completed translation 170 of 9084 at 1715995482.1353285
# Completed translation 171 of 9084 at 1715995484.7903807
# Completed translation 172 of 9084 at 1715995487.408143
# Completed translation 173 of 9084 at 1715995490.07481
# Completed translation 174 of 9084 at 1715995492.7501361
# Completed translation 175 of 9084 at 1715995495.4354365
# Completed translation 176 of 9084 at 1715995498.0548105
# Completed translation 177 of 9084 at 1715995500.778649
# Completed translation 178 of 9084 at 1715995503.4182932
# Completed translation 179 of 9084 at 1715995506.1207833
# Completed translation 180 of 9084 at 1715995508.7682512
# Completed translation 181 of 9084 at 1715995511.408152
# Completed translation 182 of 9084 at 1715995514.0313845
# Completed translation 183 of 9084 at 1715995516.6246598
# Completed translation 184 of 9084 at 1715995519.2577462
# Completed translation 185 of 9084 at 1715995521.9278781
# Completed translation 186 of 9084 at 1715995524.5637643
# Completed translation 187 of 9084 at 1715995527.2481608
# Completed translation 188 of 9084 at 1715995529.8634925
# Completed translation 189 of 9084 at 1715995532.503042
# Completed translation 190 of 9084 at 1715995535.145191
# Completed translation 191 of 9084 at 1715995537.7888284
# Completed translation 192 of 9084 at 1715995540.4136415
# Completed translation 193 of 9084 at 1715995543.1744514
# Completed translation 194 of 9084 at 1715995545.8238392
# Completed translation 195 of 9084 at 1715995548.588022
# Completed translation 196 of 9084 at 1715995551.2555625
# Completed translation 197 of 9084 at 1715995553.9235978
# Completed translation 198 of 9084 at 1715995556.5604596
# Completed translation 199 of 9084 at 1715995559.195328
# Completed translation 200 of 9084 at 1715995561.8189547
# Memory usage summary:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |  25298 KiB |  32548 KiB |   3350 GiB |   3350 GiB |
# |       from large pool |   8320 KiB |   8320 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16978 KiB |  24228 KiB |   3350 GiB |   3350 GiB |
# |---------------------------------------------------------------------------|
# | Active memory         |  25298 KiB |  32548 KiB |   3350 GiB |   3350 GiB |
# |       from large pool |   8320 KiB |   8320 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16978 KiB |  24228 KiB |   3350 GiB |   3350 GiB |
# |---------------------------------------------------------------------------|
# | Requested memory      |  25230 KiB |  32465 KiB |   3350 GiB |   3349 GiB |
# |       from large pool |   8320 KiB |   8320 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16910 KiB |  24145 KiB |   3350 GiB |   3349 GiB |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |  45056 KiB |  45056 KiB |  55296 KiB |  10240 KiB |
# |       from large pool |  20480 KiB |  20480 KiB |  20480 KiB |      0 KiB |
# |       from small pool |  24576 KiB |  24576 KiB |  34816 KiB |  10240 KiB |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |  19757 KiB |  19757 KiB |   3351 GiB |   3351 GiB |
# |       from large pool |  12160 KiB |  12160 KiB |      0 GiB |      0 GiB |
# |       from small pool |   7597 KiB |   7597 KiB |   3351 GiB |   3351 GiB |
# |---------------------------------------------------------------------------|
# | Allocations           |     440    |     622    |   15161 K  |   15161 K  |
# |       from large pool |       1    |       1    |       0 K  |       0 K  |
# |       from small pool |     439    |     621    |   15161 K  |   15161 K  |
# |---------------------------------------------------------------------------|
# | Active allocs         |     440    |     622    |   15161 K  |   15161 K  |
# |       from large pool |       1    |       1    |       0 K  |       0 K  |
# |       from small pool |     439    |     621    |   15161 K  |   15161 K  |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |      13    |      13    |      18    |       5    |
# |       from large pool |       1    |       1    |       1    |       0    |
# |       from small pool |      12    |      12    |      17    |       5    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |       7    |      20    |    5534 K  |    5534 K  |
# |       from large pool |       1    |       1    |       0 K  |       0 K  |
# |       from small pool |       6    |      19    |    5534 K  |    5534 K  |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|
#
# Translation200: {'source': 'Hükümet müzakerelerinin nasıl süreceği henüz belirsiz.Ģ', 'target': 'It is not clear how the government talks will continue.Ģ', 'translation': 's%%62H62%662%H%%2%%%%266666226H2%66%22HH%2%%2%6H2H6?"?""""])"))?)""?"]")]])"??])?)???]]""""])?]]])]"?"]))??)))"]])?)???]?]"]?])])?"]?])?]]]?))]"""?]????))?""?]?]"""])?)"")))"))??)"")]"]]?????)??]]"]")?]?)"?]))?)]]?]]]?])?"?]")]]]"]?)????]?)?]]")?"?)""])"?)'}
# Completed translation 201 of 9084 at 1715995564.4535954
# Completed translation 202 of 9084 at 1715995567.099135
# Completed translation 203 of 9084 at 1715995569.7360973
# Completed translation 204 of 9084 at 1715995572.410939
# Completed translation 205 of 9084 at 1715995575.0156276
# Completed translation 206 of 9084 at 1715995577.7357683
# Completed translation 207 of 9084 at 1715995580.5456967
# Completed translation 208 of 9084 at 1715995583.2381067
# Completed translation 209 of 9084 at 1715995585.9024498
# Completed translation 210 of 9084 at 1715995588.561797
# Completed translation 211 of 9084 at 1715995591.2094476
# Completed translation 212 of 9084 at 1715995593.7883663
# Completed translation 213 of 9084 at 1715995596.4243913
# Completed translation 214 of 9084 at 1715995599.079222
# Completed translation 215 of 9084 at 1715995601.8096478
# Completed translation 216 of 9084 at 1715995604.4330916
# Completed translation 217 of 9084 at 1715995607.06664
# Completed translation 218 of 9084 at 1715995609.8301337
# Completed translation 219 of 9084 at 1715995612.492653
# Completed translation 220 of 9084 at 1715995615.2102764
# Completed translation 221 of 9084 at 1715995617.8160331
# Completed translation 222 of 9084 at 1715995620.5012147
# Completed translation 223 of 9084 at 1715995623.140135
# Completed translation 224 of 9084 at 1715995625.764384
# Completed translation 225 of 9084 at 1715995628.4937987
# Completed translation 226 of 9084 at 1715995631.107815
# Completed translation 227 of 9084 at 1715995633.7789104
# Completed translation 228 of 9084 at 1715995636.3914385
# Completed translation 229 of 9084 at 1715995638.9852054
# Completed translation 230 of 9084 at 1715995641.594429
# Completed translation 231 of 9084 at 1715995644.4154642
# Completed translation 232 of 9084 at 1715995647.0343451
# Completed translation 233 of 9084 at 1715995649.6788042
# Completed translation 234 of 9084 at 1715995652.309368
# Completed translation 235 of 9084 at 1715995654.957646
# Completed translation 236 of 9084 at 1715995657.6383398
# Completed translation 237 of 9084 at 1715995660.257483
# Completed translation 238 of 9084 at 1715995662.8641143
# Completed translation 239 of 9084 at 1715995665.545302
# Completed translation 240 of 9084 at 1715995668.1306708
# Completed translation 241 of 9084 at 1715995670.8193147
# Completed translation 242 of 9084 at 1715995673.4383485
# Completed translation 243 of 9084 at 1715995676.1795385
# Completed translation 244 of 9084 at 1715995678.7673352
# Completed translation 245 of 9084 at 1715995681.4592168
# Completed translation 246 of 9084 at 1715995684.134547
# Completed translation 247 of 9084 at 1715995686.7925682
# Completed translation 248 of 9084 at 1715995689.4025114
# Completed translation 249 of 9084 at 1715995692.0491235
# Completed translation 250 of 9084 at 1715995694.7127492
# Completed translation 251 of 9084 at 1715995697.37704
# Completed translation 252 of 9084 at 1715995700.006387
# Completed translation 253 of 9084 at 1715995702.6221771
# Completed translation 254 of 9084 at 1715995705.2240872
# Completed translation 255 of 9084 at 1715995707.8649118
# Completed translation 256 of 9084 at 1715995710.677723
# Completed translation 257 of 9084 at 1715995713.3333037
# Completed translation 258 of 9084 at 1715995715.964629
# Completed translation 259 of 9084 at 1715995718.6341524
# Completed translation 260 of 9084 at 1715995721.2862546
# Completed translation 261 of 9084 at 1715995723.9993393
# Completed translation 262 of 9084 at 1715995726.6334195
# Completed translation 263 of 9084 at 1715995729.2553372
# Completed translation 264 of 9084 at 1715995731.8969328
# Completed translation 265 of 9084 at 1715995734.5043716
# Completed translation 266 of 9084 at 1715995737.1334991
# Completed translation 267 of 9084 at 1715995739.7436857
# Completed translation 268 of 9084 at 1715995742.3649416
# Completed translation 269 of 9084 at 1715995744.9812825
# Completed translation 270 of 9084 at 1715995747.6119006
# Completed translation 271 of 9084 at 1715995750.319529
# Completed translation 272 of 9084 at 1715995753.1049287
# Completed translation 273 of 9084 at 1715995755.726751
# Completed translation 274 of 9084 at 1715995758.4096317
# Completed translation 275 of 9084 at 1715995761.0196946
# Completed translation 276 of 9084 at 1715995763.6167462
# Completed translation 277 of 9084 at 1715995766.2132893
# Completed translation 278 of 9084 at 1715995768.864335
# Completed translation 279 of 9084 at 1715995771.4964335
# Completed translation 280 of 9084 at 1715995774.162188
# Completed translation 281 of 9084 at 1715995776.8079026
# Completed translation 282 of 9084 at 1715995779.4177246
# Completed translation 283 of 9084 at 1715995782.0437543
# Completed translation 284 of 9084 at 1715995784.705295
# Completed translation 285 of 9084 at 1715995787.3493965
# Completed translation 286 of 9084 at 1715995789.973363
# Completed translation 287 of 9084 at 1715995792.6503968
# Completed translation 288 of 9084 at 1715995795.3353913
# Completed translation 289 of 9084 at 1715995798.0258281
# Completed translation 290 of 9084 at 1715995800.6480541
# Completed translation 291 of 9084 at 1715995803.325463
# Completed translation 292 of 9084 at 1715995806.0034916
# Completed translation 293 of 9084 at 1715995808.636406
# Completed translation 294 of 9084 at 1715995811.2829516
# Completed translation 295 of 9084 at 1715995813.9711723
# Completed translation 296 of 9084 at 1715995816.6115088
# Completed translation 297 of 9084 at 1715995819.3179092
# Completed translation 298 of 9084 at 1715995822.2265115
# Completed translation 299 of 9084 at 1715995824.9534357
# Completed translation 300 of 9084 at 1715995827.6534262
# Memory usage summary:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |  25298 KiB |  33014 KiB |   5039 GiB |   5039 GiB |
# |       from large pool |   8320 KiB |   8320 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16978 KiB |  24694 KiB |   5039 GiB |   5039 GiB |
# |---------------------------------------------------------------------------|
# | Active memory         |  25298 KiB |  33014 KiB |   5039 GiB |   5039 GiB |
# |       from large pool |   8320 KiB |   8320 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16978 KiB |  24694 KiB |   5039 GiB |   5039 GiB |
# |---------------------------------------------------------------------------|
# | Requested memory      |  25230 KiB |  32931 KiB |   5037 GiB |   5037 GiB |
# |       from large pool |   8320 KiB |   8320 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16910 KiB |  24611 KiB |   5037 GiB |   5037 GiB |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |  45056 KiB |  47104 KiB |  94208 KiB |  49152 KiB |
# |       from large pool |  20480 KiB |  20480 KiB |  20480 KiB |      0 KiB |
# |       from small pool |  24576 KiB |  26624 KiB |  73728 KiB |  49152 KiB |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |  19757 KiB |  19757 KiB |   5039 GiB |   5039 GiB |
# |       from large pool |  12160 KiB |  12160 KiB |      0 GiB |      0 GiB |
# |       from small pool |   7597 KiB |   7597 KiB |   5039 GiB |   5039 GiB |
# |---------------------------------------------------------------------------|
# | Allocations           |     440    |     622    |   22704 K  |   22703 K  |
# |       from large pool |       1    |       1    |       0 K  |       0 K  |
# |       from small pool |     439    |     621    |   22704 K  |   22703 K  |
# |---------------------------------------------------------------------------|
# | Active allocs         |     440    |     622    |   22704 K  |   22703 K  |
# |       from large pool |       1    |       1    |       0 K  |       0 K  |
# |       from small pool |     439    |     621    |   22704 K  |   22703 K  |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |      13    |      14    |      37    |      24    |
# |       from large pool |       1    |       1    |       1    |       0    |
# |       from small pool |      12    |      13    |      36    |      24    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |       7    |      21    |    8244 K  |    8244 K  |
# |       from large pool |       1    |       1    |       0 K  |       0 K  |
# |       from small pool |       6    |      20    |    8244 K  |    8244 K  |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|
#
# Translation300: {'source': 'Sırp sığınmacılar serbest vize rejimini tehlikeye atıyorlarĢ', 'target': 'Serbian asylum seekers jeopardising visa liberalisationĢ', 'translation': 'v%%22H2H26%%HHH2%2%26%%6%6%%2%%6%62%%H2H22H%6H2%2HH)?])""????]?)]"]?)?"]])"?]]"?")]"]")?]])"?")?)")]]]?")]])"]]")?]]])?""?"]]))??]?]?"])]))]?)"??)?""""?"]]]?))]]")?))??])]?"]"""])]"?]?"?)??])")))""))?])]?)?)?""?"?))))")?"]))]"))")]""""])]"????)"]")??]")?"?'}
# Completed translation 301 of 9084 at 1715995830.3137298
# Completed translation 302 of 9084 at 1715995832.9807236
# Completed translation 303 of 9084 at 1715995835.6397321
# Completed translation 304 of 9084 at 1715995838.2901492
# Completed translation 305 of 9084 at 1715995840.949225
# Completed translation 306 of 9084 at 1715995843.6002614
# Completed translation 307 of 9084 at 1715995846.3166745
# Completed translation 308 of 9084 at 1715995848.928112
# Completed translation 309 of 9084 at 1715995851.5214124
# Completed translation 310 of 9084 at 1715995854.1490874
# Completed translation 311 of 9084 at 1715995856.8241053
# Completed translation 312 of 9084 at 1715995859.4512522
# Completed translation 313 of 9084 at 1715995862.1322923
# Completed translation 314 of 9084 at 1715995864.7568223
# Completed translation 315 of 9084 at 1715995867.4796152
# Completed translation 316 of 9084 at 1715995870.1658452
# Completed translation 317 of 9084 at 1715995872.7734423
# Completed translation 318 of 9084 at 1715995875.4020636
# Completed translation 319 of 9084 at 1715995878.1151936
# Completed translation 320 of 9084 at 1715995880.7688763
# Completed translation 321 of 9084 at 1715995883.4219244
# Completed translation 322 of 9084 at 1715995886.0674868
# Completed translation 323 of 9084 at 1715995888.756924
# Completed translation 324 of 9084 at 1715995891.433507
# Completed translation 325 of 9084 at 1715995894.0672596
# Completed translation 326 of 9084 at 1715995896.657762
# Completed translation 327 of 9084 at 1715995899.354818
# Completed translation 328 of 9084 at 1715995902.0681262
# Completed translation 329 of 9084 at 1715995904.701998
# Completed translation 330 of 9084 at 1715995907.4130313
# Completed translation 331 of 9084 at 1715995910.146056
# Completed translation 332 of 9084 at 1715995912.9376926
# Completed translation 333 of 9084 at 1715995915.5425465
# Completed translation 334 of 9084 at 1715995918.2967982
# Completed translation 335 of 9084 at 1715995921.0111835
# Completed translation 336 of 9084 at 1715995923.6439536
# Completed translation 337 of 9084 at 1715995926.3374686
# Completed translation 338 of 9084 at 1715995928.9691856
# Completed translation 339 of 9084 at 1715995931.59092
# Completed translation 340 of 9084 at 1715995934.2490065
# Completed translation 341 of 9084 at 1715995936.90803
# Completed translation 342 of 9084 at 1715995939.525058
# Completed translation 343 of 9084 at 1715995942.1870487
# Completed translation 344 of 9084 at 1715995944.8312993
# Completed translation 345 of 9084 at 1715995947.4767184
# Completed translation 346 of 9084 at 1715995950.1553316
# Completed translation 347 of 9084 at 1715995952.7705956
# Completed translation 348 of 9084 at 1715995955.4315603
# Completed translation 349 of 9084 at 1715995958.1150002
# Completed translation 350 of 9084 at 1715995960.720838
# Completed translation 351 of 9084 at 1715995963.3479555
# Completed translation 352 of 9084 at 1715995965.979935
# Completed translation 353 of 9084 at 1715995968.626719
# Completed translation 354 of 9084 at 1715995971.3512087
# Completed translation 355 of 9084 at 1715995974.0270922
# Completed translation 356 of 9084 at 1715995976.747759
# Completed translation 357 of 9084 at 1715995979.4646423
# Completed translation 358 of 9084 at 1715995982.10269
# Completed translation 359 of 9084 at 1715995984.7881796
# Completed translation 360 of 9084 at 1715995987.4113784
# Completed translation 361 of 9084 at 1715995990.1064034
# Completed translation 362 of 9084 at 1715995992.7578526
# Completed translation 363 of 9084 at 1715995995.3553057
# Completed translation 364 of 9084 at 1715995998.0300026
# Completed translation 365 of 9084 at 1715996000.6826274
# Completed translation 366 of 9084 at 1715996003.3168898
# Completed translation 367 of 9084 at 1715996005.946831
# Completed translation 368 of 9084 at 1715996008.6160583
# Completed translation 369 of 9084 at 1715996011.2168996
# Completed translation 370 of 9084 at 1715996013.89117
# Completed translation 371 of 9084 at 1715996016.60029
# Completed translation 372 of 9084 at 1715996019.208911
# Completed translation 373 of 9084 at 1715996021.813388
# Completed translation 374 of 9084 at 1715996024.514792
# Completed translation 375 of 9084 at 1715996027.1565309
# Completed translation 376 of 9084 at 1715996029.7944634
# Completed translation 377 of 9084 at 1715996032.5063434
# Completed translation 378 of 9084 at 1715996035.1865149
# Completed translation 379 of 9084 at 1715996037.8529077
# Completed translation 380 of 9084 at 1715996040.5115209
# Completed translation 381 of 9084 at 1715996043.107976
# Completed translation 382 of 9084 at 1715996045.6853604
# Completed translation 383 of 9084 at 1715996048.3268962
# Completed translation 384 of 9084 at 1715996050.9837246
# Completed translation 385 of 9084 at 1715996053.6091607
# Completed translation 386 of 9084 at 1715996056.2916362
# Completed translation 387 of 9084 at 1715996058.9271965
# Completed translation 388 of 9084 at 1715996061.5375504
# Completed translation 389 of 9084 at 1715996064.161029
# Completed translation 390 of 9084 at 1715996066.7723255
# Completed translation 391 of 9084 at 1715996069.413493
# Completed translation 392 of 9084 at 1715996072.129335
# Completed translation 393 of 9084 at 1715996074.7727325
# Completed translation 394 of 9084 at 1715996077.4327447
# Completed translation 395 of 9084 at 1715996080.061507
# Completed translation 396 of 9084 at 1715996082.7352717
# Completed translation 397 of 9084 at 1715996085.454277
# Completed translation 398 of 9084 at 1715996088.090318
# Completed translation 399 of 9084 at 1715996090.7194114
# Completed translation 400 of 9084 at 1715996093.3948557
# Memory usage summary:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |  25298 KiB |  33256 KiB |   6737 GiB |   6737 GiB |
# |       from large pool |   8320 KiB |   8320 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16978 KiB |  24936 KiB |   6737 GiB |   6737 GiB |
# |---------------------------------------------------------------------------|
# | Active memory         |  25298 KiB |  33256 KiB |   6737 GiB |   6737 GiB |
# |       from large pool |   8320 KiB |   8320 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16978 KiB |  24936 KiB |   6737 GiB |   6737 GiB |
# |---------------------------------------------------------------------------|
# | Requested memory      |  25230 KiB |  33173 KiB |   6735 GiB |   6735 GiB |
# |       from large pool |   8320 KiB |   8320 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16910 KiB |  24853 KiB |   6735 GiB |   6735 GiB |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |  45056 KiB |  47104 KiB | 235520 KiB | 190464 KiB |
# |       from large pool |  20480 KiB |  20480 KiB |  20480 KiB |      0 KiB |
# |       from small pool |  24576 KiB |  26624 KiB | 215040 KiB | 190464 KiB |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |  19757 KiB |  19757 KiB |   6738 GiB |   6738 GiB |
# |       from large pool |  12160 KiB |  12160 KiB |      0 GiB |      0 GiB |
# |       from small pool |   7597 KiB |   7597 KiB |   6738 GiB |   6738 GiB |
# |---------------------------------------------------------------------------|
# | Allocations           |     440    |     623    |   30246 K  |   30246 K  |
# |       from large pool |       1    |       1    |       0 K  |       0 K  |
# |       from small pool |     439    |     622    |   30246 K  |   30246 K  |
# |---------------------------------------------------------------------------|
# | Active allocs         |     440    |     623    |   30246 K  |   30246 K  |
# |       from large pool |       1    |       1    |       0 K  |       0 K  |
# |       from small pool |     439    |     622    |   30246 K  |   30246 K  |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |      13    |      14    |     106    |      93    |
# |       from large pool |       1    |       1    |       1    |       0    |
# |       from small pool |      12    |      13    |     105    |      93    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |       7    |      21    |   10973 K  |   10973 K  |
# |       from large pool |       1    |       1    |       0 K  |       0 K  |
# |       from small pool |       6    |      20    |   10973 K  |   10973 K  |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|
#
# Translation400: {'source': 'Düşük ücretler tek başlarına haksız rekabete yol açmazlar.Ģ', 'target': 'Low wages, by themselves, are not an unfair competitive tool.Ģ', 'translation': 'oHH2%6%H662H6%262626222%6262%22%H%2H%2H6H6HH2HH2%HH]"?)")])?]")?"]?)"]???])?)?"])???]?]"])))]")?""")]]"?""??]""?])]]??)??)]?)"]])??]?))]]]]?)]))]?"")")?")])?")")"""?""?))?"]?"]])))"?])?"]")")]")")???""?]")?]??)))]?)])]))???)])?)""???)"]))?"])]?)]"????])]??'}
# Completed translation 401 of 9084 at 1715996096.077627
# Completed translation 402 of 9084 at 1715996098.850534
# Completed translation 403 of 9084 at 1715996101.4915667
# Completed translation 404 of 9084 at 1715996104.1400237
# Completed translation 405 of 9084 at 1715996106.7520027
# Completed translation 406 of 9084 at 1715996109.3731523
# Completed translation 407 of 9084 at 1715996112.1115282
# Completed translation 408 of 9084 at 1715996114.8313649
# Completed translation 409 of 9084 at 1715996117.5726113
# Completed translation 410 of 9084 at 1715996120.2273686
# Completed translation 411 of 9084 at 1715996122.858107
# Completed translation 412 of 9084 at 1715996125.5444074
# Completed translation 413 of 9084 at 1715996128.1775684
# Completed translation 414 of 9084 at 1715996130.7994165
# Completed translation 415 of 9084 at 1715996133.4231045
# Completed translation 416 of 9084 at 1715996136.08542
# Completed translation 417 of 9084 at 1715996138.7729561
# Completed translation 418 of 9084 at 1715996141.488587
# Completed translation 419 of 9084 at 1715996144.1290736
# Completed translation 420 of 9084 at 1715996146.9597957
# Completed translation 421 of 9084 at 1715996149.6842313
# Completed translation 422 of 9084 at 1715996152.4936776
# Completed translation 423 of 9084 at 1715996155.3518207
# Completed translation 424 of 9084 at 1715996158.0553558
# Completed translation 425 of 9084 at 1715996160.7706368
# Completed translation 426 of 9084 at 1715996163.4564638
# Completed translation 427 of 9084 at 1715996166.112018
# Completed translation 428 of 9084 at 1715996168.7595417
# Completed translation 429 of 9084 at 1715996171.4034998
# Completed translation 430 of 9084 at 1715996174.1260054
# Completed translation 431 of 9084 at 1715996176.7434425
# Completed translation 432 of 9084 at 1715996179.664576
# Completed translation 433 of 9084 at 1715996182.3043616
# Completed translation 434 of 9084 at 1715996184.9984894
# Completed translation 435 of 9084 at 1715996187.6546052
# Completed translation 436 of 9084 at 1715996190.3162818
# Completed translation 437 of 9084 at 1715996193.1203241
# Completed translation 438 of 9084 at 1715996195.9489458
# Completed translation 439 of 9084 at 1715996198.7074294
# Completed translation 440 of 9084 at 1715996201.3608153
# Completed translation 441 of 9084 at 1715996204.002737
# Completed translation 442 of 9084 at 1715996206.5959225
# Completed translation 443 of 9084 at 1715996209.235283
# Completed translation 444 of 9084 at 1715996211.8369274
# Completed translation 445 of 9084 at 1715996214.4795136
# Completed translation 446 of 9084 at 1715996217.1329954
# Completed translation 447 of 9084 at 1715996219.816981
# Completed translation 448 of 9084 at 1715996222.4974825
# Completed translation 449 of 9084 at 1715996225.1048348
# Completed translation 450 of 9084 at 1715996227.7142613
# Completed translation 451 of 9084 at 1715996230.3151577
# Completed translation 452 of 9084 at 1715996233.0232096
# Completed translation 453 of 9084 at 1715996235.6554847
# Completed translation 454 of 9084 at 1715996238.2955632
# Completed translation 455 of 9084 at 1715996240.9090855
# Completed translation 456 of 9084 at 1715996243.5744467
# Completed translation 457 of 9084 at 1715996246.214003
# Completed translation 458 of 9084 at 1715996248.8215156
# Completed translation 459 of 9084 at 1715996251.4358156
# Completed translation 460 of 9084 at 1715996254.063688
# Completed translation 461 of 9084 at 1715996256.7982926
# Completed translation 462 of 9084 at 1715996259.4335425
# Completed translation 463 of 9084 at 1715996262.0575476
# ...
# Completed translation 3196 of 9084 at 1716003595.5542064
# Completed translation 3197 of 9084 at 1716003598.2019658
# Completed translation 3198 of 9084 at 1716003600.911456
# Completed translation 3199 of 9084 at 1716003603.5444734
# Completed translation 3200 of 9084 at 1716003606.2642987
# Memory usage summary:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |  25298 KiB |  39600 KiB |  57355 GiB |  57354 GiB |
# |       from large pool |   8320 KiB |   8320 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16978 KiB |  31280 KiB |  57355 GiB |  57354 GiB |
# |---------------------------------------------------------------------------|
# | Active memory         |  25298 KiB |  39600 KiB |  57355 GiB |  57354 GiB |
# |       from large pool |   8320 KiB |   8320 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16978 KiB |  31280 KiB |  57355 GiB |  57354 GiB |
# |---------------------------------------------------------------------------|
# | Requested memory      |  25230 KiB |  39510 KiB |  57345 GiB |  57345 GiB |
# |       from large pool |   8320 KiB |   8320 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16910 KiB |  31190 KiB |  57345 GiB |  57345 GiB |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |  45056 KiB |  53248 KiB |  11106 MiB |  11062 MiB |
# |       from large pool |  20480 KiB |  20480 KiB |     20 MiB |      0 MiB |
# |       from small pool |  24576 KiB |  32768 KiB |  11086 MiB |  11062 MiB |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |  19757 KiB |  25814 KiB |  58613 GiB |  58613 GiB |
# |       from large pool |  12160 KiB |  12160 KiB |      0 GiB |      0 GiB |
# |       from small pool |   7597 KiB |  13654 KiB |  58613 GiB |  58613 GiB |
# |---------------------------------------------------------------------------|
# | Allocations           |     440    |     622    |  241439 K  |  241439 K  |
# |       from large pool |       1    |       1    |       0 K  |       0 K  |
# |       from small pool |     439    |     621    |  241439 K  |  241439 K  |
# |---------------------------------------------------------------------------|
# | Active allocs         |     440    |     622    |  241439 K  |  241439 K  |
# |       from large pool |       1    |       1    |       0 K  |       0 K  |
# |       from small pool |     439    |     621    |  241439 K  |  241439 K  |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |      13    |      17    |    5544    |    5531    |
# |       from large pool |       1    |       1    |       1    |       0    |
# |       from small pool |      12    |      16    |    5543    |    5531    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |       7    |      24    |   95099 K  |   95099 K  |
# |       from large pool |       1    |       1    |       0 K  |       0 K  |
# |       from small pool |       6    |      23    |   95099 K  |   95099 K  |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|
#
# Translation3200: {'source': "Papa, Vatikan'ın Makedonya'nın çok ırklı ve çok inançlı hoşgörü modeline verdiği desteği de ifade etti. 16.Ģ", 'target': 'He also stressed Vatican support for the Macedonian model of multi-ethnic and multi-confessional tolerance.Ģ', 'translation': 's6662HH2H%62H26%%6626666%H%%2%6662H626%66HH6%H2%62H)]"?"]"""")]?]]?)?))]?)?)?""?"?))"?))]"]?]?]?)))?])?]]]?])?"]"))?")?]"""?)])??]?]??])"??)")""]"]"??")]""]"?"")??]]")"??])??)"))""))?")]")")])]?))??]"?"??]?)]]?")]"]])")]])?)]?"")""?)")]?"")?]]?)])?"]]??)]?'}
# Completed translation 3201 of 9084 at 1716003609.0092387
# Completed translation 3202 of 9084 at 1716003611.6632154
# Completed translation 3203 of 9084 at 1716003614.2559953
# Completed translation 3204 of 9084 at 1716003616.9536254
# Completed translation 3205 of 9084 at 1716003619.5788531
# Completed translation 3206 of 9084 at 1716003622.2535644
# Completed translation 3207 of 9084 at 1716003624.8841097
# Completed translation 3208 of 9084 at 1716003627.5119348
# Completed translation 3209 of 9084 at 1716003630.2686946
# Completed translation 3210 of 9084 at 1716003632.8868525
# Completed translation 3211 of 9084 at 1716003635.5375218
# Completed translation 3212 of 9084 at 1716003638.1753645
# Completed translation 3213 of 9084 at 1716003640.887962
# Completed translation 3214 of 9084 at 1716003643.5910168
# Completed translation 3215 of 9084 at 1716003646.2421677
# Completed translation 3216 of 9084 at 1716003648.9276006
# Completed translation 3217 of 9084 at 1716003651.5433424
# Completed translation 3218 of 9084 at 1716003654.1836073
# Completed translation 3219 of 9084 at 1716003656.8756454
# Completed translation 3220 of 9084 at 1716003659.4989352
# Completed translation 3221 of 9084 at 1716003662.1634517
# Completed translation 3222 of 9084 at 1716003664.8388712
# Completed translation 3223 of 9084 at 1716003667.5140839
# Completed translation 3224 of 9084 at 1716003670.2274444
# Completed translation 3225 of 9084 at 1716003672.85526
# Completed translation 3226 of 9084 at 1716003675.4904726
# Completed translation 3227 of 9084 at 1716003678.1236072
# Completed translation 3228 of 9084 at 1716003680.7848938
# Completed translation 3229 of 9084 at 1716003683.411351
# Completed translation 3230 of 9084 at 1716003686.028451
# Completed translation 3231 of 9084 at 1716003688.6512933
# Completed translation 3232 of 9084 at 1716003691.3390012
# Completed translation 3233 of 9084 at 1716003693.9807575
# Completed translation 3234 of 9084 at 1716003696.7053618
# Completed translation 3235 of 9084 at 1716003699.3247352
# Completed translation 3236 of 9084 at 1716003702.0204637
# Completed translation 3237 of 9084 at 1716003704.6286638
# Completed translation 3238 of 9084 at 1716003707.2389243
# Completed translation 3239 of 9084 at 1716003709.901443
# Completed translation 3240 of 9084 at 1716003712.5749166
# Completed translation 3241 of 9084 at 1716003715.2925563
# Completed translation 3242 of 9084 at 1716003717.9787195
# Completed translation 3243 of 9084 at 1716003720.6071193
# Completed translation 3244 of 9084 at 1716003723.2498415
# Completed translation 3245 of 9084 at 1716003725.883783
# Completed translation 3246 of 9084 at 1716003728.5098183
# Completed translation 3247 of 9084 at 1716003731.399955
# Completed translation 3248 of 9084 at 1716003734.0960104
# Completed translation 3249 of 9084 at 1716003736.7126973
# Completed translation 3250 of 9084 at 1716003739.4064572
# Completed translation 3251 of 9084 at 1716003742.0599556
# Completed translation 3252 of 9084 at 1716003744.698623
# Completed translation 3253 of 9084 at 1716003747.4985285
# Completed translation 3254 of 9084 at 1716003750.1711767
# Completed translation 3255 of 9084 at 1716003752.8037937
# Completed translation 3256 of 9084 at 1716003755.4347253
# Completed translation 3257 of 9084 at 1716003758.145008
# Completed translation 3258 of 9084 at 1716003760.8140557
# Completed translation 3259 of 9084 at 1716003763.5289392
# Completed translation 3260 of 9084 at 1716003766.1712952
# Completed translation 3261 of 9084 at 1716003768.7858512
# Completed translation 3262 of 9084 at 1716003771.4121628
# Completed translation 3263 of 9084 at 1716003774.172794
# Completed translation 3264 of 9084 at 1716003776.9684403
# Completed translation 3265 of 9084 at 1716003779.6134467
# Completed translation 3266 of 9084 at 1716003782.2761905
# Completed translation 3267 of 9084 at 1716003785.051218
# Completed translation 3268 of 9084 at 1716003787.8885462
# Completed translation 3269 of 9084 at 1716003790.6292548
# Completed translation 3270 of 9084 at 1716003793.4069536
# Completed translation 3271 of 9084 at 1716003796.1090028
# Completed translation 3272 of 9084 at 1716003798.780391
# Completed translation 3273 of 9084 at 1716003801.5667763
# Completed translation 3274 of 9084 at 1716003804.3460643
# Completed translation 3275 of 9084 at 1716003807.068757
# Completed translation 3276 of 9084 at 1716003809.7346568
# Completed translation 3277 of 9084 at 1716003812.501656
# Completed translation 3278 of 9084 at 1716003815.1502001
# Completed translation 3279 of 9084 at 1716003817.8522444
# Completed translation 3280 of 9084 at 1716003820.503953
# Completed translation 3281 of 9084 at 1716003823.274456
# Completed translation 3282 of 9084 at 1716003825.9679332
# Completed translation 3283 of 9084 at 1716003828.6253557
# Completed translation 3284 of 9084 at 1716003831.368088
# Completed translation 3285 of 9084 at 1716003834.0400407
# Completed translation 3286 of 9084 at 1716003836.6727092
# Completed translation 3287 of 9084 at 1716003839.4581964
# Completed translation 3288 of 9084 at 1716003842.1299548
# Completed translation 3289 of 9084 at 1716003844.77989
# Completed translation 3290 of 9084 at 1716003847.453944
# Completed translation 3291 of 9084 at 1716003850.1113744
# Completed translation 3292 of 9084 at 1716003852.743962
# Completed translation 3293 of 9084 at 1716003855.4216983
# Completed translation 3294 of 9084 at 1716003858.0594838
# Completed translation 3295 of 9084 at 1716003860.7895963
# Completed translation 3296 of 9084 at 1716003863.630096
# Completed translation 3297 of 9084 at 1716003866.3334274
# Completed translation 3298 of 9084 at 1716003868.9986925
# Completed translation 3299 of 9084 at 1716003871.678092
# Completed translation 3300 of 9084 at 1716003874.3596697
# Memory usage summary:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |  25298 KiB |  39154 KiB |  59262 GiB |  59262 GiB |
# |       from large pool |   8320 KiB |   8320 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16978 KiB |  30834 KiB |  59262 GiB |  59262 GiB |
# |---------------------------------------------------------------------------|
# | Active memory         |  25298 KiB |  39154 KiB |  59262 GiB |  59262 GiB |
# |       from large pool |   8320 KiB |   8320 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16978 KiB |  30834 KiB |  59262 GiB |  59262 GiB |
# |---------------------------------------------------------------------------|
# | Requested memory      |  25230 KiB |  39063 KiB |  59252 GiB |  59252 GiB |
# |       from large pool |   8320 KiB |   8320 KiB |      0 GiB |      0 GiB |
# |       from small pool |  16910 KiB |  30743 KiB |  59252 GiB |  59252 GiB |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |  45056 KiB |  53248 KiB |  11724 MiB |  11680 MiB |
# |       from large pool |  20480 KiB |  20480 KiB |     20 MiB |      0 MiB |
# |       from small pool |  24576 KiB |  32768 KiB |  11704 MiB |  11680 MiB |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |  19757 KiB |  25237 KiB |  60605 GiB |  60605 GiB |
# |       from large pool |  12160 KiB |  12160 KiB |      0 GiB |      0 GiB |
# |       from small pool |   7597 KiB |  13077 KiB |  60605 GiB |  60605 GiB |
# |---------------------------------------------------------------------------|
# | Allocations           |     440    |     623    |  248982 K  |  248981 K  |
# |       from large pool |       1    |       1    |       0 K  |       0 K  |
# |       from small pool |     439    |     622    |  248982 K  |  248981 K  |
# |---------------------------------------------------------------------------|
# | Active allocs         |     440    |     623    |  248982 K  |  248981 K  |
# |       from large pool |       1    |       1    |       0 K  |       0 K  |
# |       from small pool |     439    |     622    |  248982 K  |  248981 K  |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |      13    |      17    |    5853    |    5840    |
# |       from large pool |       1    |       1    |       1    |       0    |
# |       from small pool |      12    |      16    |    5852    |    5840    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |       7    |      22    |   98255 K  |   98255 K  |
# |       from large pool |       1    |       1    |       0 K  |       0 K  |
# |       from small pool |       6    |      21    |   98255 K  |   98255 K  |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|
#
# Translation3300: {'source': 'Ancak uluslararası toplum, ülkenin önce gerekli standartları karşıladığını göstermesi gerektiğini söylüyor.Ģ', 'target': 'However, the international community says the country must first show it is fulfilling the required standards.Ģ', 'translation': 's2H2622226626%2%H22626%26%2226%H26HHH62%HHH%6H%%%%%])""]"?)))"??""?]))]""))?")"""??"?])]??]?)?"]))"]""]"?])])""")]]]]]]?)])""])"")]")]??"?)?)?]]?"?"]"?)?])"?"?))))"))"???)")]"")]"")"??")?)?)?)))?)))??]"]"""?]"]"]")")]?)]])]]]]))?")?)))"???]"??)]]]?)]?])"]"'}
# Completed translation 3301 of 9084 at 1716003877.0786586
# Completed translation 3302 of 9084 at 1716003879.7521818
# Completed translation 3303 of 9084 at 1716003882.3922384
# Completed translation 3304 of 9084 at 1716003885.1559026
# Completed translation 3305 of 9084 at 1716003887.796412
# Completed translation 3306 of 9084 at 1716003890.643505
# Completed translation 3307 of 9084 at 1716003893.381367
# Completed translation 3308 of 9084 at 1716003896.264439
# Completed translation 3309 of 9084 at 1716003899.0622346
# Completed translation 3310 of 9084 at 1716003901.7151752
# Completed translation 3311 of 9084 at 1716003904.3809001
# Completed translation 3312 of 9084 at 1716003907.10239
# Completed translation 3313 of 9084 at 1716003909.8626194
# Completed translation 3314 of 9084 at 1716003912.6484122
# Completed translation 3315 of 9084 at 1716003915.3334394
# Completed translation 3316 of 9084 at 1716003918.2704275
# Completed translation 3317 of 9084 at 1716003921.0787117
# Completed translation 3318 of 9084 at 1716003923.8489244
# Completed translation 3319 of 9084 at 1716003926.6389544
# Completed translation 3320 of 9084 at 1716003929.3140264
# Completed translation 3321 of 9084 at 1716003932.031007
# Completed translation 3322 of 9084 at 1716003934.8631616
# Completed translation 3323 of 9084 at 1716003937.5597672
# Completed translation 3324 of 9084 at 1716003940.2187083
# Completed translation 3325 of 9084 at 1716003942.9357762
# Completed translation 3326 of 9084 at 1716003945.6257596
# Completed translation 3327 of 9084 at 1716003948.4736555
